# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
import numpy as np
import pylab as plt
import glob
import os
from pprint import pprint
import scipy.integrate as inte
import scipy.special as special
import scipy.interpolate as interp
import scipy.signal as sig

# %%
import stephane.display.graphes as graphes
import stephane.tools.Smath as smath

import icewave.tools.datafolders as df
import icewave.tools.rw_data as rw_data

#import sympy #symoblic python
#import mpmath as math
#import cv2
import glob
import csv
import os

import icewave.phone.rw_pyphone as rw
# Out:
# macOS
# laita.pmmh-local.espci.fr

# %%
base = '/Volumes/Hublot24/Share_hublot/Data/'

savefolder = base+'Summary/Results/'
savefolder_local = '/Users/stephane/Documents/Articles/En_cours/BicWin2024/Summary/Results/'

if not os.path.exists(savefolder):
    os.makedirs(savefolder)
    os.makedirs(savefolder_local)

# %%
folder = '/Volumes/Hublot24/Share_hublot/Data/0221/Drones/bernache/29-frac_001/'
data = rw_data.load_pkl(folder+'record_0221_Bernache_29-frac_001.pkl')
print(data.keys())

# %%
filename = '/Volumes/Hublot24/Share_hublot/Data/0221/Summary/records_0221.pkl'

records = rw_data.load_pkl(filename)

# %%
record = records['drones']['Bernache']
for key in record.keys():
    print(len(record[key]),key)
# Out:
# 1 07-doc_004
# 1 15-float_001
# 3 17-doc_010
# 1 18-calib_001
# 1 19-calib_002
# 1 20-calib_003
# 1 21-calib_004
# 1 22-doc_011
# 1 29-frac_001
# 1 28-stereo_001

# %%
for rec in records['drones']['Bernache']['17-doc_010']:
    plt.plot(rec['longitude'],rec['latitude'],'o')
    print(rec['time'])
# Out:
# ['19:03:30', '19:03:34', '19:03:37', '19:03:40', '19:03:44', '19:03:47', '19:03:50', '19:03:54', '19:03:57', '19:04:00', '19:04:04', '19:04:07', '19:04:10', '19:04:14', '19:04:17', '19:04:20', '19:04:24', '19:04:27', '19:04:30', '19:04:34', '19:04:37', '19:04:40', '19:04:44', '19:04:47', '19:04:50', '19:04:54', '19:04:57', '19:05:00']
# ['19:01:16', '19:01:20', '19:01:23', '19:01:26', '19:01:30', '19:01:33', '19:01:36', '19:01:40', '19:01:43', '19:01:46', '19:01:50', '19:01:53', '19:01:56', '19:02:00', '19:02:03', '19:02:06', '19:02:10', '19:02:13', '19:02:16', '19:02:20', '19:02:23', '19:02:26', '19:02:30', '19:02:33', '19:02:36', '19:02:40']
# ['19:02:48', '19:02:50', '19:02:52', '19:02:53', '19:02:55', '19:02:57', '19:02:58', '19:03:00', '19:03:02', '19:03:03', '19:03:05', '19:03:07', '19:03:08', '19:03:10', '19:03:12', '19:03:13', '19:03:15', '19:03:17', '19:03:18']

# %%
# look for .SRT files of drone
date = '0223'
srtfiles_mesange = glob.glob(base+date+'/Drones/mesange/*/*.SRT')#/*/*.srt')
srtfiles_bernache = glob.glob(base+date+'/Drones/Bernache/*/*.SRT')#/*/*.srt')

pprint(srtfiles_mesange)
# Out:
# ['/Volumes/Hublot24/Share_hublot/Data/0223/Drones/mesange/04-waves_001/DJI_20240223172423_0469_D.SRT',
#  '/Volumes/Hublot24/Share_hublot/Data/0223/Drones/mesange/05-doc_003/DJI_20240223172840_0470_D.SRT',
#  '/Volumes/Hublot24/Share_hublot/Data/0223/Drones/mesange/06-waves_002/DJI_20240223172954_0471_D.SRT',
#  '/Volumes/Hublot24/Share_hublot/Data/0223/Drones/mesange/07-frac+waves_001/DJI_20240223173504_0473_D.SRT',
#  '/Volumes/Hublot24/Share_hublot/Data/0223/Drones/mesange/08-waves_003/DJI_20240223173846_0474_D.SRT',
#  '/Volumes/Hublot24/Share_hublot/Data/0223/Drones/mesange/10-rheo+waves_001/DJI_20240223174526_0477_D.SRT',
#  '/Volumes/Hublot24/Share_hublot/Data/0223/Drones/mesange/10-rheo+waves_001/DJI_20240223174913_0478_D.SRT',
#  '/Volumes/Hublot24/Share_hublot/Data/0223/Drones/mesange/11-ortho_002/DJI_20240223175144_0552_D.SRT',
#  '/Volumes/Hublot24/Share_hublot/Data/0223/Drones/mesange/12-waves_004/DJI_20240223175826_0785_D.SRT',
#  '/Volumes/Hublot24/Share_hublot/Data/0223/Drones/mesange/13-waves_005/DJI_20240223180617_0787_D.SRT',
#  '/Volumes/Hublot24/Share_hublot/Data/0223/Drones/mesange/13-waves_005/DJI_20240223180230_0786_D.SRT',
#  '/Volumes/Hublot24/Share_hublot/Data/0223/Drones/mesange/14-waves_006/DJI_20240223180737_0789_D.SRT',
#  '/Volumes/Hublot24/Share_hublot/Data/0223/Drones/mesange/17-waves_007/DJI_20240223181757_0948_D.SRT',
#  '/Volumes/Hublot24/Share_hublot/Data/0223/Drones/mesange/18-waves_008/DJI_20240223182218_0950_D.SRT',
#  '/Volumes/Hublot24/Share_hublot/Data/0223/Drones/mesange/18-waves_008/DJI_20240223181831_0949_D.SRT',
#  '/Volumes/Hublot24/Share_hublot/Data/0223/Drones/mesange/19-canot_001/DJI_20240223182247_0951_D.SRT',
#  '/Volumes/Hublot24/Share_hublot/Data/0223/Drones/mesange/20-frac+waves_002/DJI_20240223182550_0952_D.SRT',
#  '/Volumes/Hublot24/Share_hublot/Data/0223/Drones/mesange/21-waves_009/DJI_20240223182831_0954_D.SRT',
#  '/Volumes/Hublot24/Share_hublot/Data/0223/Drones/mesange/23_waves_010/DJI_20240223183314_0957_D.SRT',
#  '/Volumes/Hublot24/Share_hublot/Data/0223/Drones/mesange/24-doc_005/DJI_20240223183725_0958_D.SRT',
#  '/Volumes/Hublot24/Share_hublot/Data/0223/Drones/mesange/25-doc_006/DJI_20240223183735_0959_D.SRT',
#  '/Volumes/Hublot24/Share_hublot/Data/0223/Drones/mesange/27-doc_007/DJI_20240223184032_0007_D.SRT',
#  '/Volumes/Hublot24/Share_hublot/Data/0223/Drones/mesange/28-waves_011/DJI_20240223185105_0242_D.SRT',
#  '/Volumes/Hublot24/Share_hublot/Data/0223/Drones/mesange/29-waves_012/DJI_20240223185630_0244_D.SRT',
#  '/Volumes/Hublot24/Share_hublot/Data/0223/Drones/mesange/30-rheo+waves_002/DJI_20240223190117_0246_D.SRT',
#  '/Volumes/Hublot24/Share_hublot/Data/0223/Drones/mesange/32-canot-002/DJI_20240223193826_0315_D.SRT',
#  '/Volumes/Hublot24/Share_hublot/Data/0223/Drones/mesange/34-waves_013/DJI_20240223194021_0316_D.SRT',
#  '/Volumes/Hublot24/Share_hublot/Data/0223/Drones/mesange/35-waves_014/DJI_20240223194842_0318_D.SRT',
#  '/Volumes/Hublot24/Share_hublot/Data/0223/Drones/mesange/35-waves_014/DJI_20240223194455_0317_D.SRT',
#  '/Volumes/Hublot24/Share_hublot/Data/0223/Drones/mesange/37-waves_015/DJI_20240223195200_0393_D.SRT',
#  '/Volumes/Hublot24/Share_hublot/Data/0223/Drones/mesange/39-waves_016/DJI_20240223200958_0396_D.SRT',
#  '/Volumes/Hublot24/Share_hublot/Data/0223/Drones/mesange/40-waves_017/DJI_20240223201247_0397_D.SRT',
#  '/Volumes/Hublot24/Share_hublot/Data/0223/Drones/mesange/41-waves_018/DJI_20240223201328_0398_D.SRT',
#  '/Volumes/Hublot24/Share_hublot/Data/0223/Drones/mesange/42-waves_019/DJI_20240223201658_0399_D.SRT']

# %%
folder = '/Volumes/Hublot24/Share_hublot/Data/0221/Drones/bernache/29-frac_001/'
data = rw_data.load_pkl(folder+'record_0221_Bernache_29-frac_001.pkl')
print(data.keys())
# Out:
# dict_keys(['OSD.altitude [ft]', 'OSD.mileage [ft]', 'OSD.hSpeed [MPH]', 'OSD.xSpeed [MPH]', 'OSD.ySpeed [MPH]', 'OSD.zSpeed [MPH]', 'OSD.pitch', 'OSD.roll', 'OSD.yaw', 'OSD.yaw [360]', 'OSD.gpsNum', 'GIMBAL.pitch', 'GIMBAL.roll', 'GIMBAL.yaw', 'GIMBAL.yaw [360]', 'CUSTOM.date [local]', 'CUSTOM.updateTime [local]', 'CAMERA.isPhoto', 'CAMERA.isVideo'])

# %%
data['CUSTOM.updateTime [local]'][0]
# Out:
# '8:18:28.01 PM'

# %%
print(np.mean(data['OSD.yaw [360]']),np.std(data['OSD.yaw [360]']))
# Out:
# 128.1460490463215 0.17833449205061058

# %%
for key in data.keys():
    try:
        print(key,np.mean(data[key]),np.std(data[key]))
    except:
        print(key)
# Out:
# OSD.altitude [ft] 197.0 0.0
# OSD.mileage [ft] 119.26103542234331 11.827158144397462
# OSD.hSpeed [MPH] 0.01792856403269755 0.061391761426445
# OSD.xSpeed [MPH] -0.012190408719346048 0.053394825143708705
# OSD.ySpeed [MPH] -0.0012190408719346048 0.03300427933736338
# OSD.zSpeed [MPH] 0.0 0.0
# OSD.pitch 0.08828337874659395 2.142968743790422
# OSD.roll 2.1223433242506813 1.4979702750050679
# OSD.yaw 128.1460490463215 0.17833449205061058
# OSD.yaw [360] 128.1460490463215 0.17833449205061058
# OSD.gpsNum 23.0 0.0
# GIMBAL.pitch -90.0 0.0
# GIMBAL.roll 0.0 0.0
# GIMBAL.yaw 139.9 0.0
# GIMBAL.yaw [360] 139.9 0.0
# CUSTOM.date [local]
# CUSTOM.updateTime [local]
# CAMERA.isPhoto 1.0 0.0
# CAMERA.isVideo 1.0 0.0

# %%
#pprint(d[:6])
#event = d[:6]
#pprint([event[1],event[3],event[4]])

# %%
def get_flighrecord(data,step=100):
    n = int(len(data)/6)
    print('number of records : '+str(n))
    record = {}
    for i in range(0,n-1,step):
        event = data[i*6:(i+1)*6]
        if int(event[0][0])==i+1:  
            record[i]={}
            record[i]['record_time']=event[1]
            record[i]['date']=event[3][0].split(' ')[0]
            record[i]['time']=event[3][0].split(' ')[1][:-4]
            params = event[4][0]
            latitude = float(params.split('latitude: ')[1].split(']')[0])
            longitude = float(params.split('longitude: ')[1].split(']')[0])

            #print(event[3],latitude,longitude)
            record[i]['latitude']=latitude
            record[i]['longitude']=longitude
            record[i]['params'] = params
#pprint(d[6:12])
    return record

# %%
print(event[3][0].split(' ')[1][:-4])
print(event[3][0].split(' ')[0])
# Out:
# 13:03:30
# 2024-02-23

# %%
import icewave.field.drone as drone
date = '0223'
records_drones = drone.get_records(date)
# Out:
# /Volumes/Hublot24/Share_hublot/Data/
# ['/Volumes/Hublot24/Share_hublot/Data/0223/Drones/mesange/04-waves_001/DJI_20240223172423_0469_D.SRT', '/Volumes/Hublot24/Share_hublot/Data/0223/Drones/mesange/05-doc_003/DJI_20240223172840_0470_D.SRT', '/Volumes/Hublot24/Share_hublot/Data/0223/Drones/mesange/06-waves_002/DJI_20240223172954_0471_D.SRT', '/Volumes/Hublot24/Share_hublot/Data/0223/Drones/mesange/07-frac+waves_001/DJI_20240223173504_0473_D.SRT', '/Volumes/Hublot24/Share_hublot/Data/0223/Drones/mesange/08-waves_003/DJI_20240223173846_0474_D.SRT', '/Volumes/Hublot24/Share_hublot/Data/0223/Drones/mesange/10-rheo+waves_001/DJI_20240223174526_0477_D.SRT', '/Volumes/Hublot24/Share_hublot/Data/0223/Drones/mesange/10-rheo+waves_001/DJI_20240223174913_0478_D.SRT', '/Volumes/Hublot24/Share_hublot/Data/0223/Drones/mesange/11-ortho_002/DJI_20240223175144_0552_D.SRT', '/Volumes/Hublot24/Share_hublot/Data/0223/Drones/mesange/12-waves_004/DJI_20240223175826_0785_D.SRT', '/Volumes/Hublot24/Share_hublot/Data/0223/Drones/mesange/13-waves_005/DJI_20240223180617_0787_D.SRT', '/Volumes/Hublot24/Share_hublot/Data/0223/Drones/mesange/13-waves_005/DJI_20240223180230_0786_D.SRT', '/Volumes/Hublot24/Share_hublot/Data/0223/Drones/mesange/14-waves_006/DJI_20240223180737_0789_D.SRT', '/Volumes/Hublot24/Share_hublot/Data/0223/Drones/mesange/17-waves_007/DJI_20240223181757_0948_D.SRT', '/Volumes/Hublot24/Share_hublot/Data/0223/Drones/mesange/18-waves_008/DJI_20240223182218_0950_D.SRT', '/Volumes/Hublot24/Share_hublot/Data/0223/Drones/mesange/18-waves_008/DJI_20240223181831_0949_D.SRT', '/Volumes/Hublot24/Share_hublot/Data/0223/Drones/mesange/19-canot_001/DJI_20240223182247_0951_D.SRT', '/Volumes/Hublot24/Share_hublot/Data/0223/Drones/mesange/20-frac+waves_002/DJI_20240223182550_0952_D.SRT', '/Volumes/Hublot24/Share_hublot/Data/0223/Drones/mesange/21-waves_009/DJI_20240223182831_0954_D.SRT', '/Volumes/Hublot24/Share_hublot/Data/0223/Drones/mesange/23_waves_010/DJI_20240223183314_0957_D.SRT', '/Volumes/Hublot24/Share_hublot/Data/0223/Drones/mesange/24-doc_005/DJI_20240223183725_0958_D.SRT', '/Volumes/Hublot24/Share_hublot/Data/0223/Drones/mesange/25-doc_006/DJI_20240223183735_0959_D.SRT', '/Volumes/Hublot24/Share_hublot/Data/0223/Drones/mesange/27-doc_007/DJI_20240223184032_0007_D.SRT', '/Volumes/Hublot24/Share_hublot/Data/0223/Drones/mesange/28-waves_011/DJI_20240223185105_0242_D.SRT', '/Volumes/Hublot24/Share_hublot/Data/0223/Drones/mesange/29-waves_012/DJI_20240223185630_0244_D.SRT', '/Volumes/Hublot24/Share_hublot/Data/0223/Drones/mesange/30-rheo+waves_002/DJI_20240223190117_0246_D.SRT', '/Volumes/Hublot24/Share_hublot/Data/0223/Drones/mesange/32-canot-002/DJI_20240223193826_0315_D.SRT', '/Volumes/Hublot24/Share_hublot/Data/0223/Drones/mesange/34-waves_013/DJI_20240223194021_0316_D.SRT', '/Volumes/Hublot24/Share_hublot/Data/0223/Drones/mesange/35-waves_014/DJI_20240223194842_0318_D.SRT', '/Volumes/Hublot24/Share_hublot/Data/0223/Drones/mesange/35-waves_014/DJI_20240223194455_0317_D.SRT', '/Volumes/Hublot24/Share_hublot/Data/0223/Drones/mesange/37-waves_015/DJI_20240223195200_0393_D.SRT', '/Volumes/Hublot24/Share_hublot/Data/0223/Drones/mesange/39-waves_016/DJI_20240223200958_0396_D.SRT', '/Volumes/Hublot24/Share_hublot/Data/0223/Drones/mesange/40-waves_017/DJI_20240223201247_0397_D.SRT', '/Volumes/Hublot24/Share_hublot/Data/0223/Drones/mesange/41-waves_018/DJI_20240223201328_0398_D.SRT', '/Volumes/Hublot24/Share_hublot/Data/0223/Drones/mesange/42-waves_019/DJI_20240223201658_0399_D.SRT']
# ['/Volumes/Hublot24/Share_hublot/Data/0223/Drones/Bernache/16-waves_011/DJI_20240223125950_0097_D.SRT', '/Volumes/Hublot24/Share_hublot/Data/0223/Drones/Bernache/17-waves_012/DJI_20240223130751_0099_D.SRT', '/Volumes/Hublot24/Share_hublot/Data/0223/Drones/Bernache/17-waves_012/DJI_20240223130403_0098_D.SRT', '/Volumes/Hublot24/Share_hublot/Data/0223/Drones/Bernache/18-doc_002/DJI_20240223130816_0100_D.SRT', '/Volumes/Hublot24/Share_hublot/Data/0223/Drones/Bernache/20-waves_013/DJI_20240223131939_0141_D.SRT', '/Volumes/Hublot24/Share_hublot/Data/0223/Drones/Bernache/21-waves_014/DJI_20240223133416_0142_D.SRT', '/Volumes/Hublot24/Share_hublot/Data/0223/Drones/Bernache/22-waves_015/DJI_20240223134119_0144_D.SRT', '/Volumes/Hublot24/Share_hublot/Data/0223/Drones/Bernache/22-waves_015/DJI_20240223133732_0143_D.SRT', '/Volumes/Hublot24/Share_hublot/Data/0223/Drones/Bernache/23-doc_003/DJI_20240223134220_0145_D.SRT', '/Volumes/Hublot24/Share_hublot/Data/0223/Drones/Bernache/25-waves_016/DJI_20240223143438_0480_D.SRT', '/Volumes/Hublot24/Share_hublot/Data/0223/Drones/Bernache/26-diamand_001/DJI_20240223143520_0481_D.SRT', '/Volumes/Hublot24/Share_hublot/Data/0223/Drones/Bernache/27-ice_001/DJI_20240223143919_0483_D.SRT', '/Volumes/Hublot24/Share_hublot/Data/0223/Drones/Bernache/27-ice_001/DJI_20240223143532_0482_D.SRT', '/Volumes/Hublot24/Share_hublot/Data/0223/Drones/Bernache/28-waves_017/DJI_20240223144023_0484_D.SRT', '/Volumes/Hublot24/Share_hublot/Data/0223/Drones/Bernache/30-doc_004/DJI_20240223153445_0590_D.SRT', '/Volumes/Hublot24/Share_hublot/Data/0223/Drones/Bernache/02-waves_002/DJI_20240223114332_0807_D.SRT', '/Volumes/Hublot24/Share_hublot/Data/0223/Drones/Bernache/03-waves_003/DJI_20240223114602_0808_D.SRT', '/Volumes/Hublot24/Share_hublot/Data/0223/Drones/Bernache/04-waves_004/DJI_20240223115002_0809_D.SRT', '/Volumes/Hublot24/Share_hublot/Data/0223/Drones/Bernache/05-waves_005/DJI_20240223115009_0810_D.SRT', '/Volumes/Hublot24/Share_hublot/Data/0223/Drones/Bernache/06-waves_006/DJI_20240223115412_0811_D.SRT', '/Volumes/Hublot24/Share_hublot/Data/0223/Drones/Bernache/07-waves_007/DJI_20240223120244_0813_D.SRT', '/Volumes/Hublot24/Share_hublot/Data/0223/Drones/Bernache/07-waves_007/DJI_20240223115857_0812_D.SRT', '/Volumes/Hublot24/Share_hublot/Data/0223/Drones/Bernache/08-waves_008/DJI_20240223120934_0814_D.SRT', '/Volumes/Hublot24/Share_hublot/Data/0223/Drones/Bernache/09-waves_009/DJI_20240223121315_0815_D.SRT', '/Volumes/Hublot24/Share_hublot/Data/0223/Drones/Bernache/11-doc_001/DJI_20240223123014_0902_D.SRT', '/Volumes/Hublot24/Share_hublot/Data/0223/Drones/Bernache/11-doc_001/DJI_20240223122627_0901_D.SRT', '/Volumes/Hublot24/Share_hublot/Data/0223/Drones/Bernache/12-waves_010/DJI_20240223123353_0903_D.SRT', '/Volumes/Hublot24/Share_hublot/Data/0223/Drones/Bernache/13-doc_002/DJI_20240223124512_0906_D.SRT', '/Volumes/Hublot24/Share_hublot/Data/0223/Drones/Bernache/13-doc_002/DJI_20240223123806_0904_D.SRT', '/Volumes/Hublot24/Share_hublot/Data/0223/Drones/Bernache/13-doc_002/DJI_20240223124125_0905_D.SRT', '/Volumes/Hublot24/Share_hublot/Data/0223/Drones/Bernache/01-waves_001/DJI_20240223113824_0806_D.SRT']
# []
# No data for Fulmar on 0223
# 0 /Volumes/Hublot24/Share_hublot/Data/0223/Drones/mesange/04-waves_001/DJI_20240223172423_0469_D.SRT
# number of records : 5418
# 1 /Volumes/Hublot24/Share_hublot/Data/0223/Drones/mesange/05-doc_003/DJI_20240223172840_0470_D.SRT
# number of records : 803
# 2 /Volumes/Hublot24/Share_hublot/Data/0223/Drones/mesange/06-waves_002/DJI_20240223172954_0471_D.SRT
# number of records : 5422
# 3 /Volumes/Hublot24/Share_hublot/Data/0223/Drones/mesange/07-frac+waves_001/DJI_20240223173504_0473_D.SRT
# number of records : 5537
# 4 /Volumes/Hublot24/Share_hublot/Data/0223/Drones/mesange/08-waves_003/DJI_20240223173846_0474_D.SRT
# number of records : 5666
# 5 /Volumes/Hublot24/Share_hublot/Data/0223/Drones/mesange/10-rheo+waves_001/DJI_20240223174526_0477_D.SRT
# number of records : 6803
# 6 /Volumes/Hublot24/Share_hublot/Data/0223/Drones/mesange/10-rheo+waves_001/DJI_20240223174913_0478_D.SRT
# number of records : 966
# 7 /Volumes/Hublot24/Share_hublot/Data/0223/Drones/mesange/11-ortho_002/DJI_20240223175144_0552_D.SRT
# number of records : 260
# 8 /Volumes/Hublot24/Share_hublot/Data/0223/Drones/mesange/12-waves_004/DJI_20240223175826_0785_D.SRT
# number of records : 5472
# 9 /Volumes/Hublot24/Share_hublot/Data/0223/Drones/mesange/13-waves_005/DJI_20240223180617_0787_D.SRT
# number of records : 588
# 10 /Volumes/Hublot24/Share_hublot/Data/0223/Drones/mesange/13-waves_005/DJI_20240223180230_0786_D.SRT
# number of records : 6803
# 11 /Volumes/Hublot24/Share_hublot/Data/0223/Drones/mesange/14-waves_006/DJI_20240223180737_0789_D.SRT
# number of records : 6734
# 12 /Volumes/Hublot24/Share_hublot/Data/0223/Drones/mesange/17-waves_007/DJI_20240223181757_0948_D.SRT
# number of records : 798
# 13 /Volumes/Hublot24/Share_hublot/Data/0223/Drones/mesange/18-waves_008/DJI_20240223182218_0950_D.SRT
# number of records : 646
# 14 /Volumes/Hublot24/Share_hublot/Data/0223/Drones/mesange/18-waves_008/DJI_20240223181831_0949_D.SRT
# number of records : 6802
# 15 /Volumes/Hublot24/Share_hublot/Data/0223/Drones/mesange/19-canot_001/DJI_20240223182247_0951_D.SRT
# number of records : 2815
# 16 /Volumes/Hublot24/Share_hublot/Data/0223/Drones/mesange/20-frac+waves_002/DJI_20240223182550_0952_D.SRT
# number of records : 2616
# 17 /Volumes/Hublot24/Share_hublot/Data/0223/Drones/mesange/21-waves_009/DJI_20240223182831_0954_D.SRT
# number of records : 5457
# 18 /Volumes/Hublot24/Share_hublot/Data/0223/Drones/mesange/23_waves_010/DJI_20240223183314_0957_D.SRT
# number of records : 6726
# 19 /Volumes/Hublot24/Share_hublot/Data/0223/Drones/mesange/24-doc_005/DJI_20240223183725_0958_D.SRT
# number of records : 43
# 20 /Volumes/Hublot24/Share_hublot/Data/0223/Drones/mesange/25-doc_006/DJI_20240223183735_0959_D.SRT
# number of records : 2473
# 21 /Volumes/Hublot24/Share_hublot/Data/0223/Drones/mesange/27-doc_007/DJI_20240223184032_0007_D.SRT
# number of records : 1388
# 22 /Volumes/Hublot24/Share_hublot/Data/0223/Drones/mesange/28-waves_011/DJI_20240223185105_0242_D.SRT
# number of records : 6286
# 23 /Volumes/Hublot24/Share_hublot/Data/0223/Drones/mesange/29-waves_012/DJI_20240223185630_0244_D.SRT
# number of records : 6802
# 24 /Volumes/Hublot24/Share_hublot/Data/0223/Drones/mesange/30-rheo+waves_002/DJI_20240223190117_0246_D.SRT
# number of records : 6802
# 25 /Volumes/Hublot24/Share_hublot/Data/0223/Drones/mesange/32-canot-002/DJI_20240223193826_0315_D.SRT
# number of records : 962
# 26 /Volumes/Hublot24/Share_hublot/Data/0223/Drones/mesange/34-waves_013/DJI_20240223194021_0316_D.SRT
# number of records : 4034
# 27 /Volumes/Hublot24/Share_hublot/Data/0223/Drones/mesange/35-waves_014/DJI_20240223194842_0318_D.SRT
# number of records : 292
# 28 /Volumes/Hublot24/Share_hublot/Data/0223/Drones/mesange/35-waves_014/DJI_20240223194455_0317_D.SRT
# number of records : 6802
# 29 /Volumes/Hublot24/Share_hublot/Data/0223/Drones/mesange/37-waves_015/DJI_20240223195200_0393_D.SRT
# number of records : 3452
# 30 /Volumes/Hublot24/Share_hublot/Data/0223/Drones/mesange/39-waves_016/DJI_20240223200958_0396_D.SRT
# number of records : 3180
# 31 /Volumes/Hublot24/Share_hublot/Data/0223/Drones/mesange/40-waves_017/DJI_20240223201247_0397_D.SRT
# number of records : 739
# 32 /Volumes/Hublot24/Share_hublot/Data/0223/Drones/mesange/41-waves_018/DJI_20240223201328_0398_D.SRT
# number of records : 5414
# 33 /Volumes/Hublot24/Share_hublot/Data/0223/Drones/mesange/42-waves_019/DJI_20240223201658_0399_D.SRT
# number of records : 5431
# 0 /Volumes/Hublot24/Share_hublot/Data/0223/Drones/Bernache/16-waves_011/DJI_20240223125950_0097_D.SRT
# number of records : 6614
# 1 /Volumes/Hublot24/Share_hublot/Data/0223/Drones/Bernache/17-waves_012/DJI_20240223130751_0099_D.SRT
# number of records : 715
# 2 /Volumes/Hublot24/Share_hublot/Data/0223/Drones/Bernache/17-waves_012/DJI_20240223130403_0098_D.SRT
# number of records : 6802
# 3 /Volumes/Hublot24/Share_hublot/Data/0223/Drones/Bernache/18-doc_002/DJI_20240223130816_0100_D.SRT
# number of records : 6294
# 4 /Volumes/Hublot24/Share_hublot/Data/0223/Drones/Bernache/20-waves_013/DJI_20240223131939_0141_D.SRT
# number of records : 6224
# 5 /Volumes/Hublot24/Share_hublot/Data/0223/Drones/Bernache/21-waves_014/DJI_20240223133416_0142_D.SRT
# number of records : 5421
# 6 /Volumes/Hublot24/Share_hublot/Data/0223/Drones/Bernache/22-waves_015/DJI_20240223134119_0144_D.SRT
# number of records : 1310
# 7 /Volumes/Hublot24/Share_hublot/Data/0223/Drones/Bernache/22-waves_015/DJI_20240223133732_0143_D.SRT
# number of records : 6803
# 8 /Volumes/Hublot24/Share_hublot/Data/0223/Drones/Bernache/23-doc_003/DJI_20240223134220_0145_D.SRT
# number of records : 3342
# 9 /Volumes/Hublot24/Share_hublot/Data/0223/Drones/Bernache/25-waves_016/DJI_20240223143438_0480_D.SRT
# number of records : 823
# 10 /Volumes/Hublot24/Share_hublot/Data/0223/Drones/Bernache/26-diamand_001/DJI_20240223143520_0481_D.SRT
# number of records : 250
# 11 /Volumes/Hublot24/Share_hublot/Data/0223/Drones/Bernache/27-ice_001/DJI_20240223143919_0483_D.SRT
# number of records : 420
# 12 /Volumes/Hublot24/Share_hublot/Data/0223/Drones/Bernache/27-ice_001/DJI_20240223143532_0482_D.SRT
# number of records : 6802
# 13 /Volumes/Hublot24/Share_hublot/Data/0223/Drones/Bernache/28-waves_017/DJI_20240223144023_0484_D.SRT
# number of records : 5419
# 14 /Volumes/Hublot24/Share_hublot/Data/0223/Drones/Bernache/30-doc_004/DJI_20240223153445_0590_D.SRT
# number of records : 1656
# 15 /Volumes/Hublot24/Share_hublot/Data/0223/Drones/Bernache/02-waves_002/DJI_20240223114332_0807_D.SRT
# number of records : 2723
# 16 /Volumes/Hublot24/Share_hublot/Data/0223/Drones/Bernache/03-waves_003/DJI_20240223114602_0808_D.SRT
# number of records : 4911
# 17 /Volumes/Hublot24/Share_hublot/Data/0223/Drones/Bernache/04-waves_004/DJI_20240223115002_0809_D.SRT
# number of records : 66
# 18 /Volumes/Hublot24/Share_hublot/Data/0223/Drones/Bernache/05-waves_005/DJI_20240223115009_0810_D.SRT
# number of records : 6024
# 19 /Volumes/Hublot24/Share_hublot/Data/0223/Drones/Bernache/06-waves_006/DJI_20240223115412_0811_D.SRT
# number of records : 6324
# 20 /Volumes/Hublot24/Share_hublot/Data/0223/Drones/Bernache/07-waves_007/DJI_20240223120244_0813_D.SRT
# number of records : 1762
# 21 /Volumes/Hublot24/Share_hublot/Data/0223/Drones/Bernache/07-waves_007/DJI_20240223115857_0812_D.SRT
# number of records : 6802
# 22 /Volumes/Hublot24/Share_hublot/Data/0223/Drones/Bernache/08-waves_008/DJI_20240223120934_0814_D.SRT
# number of records : 5419
# 23 /Volumes/Hublot24/Share_hublot/Data/0223/Drones/Bernache/09-waves_009/DJI_20240223121315_0815_D.SRT
# number of records : 5422
# 24 /Volumes/Hublot24/Share_hublot/Data/0223/Drones/Bernache/11-doc_001/DJI_20240223123014_0902_D.SRT
# number of records : 4902
# 25 /Volumes/Hublot24/Share_hublot/Data/0223/Drones/Bernache/11-doc_001/DJI_20240223122627_0901_D.SRT
# number of records : 6803
# 26 /Volumes/Hublot24/Share_hublot/Data/0223/Drones/Bernache/12-waves_010/DJI_20240223123353_0903_D.SRT
# number of records : 5418
# 27 /Volumes/Hublot24/Share_hublot/Data/0223/Drones/Bernache/13-doc_002/DJI_20240223124512_0906_D.SRT
# number of records : 3999
# 28 /Volumes/Hublot24/Share_hublot/Data/0223/Drones/Bernache/13-doc_002/DJI_20240223123806_0904_D.SRT
# number of records : 1449
# 29 /Volumes/Hublot24/Share_hublot/Data/0223/Drones/Bernache/13-doc_002/DJI_20240223124125_0905_D.SRT
# number of records : 6803
# 30 /Volumes/Hublot24/Share_hublot/Data/0223/Drones/Bernache/01-waves_001/DJI_20240223113824_0806_D.SRT
# number of records : 5617

# %%
import icewave.field.phone as phone
date = '0223'
records_phones = phone.get_records(date)
# Out:
# /Volumes/Hublot24/Share_hublot/Data/0223/Telephones/Bic24_S02_2024_0223/averages_Summary.csv
# dict_keys(['Phone', 'ax_err', 'ax_w_mean', 'ax_high_mean', 'ax_trend_mean', 'ax_w_std', 'ax_high_std', 'ax_trend_std', 'ay_err', 'ay_w_mean', 'ay_high_mean', 'ay_trend_mean', 'ay_w_std', 'ay_high_std', 'ay_trend_std', 'az_err', 'az_w_mean', 'az_high_mean', 'az_trend_mean', 'az_w_std', 'az_high_std', 'az_trend_std', 'gx_err', 'gx_w_std', 'gx_high_std', 'gx_trend_std', 'gy_err', 'gy_w_std', 'gy_high_std', 'gy_trend_std', 'gz_err', 'gz_w_std', 'gz_high_std', 'gz_trend_std', 'mx_err', 'mx_w_mean', 'mx_high_mean', 'mx_trend_mean', 'mx_w_std', 'mx_high_std', 'mx_trend_std', 'my_err', 'my_w_mean', 'my_high_mean', 'my_trend_mean', 'my_w_std', 'my_high_std', 'my_trend_std', 'mz_err', 'mz_w_mean', 'mz_high_mean', 'mz_trend_mean', 'mz_w_std', 'mz_high_std', 'mz_trend_std', 'az_w_freq', 'elev_mean', 'elev_std', 'lat_mean', 'lat_std', 'lon_mean', 'lon_std', 'time_start', 'time_end'])
# dict_keys(['Phone', 'ax_err', 'ax_w_mean', 'ax_high_mean', 'ax_trend_mean', 'ax_w_std', 'ax_high_std', 'ax_trend_std', 'ay_err', 'ay_w_mean', 'ay_high_mean', 'ay_trend_mean', 'ay_w_std', 'ay_high_std', 'ay_trend_std', 'az_err', 'az_w_mean', 'az_high_mean', 'az_trend_mean', 'az_w_std', 'az_high_std', 'az_trend_std', 'gx_err', 'gx_w_std', 'gx_high_std', 'gx_trend_std', 'gy_err', 'gy_w_std', 'gy_high_std', 'gy_trend_std', 'gz_err', 'gz_w_std', 'gz_high_std', 'gz_trend_std', 'mx_err', 'mx_w_mean', 'mx_high_mean', 'mx_trend_mean', 'mx_w_std', 'mx_high_std', 'mx_trend_std', 'my_err', 'my_w_mean', 'my_high_mean', 'my_trend_mean', 'my_w_std', 'my_high_std', 'my_trend_std', 'mz_err', 'mz_w_mean', 'mz_high_mean', 'mz_trend_mean', 'mz_w_std', 'mz_high_std', 'mz_trend_std', 'az_w_freq', 'elev_mean', 'elev_std', 'lat_mean', 'lat_std', 'lon_mean', 'lon_std', 'time_start', 'time_end'])
# dict_keys(['Phone', 'ax_err', 'ax_w_mean', 'ax_high_mean', 'ax_trend_mean', 'ax_w_std', 'ax_high_std', 'ax_trend_std', 'ay_err', 'ay_w_mean', 'ay_high_mean', 'ay_trend_mean', 'ay_w_std', 'ay_high_std', 'ay_trend_std', 'az_err', 'az_w_mean', 'az_high_mean', 'az_trend_mean', 'az_w_std', 'az_high_std', 'az_trend_std', 'gx_err', 'gx_w_std', 'gx_high_std', 'gx_trend_std', 'gy_err', 'gy_w_std', 'gy_high_std', 'gy_trend_std', 'gz_err', 'gz_w_std', 'gz_high_std', 'gz_trend_std', 'mx_err', 'mx_w_mean', 'mx_high_mean', 'mx_trend_mean', 'mx_w_std', 'mx_high_std', 'mx_trend_std', 'my_err', 'my_w_mean', 'my_high_mean', 'my_trend_mean', 'my_w_std', 'my_high_std', 'my_trend_std', 'mz_err', 'mz_w_mean', 'mz_high_mean', 'mz_trend_mean', 'mz_w_std', 'mz_high_std', 'mz_trend_std', 'az_w_freq', 'elev_mean', 'elev_std', 'lat_mean', 'lat_std', 'lon_mean', 'lon_std', 'time_start', 'time_end'])
# dict_keys(['Phone', 'ax_err', 'ax_w_mean', 'ax_high_mean', 'ax_trend_mean', 'ax_w_std', 'ax_high_std', 'ax_trend_std', 'ay_err', 'ay_w_mean', 'ay_high_mean', 'ay_trend_mean', 'ay_w_std', 'ay_high_std', 'ay_trend_std', 'az_err', 'az_w_mean', 'az_high_mean', 'az_trend_mean', 'az_w_std', 'az_high_std', 'az_trend_std', 'gx_err', 'gx_w_std', 'gx_high_std', 'gx_trend_std', 'gy_err', 'gy_w_std', 'gy_high_std', 'gy_trend_std', 'gz_err', 'gz_w_std', 'gz_high_std', 'gz_trend_std', 'mx_err', 'mx_w_mean', 'mx_high_mean', 'mx_trend_mean', 'mx_w_std', 'mx_high_std', 'mx_trend_std', 'my_err', 'my_w_mean', 'my_high_mean', 'my_trend_mean', 'my_w_std', 'my_high_std', 'my_trend_std', 'mz_err', 'mz_w_mean', 'mz_high_mean', 'mz_trend_mean', 'mz_w_std', 'mz_high_std', 'mz_trend_std', 'az_w_freq', 'elev_mean', 'elev_std', 'lat_mean', 'lat_std', 'lon_mean', 'lon_std', 'time_start', 'time_end'])
# dict_keys(['Phone', 'ax_err', 'ax_w_mean', 'ax_high_mean', 'ax_trend_mean', 'ax_w_std', 'ax_high_std', 'ax_trend_std', 'ay_err', 'ay_w_mean', 'ay_high_mean', 'ay_trend_mean', 'ay_w_std', 'ay_high_std', 'ay_trend_std', 'az_err', 'az_w_mean', 'az_high_mean', 'az_trend_mean', 'az_w_std', 'az_high_std', 'az_trend_std', 'gx_err', 'gx_w_std', 'gx_high_std', 'gx_trend_std', 'gy_err', 'gy_w_std', 'gy_high_std', 'gy_trend_std', 'gz_err', 'gz_w_std', 'gz_high_std', 'gz_trend_std', 'mx_err', 'mx_w_mean', 'mx_high_mean', 'mx_trend_mean', 'mx_w_std', 'mx_high_std', 'mx_trend_std', 'my_err', 'my_w_mean', 'my_high_mean', 'my_trend_mean', 'my_w_std', 'my_high_std', 'my_trend_std', 'mz_err', 'mz_w_mean', 'mz_high_mean', 'mz_trend_mean', 'mz_w_std', 'mz_high_std', 'mz_trend_std', 'az_w_freq', 'elev_mean', 'elev_std', 'lat_mean', 'lat_std', 'lon_mean', 'lon_std', 'time_start', 'time_end'])
# dict_keys(['Phone', 'ax_err', 'ax_w_mean', 'ax_high_mean', 'ax_trend_mean', 'ax_w_std', 'ax_high_std', 'ax_trend_std', 'ay_err', 'ay_w_mean', 'ay_high_mean', 'ay_trend_mean', 'ay_w_std', 'ay_high_std', 'ay_trend_std', 'az_err', 'az_w_mean', 'az_high_mean', 'az_trend_mean', 'az_w_std', 'az_high_std', 'az_trend_std', 'gx_err', 'gx_w_std', 'gx_high_std', 'gx_trend_std', 'gy_err', 'gy_w_std', 'gy_high_std', 'gy_trend_std', 'gz_err', 'gz_w_std', 'gz_high_std', 'gz_trend_std', 'mx_err', 'mx_w_mean', 'mx_high_mean', 'mx_trend_mean', 'mx_w_std', 'mx_high_std', 'mx_trend_std', 'my_err', 'my_w_mean', 'my_high_mean', 'my_trend_mean', 'my_w_std', 'my_high_std', 'my_trend_std', 'mz_err', 'mz_w_mean', 'mz_high_mean', 'mz_trend_mean', 'mz_w_std', 'mz_high_std', 'mz_trend_std', 'az_w_freq', 'elev_mean', 'elev_std', 'lat_mean', 'lat_std', 'lon_mean', 'lon_std', 'time_start', 'time_end'])
# dict_keys(['Phone', 'ax_err', 'ax_w_mean', 'ax_high_mean', 'ax_trend_mean', 'ax_w_std', 'ax_high_std', 'ax_trend_std', 'ay_err', 'ay_w_mean', 'ay_high_mean', 'ay_trend_mean', 'ay_w_std', 'ay_high_std', 'ay_trend_std', 'az_err', 'az_w_mean', 'az_high_mean', 'az_trend_mean', 'az_w_std', 'az_high_std', 'az_trend_std', 'gx_err', 'gx_w_std', 'gx_high_std', 'gx_trend_std', 'gy_err', 'gy_w_std', 'gy_high_std', 'gy_trend_std', 'gz_err', 'gz_w_std', 'gz_high_std', 'gz_trend_std', 'mx_err', 'mx_w_mean', 'mx_high_mean', 'mx_trend_mean', 'mx_w_std', 'mx_high_std', 'mx_trend_std', 'my_err', 'my_w_mean', 'my_high_mean', 'my_trend_mean', 'my_w_std', 'my_high_std', 'my_trend_std', 'mz_err', 'mz_w_mean', 'mz_high_mean', 'mz_trend_mean', 'mz_w_std', 'mz_high_std', 'mz_trend_std', 'az_w_freq', 'elev_mean', 'elev_std', 'lat_mean', 'lat_std', 'lon_mean', 'lon_std', 'time_start', 'time_end'])
# dict_keys(['Phone', 'ax_err', 'ax_w_mean', 'ax_high_mean', 'ax_trend_mean', 'ax_w_std', 'ax_high_std', 'ax_trend_std', 'ay_err', 'ay_w_mean', 'ay_high_mean', 'ay_trend_mean', 'ay_w_std', 'ay_high_std', 'ay_trend_std', 'az_err', 'az_w_mean', 'az_high_mean', 'az_trend_mean', 'az_w_std', 'az_high_std', 'az_trend_std', 'gx_err', 'gx_w_std', 'gx_high_std', 'gx_trend_std', 'gy_err', 'gy_w_std', 'gy_high_std', 'gy_trend_std', 'gz_err', 'gz_w_std', 'gz_high_std', 'gz_trend_std', 'mx_err', 'mx_w_mean', 'mx_high_mean', 'mx_trend_mean', 'mx_w_std', 'mx_high_std', 'mx_trend_std', 'my_err', 'my_w_mean', 'my_high_mean', 'my_trend_mean', 'my_w_std', 'my_high_std', 'my_trend_std', 'mz_err', 'mz_w_mean', 'mz_high_mean', 'mz_trend_mean', 'mz_w_std', 'mz_high_std', 'mz_trend_std', 'az_w_freq', 'elev_mean', 'elev_std', 'lat_mean', 'lat_std', 'lon_mean', 'lon_std', 'time_start', 'time_end'])
# dict_keys(['Phone', 'ax_err', 'ax_w_mean', 'ax_high_mean', 'ax_trend_mean', 'ax_w_std', 'ax_high_std', 'ax_trend_std', 'ay_err', 'ay_w_mean', 'ay_high_mean', 'ay_trend_mean', 'ay_w_std', 'ay_high_std', 'ay_trend_std', 'az_err', 'az_w_mean', 'az_high_mean', 'az_trend_mean', 'az_w_std', 'az_high_std', 'az_trend_std', 'gx_err', 'gx_w_std', 'gx_high_std', 'gx_trend_std', 'gy_err', 'gy_w_std', 'gy_high_std', 'gy_trend_std', 'gz_err', 'gz_w_std', 'gz_high_std', 'gz_trend_std', 'mx_err', 'mx_w_mean', 'mx_high_mean', 'mx_trend_mean', 'mx_w_std', 'mx_high_std', 'mx_trend_std', 'my_err', 'my_w_mean', 'my_high_mean', 'my_trend_mean', 'my_w_std', 'my_high_std', 'my_trend_std', 'mz_err', 'mz_w_mean', 'mz_high_mean', 'mz_trend_mean', 'mz_w_std', 'mz_high_std', 'mz_trend_std', 'az_w_freq', 'elev_mean', 'elev_std', 'lat_mean', 'lat_std', 'lon_mean', 'lon_std', 'time_start', 'time_end'])
# dict_keys(['Phone', 'ax_err', 'ax_w_mean', 'ax_high_mean', 'ax_trend_mean', 'ax_w_std', 'ax_high_std', 'ax_trend_std', 'ay_err', 'ay_w_mean', 'ay_high_mean', 'ay_trend_mean', 'ay_w_std', 'ay_high_std', 'ay_trend_std', 'az_err', 'az_w_mean', 'az_high_mean', 'az_trend_mean', 'az_w_std', 'az_high_std', 'az_trend_std', 'gx_err', 'gx_w_std', 'gx_high_std', 'gx_trend_std', 'gy_err', 'gy_w_std', 'gy_high_std', 'gy_trend_std', 'gz_err', 'gz_w_std', 'gz_high_std', 'gz_trend_std', 'mx_err', 'mx_w_mean', 'mx_high_mean', 'mx_trend_mean', 'mx_w_std', 'mx_high_std', 'mx_trend_std', 'my_err', 'my_w_mean', 'my_high_mean', 'my_trend_mean', 'my_w_std', 'my_high_std', 'my_trend_std', 'mz_err', 'mz_w_mean', 'mz_high_mean', 'mz_trend_mean', 'mz_w_std', 'mz_high_std', 'mz_trend_std', 'az_w_freq', 'elev_mean', 'elev_std', 'lat_mean', 'lat_std', 'lon_mean', 'lon_std', 'time_start', 'time_end'])

# %%
import icewave.field.geophone as geo
records_geo = geo.get_records(date)
# Out:
# /Volumes/Hublot24/Share_hublot/Data/0223/Geophones/DigiSolo_4075.txt
# /Volumes/Hublot24/Share_hublot/Data/0223/Geophones/DigiSolo_4177.txt
# /Volumes/Hublot24/Share_hublot/Data/0223/Geophones/DigiSolo_4180.txt
# /Volumes/Hublot24/Share_hublot/Data/0223/Geophones/DigiSolo_4265.txt
# /Volumes/Hublot24/Share_hublot/Data/0223/Geophones/DigiSolo_4274.txt
# /Volumes/Hublot24/Share_hublot/Data/0223/Geophones/DigiSolo_4514.txt
# /Volumes/Hublot24/Share_hublot/Data/0223/Geophones/DigiSolo_4765.txt
# /Volumes/Hublot24/Share_hublot/Data/0223/Geophones/DigiSolo_5132.txt
# /Volumes/Hublot24/Share_hublot/Data/0223/Geophones/DigiSolo_5137.txt
# /Volumes/Hublot24/Share_hublot/Data/0223/Geophones/DigiSolo_5165.txt
# /Volumes/Hublot24/Share_hublot/Data/0223/Geophones/DigiSolo_5167.txt
# /Volumes/Hublot24/Share_hublot/Data/0223/Geophones/DigiSolo_5235.txt
# /Volumes/Hublot24/Share_hublot/Data/0223/Geophones/DigiSolo_5251.txt
# /Volumes/Hublot24/Share_hublot/Data/0223/Geophones/DigiSolo_5291.txt
# /Volumes/Hublot24/Share_hublot/Data/0223/Geophones/DigiSolo_5442.txt
# /Volumes/Hublot24/Share_hublot/Data/0223/Geophones/DigiSolo_5450.txt

# %%
records_geo['geophones'].keys()
# Out:
# dict_keys(['4075', '4177', '4180', '4265', '4274', '4514', '4765', '5132', '5137', '5165', '5167', '5235', '5251', '5291', '5442', '5450'])

# %%
records_geo['geophones']['4075'][14].keys()
# Out:
# dict_keys(['date', 'time', 'latitude', 'longitude'])

# %%
records_geo['geophones']['4075'][14].keys()

# %%
records_geo['geophones']['4075'][14]['longitude']
# Out:
# [-68.851119333,
#  -68.851119667,
#  -68.851122333,
#  -68.851118167,
#  -68.8511195,
#  -68.8511175,
#  -68.851118,
#  -68.851116167,
#  -68.8511085,
#  -68.851106333]

# %%
records_phones['phone'][0][0]['time']#.keys()
# Out:
# ['18:47:40', '19:38:08']

# %%
record_buoys.keys()
records_phones.keys()

record_buoys+records_phones
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[378], line 4
#       1 record_buoys.keys()
#       2 records_phones.keys()
# ----> 4 record_buoys+records_phones
#
# TypeError: unsupported operand type(s) for +: 'dict' and 'dict'

# %%
records_phones['phone'][0][0]['time']#.keys()
# Out:
# ['18:47:40', '19:38:08']

# %%
records_b = []
for i,srtfile in enumerate(srtfiles_bernache):
    print(i,srtfile)
    data = rw_data.read_csv(srtfile)
    record = get_flighrecord(data)
    records_b.append(record)
# Out:
# 0 /Volumes/Hublot24/Share_hublot/Data/0223/Drones/Bernache/16-waves_011/DJI_20240223125950_0097_D.SRT
# number of records : 6614
# 1 /Volumes/Hublot24/Share_hublot/Data/0223/Drones/Bernache/17-waves_012/DJI_20240223130751_0099_D.SRT
# number of records : 715
# 2 /Volumes/Hublot24/Share_hublot/Data/0223/Drones/Bernache/17-waves_012/DJI_20240223130403_0098_D.SRT
# number of records : 6802
# 3 /Volumes/Hublot24/Share_hublot/Data/0223/Drones/Bernache/18-doc_002/DJI_20240223130816_0100_D.SRT
# number of records : 6294
# 4 /Volumes/Hublot24/Share_hublot/Data/0223/Drones/Bernache/20-waves_013/DJI_20240223131939_0141_D.SRT
# number of records : 6224
# 5 /Volumes/Hublot24/Share_hublot/Data/0223/Drones/Bernache/21-waves_014/DJI_20240223133416_0142_D.SRT
# number of records : 5421
# 6 /Volumes/Hublot24/Share_hublot/Data/0223/Drones/Bernache/22-waves_015/DJI_20240223134119_0144_D.SRT
# number of records : 1310
# 7 /Volumes/Hublot24/Share_hublot/Data/0223/Drones/Bernache/22-waves_015/DJI_20240223133732_0143_D.SRT
# number of records : 6803
# 8 /Volumes/Hublot24/Share_hublot/Data/0223/Drones/Bernache/23-doc_003/DJI_20240223134220_0145_D.SRT
# number of records : 3342
# 9 /Volumes/Hublot24/Share_hublot/Data/0223/Drones/Bernache/25-waves_016/DJI_20240223143438_0480_D.SRT
# number of records : 823
# 10 /Volumes/Hublot24/Share_hublot/Data/0223/Drones/Bernache/26-diamand_001/DJI_20240223143520_0481_D.SRT
# number of records : 250
# 11 /Volumes/Hublot24/Share_hublot/Data/0223/Drones/Bernache/27-ice_001/DJI_20240223143919_0483_D.SRT
# number of records : 420
# 12 /Volumes/Hublot24/Share_hublot/Data/0223/Drones/Bernache/27-ice_001/DJI_20240223143532_0482_D.SRT
# number of records : 6802
# 13 /Volumes/Hublot24/Share_hublot/Data/0223/Drones/Bernache/28-waves_017/DJI_20240223144023_0484_D.SRT
# number of records : 5419
# 14 /Volumes/Hublot24/Share_hublot/Data/0223/Drones/Bernache/30-doc_004/DJI_20240223153445_0590_D.SRT
# number of records : 1656
# 15 /Volumes/Hublot24/Share_hublot/Data/0223/Drones/Bernache/02-waves_002/DJI_20240223114332_0807_D.SRT
# number of records : 2723
# 16 /Volumes/Hublot24/Share_hublot/Data/0223/Drones/Bernache/03-waves_003/DJI_20240223114602_0808_D.SRT
# number of records : 4911
# 17 /Volumes/Hublot24/Share_hublot/Data/0223/Drones/Bernache/04-waves_004/DJI_20240223115002_0809_D.SRT
# number of records : 66
# 18 /Volumes/Hublot24/Share_hublot/Data/0223/Drones/Bernache/05-waves_005/DJI_20240223115009_0810_D.SRT
# number of records : 6024
# 19 /Volumes/Hublot24/Share_hublot/Data/0223/Drones/Bernache/06-waves_006/DJI_20240223115412_0811_D.SRT
# number of records : 6324
# 20 /Volumes/Hublot24/Share_hublot/Data/0223/Drones/Bernache/07-waves_007/DJI_20240223120244_0813_D.SRT
# number of records : 1762
# 21 /Volumes/Hublot24/Share_hublot/Data/0223/Drones/Bernache/07-waves_007/DJI_20240223115857_0812_D.SRT
# number of records : 6802
# 22 /Volumes/Hublot24/Share_hublot/Data/0223/Drones/Bernache/08-waves_008/DJI_20240223120934_0814_D.SRT
# number of records : 5419
# 23 /Volumes/Hublot24/Share_hublot/Data/0223/Drones/Bernache/09-waves_009/DJI_20240223121315_0815_D.SRT
# number of records : 5422
# 24 /Volumes/Hublot24/Share_hublot/Data/0223/Drones/Bernache/11-doc_001/DJI_20240223123014_0902_D.SRT
# number of records : 4902
# 25 /Volumes/Hublot24/Share_hublot/Data/0223/Drones/Bernache/11-doc_001/DJI_20240223122627_0901_D.SRT
# number of records : 6803
# 26 /Volumes/Hublot24/Share_hublot/Data/0223/Drones/Bernache/12-waves_010/DJI_20240223123353_0903_D.SRT
# number of records : 5418
# 27 /Volumes/Hublot24/Share_hublot/Data/0223/Drones/Bernache/13-doc_002/DJI_20240223124512_0906_D.SRT
# number of records : 3999
# 28 /Volumes/Hublot24/Share_hublot/Data/0223/Drones/Bernache/13-doc_002/DJI_20240223123806_0904_D.SRT
# number of records : 1449
# 29 /Volumes/Hublot24/Share_hublot/Data/0223/Drones/Bernache/13-doc_002/DJI_20240223124125_0905_D.SRT
# number of records : 6803
# 30 /Volumes/Hublot24/Share_hublot/Data/0223/Drones/Bernache/01-waves_001/DJI_20240223113824_0806_D.SRT
# number of records : 5617

# %%
srtfile = srtfiles[0]
records_m = []
for i,srtfile in enumerate(srtfiles_mesange):
    print(i,srtfile)
    data = rw_data.read_csv(srtfile)
    record = get_flighrecord(data)
    records_m.append(record)
# Out:
# 0 /Volumes/Hublot24/Share_hublot/Data/0223/Drones/mesange/04-waves_001/DJI_20240223172423_0469_D.SRT
# number of records : 5418
# 1 /Volumes/Hublot24/Share_hublot/Data/0223/Drones/mesange/05-doc_003/DJI_20240223172840_0470_D.SRT
# number of records : 803
# 2 /Volumes/Hublot24/Share_hublot/Data/0223/Drones/mesange/06-waves_002/DJI_20240223172954_0471_D.SRT
# number of records : 5422
# 3 /Volumes/Hublot24/Share_hublot/Data/0223/Drones/mesange/07-frac+waves_001/DJI_20240223173504_0473_D.SRT
# number of records : 5537
# 4 /Volumes/Hublot24/Share_hublot/Data/0223/Drones/mesange/08-waves_003/DJI_20240223173846_0474_D.SRT
# number of records : 5666
# 5 /Volumes/Hublot24/Share_hublot/Data/0223/Drones/mesange/10-rheo+waves_001/DJI_20240223174526_0477_D.SRT
# number of records : 6803
# 6 /Volumes/Hublot24/Share_hublot/Data/0223/Drones/mesange/10-rheo+waves_001/DJI_20240223174913_0478_D.SRT
# number of records : 966
# 7 /Volumes/Hublot24/Share_hublot/Data/0223/Drones/mesange/11-ortho_002/DJI_20240223175144_0552_D.SRT
# number of records : 260
# 8 /Volumes/Hublot24/Share_hublot/Data/0223/Drones/mesange/12-waves_004/DJI_20240223175826_0785_D.SRT
# number of records : 5472
# 9 /Volumes/Hublot24/Share_hublot/Data/0223/Drones/mesange/13-waves_005/DJI_20240223180617_0787_D.SRT
# number of records : 588
# 10 /Volumes/Hublot24/Share_hublot/Data/0223/Drones/mesange/13-waves_005/DJI_20240223180230_0786_D.SRT
# number of records : 6803
# 11 /Volumes/Hublot24/Share_hublot/Data/0223/Drones/mesange/14-waves_006/DJI_20240223180737_0789_D.SRT
# number of records : 6734
# 12 /Volumes/Hublot24/Share_hublot/Data/0223/Drones/mesange/17-waves_007/DJI_20240223181757_0948_D.SRT
# number of records : 798
# 13 /Volumes/Hublot24/Share_hublot/Data/0223/Drones/mesange/18-waves_008/DJI_20240223182218_0950_D.SRT
# number of records : 646
# 14 /Volumes/Hublot24/Share_hublot/Data/0223/Drones/mesange/18-waves_008/DJI_20240223181831_0949_D.SRT
# number of records : 6802
# 15 /Volumes/Hublot24/Share_hublot/Data/0223/Drones/mesange/19-canot_001/DJI_20240223182247_0951_D.SRT
# number of records : 2815
# 16 /Volumes/Hublot24/Share_hublot/Data/0223/Drones/mesange/20-frac+waves_002/DJI_20240223182550_0952_D.SRT
# number of records : 2616
# 17 /Volumes/Hublot24/Share_hublot/Data/0223/Drones/mesange/21-waves_009/DJI_20240223182831_0954_D.SRT
# number of records : 5457
# 18 /Volumes/Hublot24/Share_hublot/Data/0223/Drones/mesange/23_waves_010/DJI_20240223183314_0957_D.SRT
# number of records : 6726
# 19 /Volumes/Hublot24/Share_hublot/Data/0223/Drones/mesange/24-doc_005/DJI_20240223183725_0958_D.SRT
# number of records : 43
# 20 /Volumes/Hublot24/Share_hublot/Data/0223/Drones/mesange/25-doc_006/DJI_20240223183735_0959_D.SRT
# number of records : 2473
# 21 /Volumes/Hublot24/Share_hublot/Data/0223/Drones/mesange/27-doc_007/DJI_20240223184032_0007_D.SRT
# number of records : 1388
# 22 /Volumes/Hublot24/Share_hublot/Data/0223/Drones/mesange/28-waves_011/DJI_20240223185105_0242_D.SRT
# number of records : 6286
# 23 /Volumes/Hublot24/Share_hublot/Data/0223/Drones/mesange/29-waves_012/DJI_20240223185630_0244_D.SRT
# number of records : 6802
# 24 /Volumes/Hublot24/Share_hublot/Data/0223/Drones/mesange/30-rheo+waves_002/DJI_20240223190117_0246_D.SRT
# number of records : 6802
# 25 /Volumes/Hublot24/Share_hublot/Data/0223/Drones/mesange/32-canot-002/DJI_20240223193826_0315_D.SRT
# number of records : 962
# 26 /Volumes/Hublot24/Share_hublot/Data/0223/Drones/mesange/34-waves_013/DJI_20240223194021_0316_D.SRT
# number of records : 4034
# 27 /Volumes/Hublot24/Share_hublot/Data/0223/Drones/mesange/35-waves_014/DJI_20240223194842_0318_D.SRT
# number of records : 292
# 28 /Volumes/Hublot24/Share_hublot/Data/0223/Drones/mesange/35-waves_014/DJI_20240223194455_0317_D.SRT
# number of records : 6802
# 29 /Volumes/Hublot24/Share_hublot/Data/0223/Drones/mesange/37-waves_015/DJI_20240223195200_0393_D.SRT
# number of records : 3452
# 30 /Volumes/Hublot24/Share_hublot/Data/0223/Drones/mesange/39-waves_016/DJI_20240223200958_0396_D.SRT
# number of records : 3180
# 31 /Volumes/Hublot24/Share_hublot/Data/0223/Drones/mesange/40-waves_017/DJI_20240223201247_0397_D.SRT
# number of records : 739
# 32 /Volumes/Hublot24/Share_hublot/Data/0223/Drones/mesange/41-waves_018/DJI_20240223201328_0398_D.SRT
# number of records : 5414
# 33 /Volumes/Hublot24/Share_hublot/Data/0223/Drones/mesange/42-waves_019/DJI_20240223201658_0399_D.SRT
# number of records : 5431

# %%
def convert(t):
    h,m,s = t.split(':')
    return int(h)*3600+int(m)*60+int(s)

# %%
fig = plt.figure(figsize=(20,15))
ax = fig.add_subplot(111)

import matplotlib.dates as mdates

b=0.2
for (record,name) in zip(records_b,srtfiles_bernache):
    try:
        title = name.split('/')[-2].split('-')[1]#.split('_')[0]
    except:
        title = name.split('/')[-2]

    times = [record[key]['time'] for key in record.keys()]
    x = [times[0],times[-1]]
    x = np.asarray([convert(x[0]),convert(x[1])])
    
    r=np.random.random()*b
    ax.plot(x/3600, [1+r,1+r],'ko-')
    #display_text(x,y,title,ax=ax)
    ax.text(x[0]/3600,1+0.01+r,title)
    #print(convert(x[0]))

for (record,name) in zip(records_m,srtfiles_mesange):
    try:
        title = name.split('/')[-2].split('-')[1]#.split('_')[0]
    except:
        title = name.split('/')[-2]

    times = [record[key]['time'] for key in record.keys()]
    x = [times[0],times[-1]]
    x = np.asarray([convert(x[0])-3600*6,convert(x[1])-3600*6])
    
    r=np.random.random()*b
    ax.plot(x/3600, [1+b+r,1+b+r],'bo-')
    ax.text(x[0]/3600,1+b+0.01+r,title)
    #print(convert(x[0]))
    
    
plt.ylim(0,2)
hours = [11,12,13,14,15,16]
ax.set_xticks(hours,[str(h)+':00' for h in hours])
#ax.xaxis.set_major_formatter(mdates.DateFormatter('%H:%M:%S'))
#ax.set_xlim(['11:30:00','15:00:00'])
#ax.xaxis.set_major_formatter(mdates.DateFormatter('%h-%m-%s'))
#fig.autofmt_xdate()

figs = graphes.legende('Local time','Instruments','')

# %%
date = '0223'
#srtfiles_bernache = glob.glob(base+date+'/Drones/Bernache/*/*.SRT')#/*/*.srt')

# %%
pprint(files_telephones)
data_phone = rw_data.read_csv(files_telephones[1])
# Out:
# ['/Volumes/Hublot24/Share_hublot/Data/0223/Telephones/Bic24_S02_2024_0223/_Summary.csv',
#  '/Volumes/Hublot24/Share_hublot/Data/0223/Telephones/Bic24_S02_2024_0223/averages_Summary.csv']

# %%
header = data_phone[0]
keys = header
phonedict = {}
for d in data_phone[1:]:
    phone = int(d[0])
    phonedict[phone]={}
    for i,key in enumerate(header):
        phonedict[phone][key]=d[i]

# %%
phonedict.keys()
# Out:
# dict_keys([0, 4, 6, 9, 11, 13, 16, 17, 18, 19])

# %%
pprint(phonedict[0].keys())
# Out:
# dict_keys(['Phone', 'ax_err', 'ax_w_mean', 'ax_high_mean', 'ax_trend_mean', 'ax_w_std', 'ax_high_std', 'ax_trend_std', 'ay_err', 'ay_w_mean', 'ay_high_mean', 'ay_trend_mean', 'ay_w_std', 'ay_high_std', 'ay_trend_std', 'az_err', 'az_w_mean', 'az_high_mean', 'az_trend_mean', 'az_w_std', 'az_high_std', 'az_trend_std', 'gx_err', 'gx_w_std', 'gx_high_std', 'gx_trend_std', 'gy_err', 'gy_w_std', 'gy_high_std', 'gy_trend_std', 'gz_err', 'gz_w_std', 'gz_high_std', 'gz_trend_std', 'mx_err', 'mx_w_mean', 'mx_high_mean', 'mx_trend_mean', 'mx_w_std', 'mx_high_std', 'mx_trend_std', 'my_err', 'my_w_mean', 'my_high_mean', 'my_trend_mean', 'my_w_std', 'my_high_std', 'my_trend_std', 'mz_err', 'mz_w_mean', 'mz_high_mean', 'mz_trend_mean', 'mz_w_std', 'mz_high_std', 'mz_trend_std', 'az_w_freq', 'elev_mean', 'elev_std', 'lat_mean', 'lat_std', 'lon_mean', 'lon_std', 'time_start', 'time_end'])

# %%
print(phonedict[0].keys())
for phone in phonedict.keys():
    print(phonedict[phone]['time_start'])#.keys())
    print(phonedict[phone]['time_end'])#.keys())
# Out:
# dict_keys(['Phone', 'ax_err', 'ax_w_mean', 'ax_high_mean', 'ax_trend_mean', 'ax_w_std', 'ax_high_std', 'ax_trend_std', 'ay_err', 'ay_w_mean', 'ay_high_mean', 'ay_trend_mean', 'ay_w_std', 'ay_high_std', 'ay_trend_std', 'az_err', 'az_w_mean', 'az_high_mean', 'az_trend_mean', 'az_w_std', 'az_high_std', 'az_trend_std', 'gx_err', 'gx_w_std', 'gx_high_std', 'gx_trend_std', 'gy_err', 'gy_w_std', 'gy_high_std', 'gy_trend_std', 'gz_err', 'gz_w_std', 'gz_high_std', 'gz_trend_std', 'mx_err', 'mx_w_mean', 'mx_high_mean', 'mx_trend_mean', 'mx_w_std', 'mx_high_std', 'mx_trend_std', 'my_err', 'my_w_mean', 'my_high_mean', 'my_trend_mean', 'my_w_std', 'my_high_std', 'my_trend_std', 'mz_err', 'mz_w_mean', 'mz_high_mean', 'mz_trend_mean', 'mz_w_std', 'mz_high_std', 'mz_trend_std', 'az_w_freq', 'elev_mean', 'elev_std', 'lat_mean', 'lat_std', 'lon_mean', 'lon_std', 'time_start', 'time_end'])
# 2024-02-23 18:47:40.664 UTC+01:00
# 2024-02-23 19:38:08.550 UTC+01:00
# 2024-02-23 18:47:43.879 UTC+01:00
# 2024-02-23 19:36:04.972 UTC+01:00
# 2024-02-23 18:47:37.071 UTC+01:00
# 2024-02-23 19:40:04.568 UTC+01:00
# 2024-02-23 18:47:41.818 UTC+01:00
# 2024-02-23 19:40:58.375 UTC+01:00
# 2024-02-23 18:47:27.191 UTC+01:00
# 2024-02-23 19:41:14.413 UTC+01:00
# 2022-04-22 05:57:50.172 UTC+02:00
# 2022-04-22 06:53:09.871 UTC+02:00
# 2024-02-23 18:47:15.440 UTC+01:00
# 2024-02-23 19:43:19.122 UTC+01:00
# 2024-02-23 18:47:12.592 UTC+01:00
# 2024-02-23 19:43:16.705 UTC+01:00
# 2022-04-22 06:05:16.297 UTC+02:00
# 2022-04-22 06:59:53.855 UTC+02:00
# 2024-02-23 18:47:36.092 UTC+01:00
# 2024-02-23 19:43:07.717 UTC+01:00

# %%
fig = plt.figure(figsize=(20,15))
ax = fig.add_subplot(111)

import matplotlib.dates as mdates

b=0.2
for (record,name) in zip(records_b,srtfiles_bernache):
    try:
        title = name.split('/')[-2].split('-')[1]#.split('_')[0]
    except:
        title = name.split('/')[-2]

    times = [record[key]['time'] for key in record.keys()]
    x = [times[0],times[-1]]
    x = np.asarray([convert(x[0]),convert(x[1])])
    
    r=np.random.random()*b
    ax.plot(x/3600, [1+r,1+r],'kp-')
    #display_text(x,y,title,ax=ax)
    ax.text(x[0]/3600,1+0.01+r,title)
    #print(convert(x[0]))

for (record,name) in zip(records_m,srtfiles_mesange):
    try:
        title = name.split('/')[-2].split('-')[1]#.split('_')[0]
    except:
        title = name.split('/')[-2]

    times = [record[key]['time'] for key in record.keys()]
    x = [times[0],times[-1]]
    x = np.asarray([convert(x[0])-3600*6,convert(x[1])-3600*6])
    
    r=np.random.random()*b
    ax.plot(x/3600, [1+b+r,1+b+r],'bp-')
    ax.text(x[0]/3600,1+b+0.01+r,title)
    #print(convert(x[0]))
    
X = {}
for i,phone in enumerate(phonedict.keys()):
    t0 = phonedict[phone]['time_start'].split(' ')[1][:-4]#.keys())
    t1 = phonedict[phone]['time_end'].split(' ')[1][:-4]
    print(t0,t1)
    X[i] = np.asarray([convert(t0)-3600*6,convert(t1)-3600*6])
    
    if X[i][0]/3600<11:
        X[i]=X[i-1]
    r=i*0.02#np.random.random()*b
    ax.plot(X[i]/3600, [1.5+r,1.5+r],'rs-')
    ax.text(X[i][0]/3600-0.1,1.5+r,str(phone))

#    ax.plot()
    #.keys())
    
plt.ylim(0,2)
hours = [11,12,13,14,15,16]
ax.set_xticks(hours,[str(h)+':00' for h in hours])
#ax.xaxis.set_major_formatter(mdates.DateFormatter('%H:%M:%S'))
#ax.set_xlim(['11:30:00','15:00:00'])
#ax.xaxis.set_major_formatter(mdates.DateFormatter('%h-%m-%s'))
#fig.autofmt_xdate()

figs = graphes.legende('Local time','Instruments',date)
# Out:
# 18:47:40 19:38:08
# 18:47:43 19:36:04
# 18:47:37 19:40:04
# 18:47:41 19:40:58
# 18:47:27 19:41:14
# 05:57:50 06:53:09
# 18:47:15 19:43:19
# 18:47:12 19:43:16
# 06:05:16 06:59:53
# 18:47:36 19:43:07

# %%
date = '0223'
files_geophones = glob.glob(base+date+'/Geophones/DigiSolo*.txt')#/*/*.srt')
#srtfiles_bernache = glob.glob(base+date+'/Drones/Bernache/*/*.SRT')#/*/*.srt')

# %%
def step2():
    return None
names = locals()['step2']
print(names)#.keys())
# Out:
# <function step2 at 0x13afc31a0>

# %%
pprint(files_geophones)
# Out:
# ['/Volumes/Hublot24/Share_hublot/Data/0223/Geophones/DigiSolo_4075.txt',
#  '/Volumes/Hublot24/Share_hublot/Data/0223/Geophones/DigiSolo_4177.txt',
#  '/Volumes/Hublot24/Share_hublot/Data/0223/Geophones/DigiSolo_4180.txt',
#  '/Volumes/Hublot24/Share_hublot/Data/0223/Geophones/DigiSolo_4265.txt',
#  '/Volumes/Hublot24/Share_hublot/Data/0223/Geophones/DigiSolo_4274.txt',
#  '/Volumes/Hublot24/Share_hublot/Data/0223/Geophones/DigiSolo_4514.txt',
#  '/Volumes/Hublot24/Share_hublot/Data/0223/Geophones/DigiSolo_4765.txt',
#  '/Volumes/Hublot24/Share_hublot/Data/0223/Geophones/DigiSolo_5132.txt',
#  '/Volumes/Hublot24/Share_hublot/Data/0223/Geophones/DigiSolo_5137.txt',
#  '/Volumes/Hublot24/Share_hublot/Data/0223/Geophones/DigiSolo_5165.txt',
#  '/Volumes/Hublot24/Share_hublot/Data/0223/Geophones/DigiSolo_5167.txt',
#  '/Volumes/Hublot24/Share_hublot/Data/0223/Geophones/DigiSolo_5235.txt',
#  '/Volumes/Hublot24/Share_hublot/Data/0223/Geophones/DigiSolo_5251.txt',
#  '/Volumes/Hublot24/Share_hublot/Data/0223/Geophones/DigiSolo_5291.txt',
#  '/Volumes/Hublot24/Share_hublot/Data/0223/Geophones/DigiSolo_5442.txt',
#  '/Volumes/Hublot24/Share_hublot/Data/0223/Geophones/DigiSolo_5450.txt']

# %%
geophones={}
for filename in files_geophones:
    num = filename.split('/DigiSolo_')[1].split('.txt')[0]
    print(num)
    geo = rw_data.read_csv(filename)
    geophones[num] = geo
# Out:
# 4075
# 4177
# 4180
# 4265
# 4274
# 4514
# 4765
# 5132
# 5137
# 5165
# 5167
# 5235
# 5251
# 5291
# 5442
# 5450

# %%
len(exemple_geophone)

records_geo={}

for num in geophones.keys():
    geo = geophones[num]
    records_geo[num]={}
    for i,line in enumerate(geo[:-1]):
       ##print(line)
        l = geo[i+1]
        if len(l)>0:
            if 'Serial Number' in l[0]:
                serial = l[0].split(' = ')[1]
                print(serial)
            if 'Start Acquisition FileName' in l[0]:
                print(l[0])
                rec = int(l[0].split('Seis')[1].split('.DLD')[0])
                print(i)
                print(rec,l)
                records_geo[num][rec]={}
                print(line)
                records_geo[num][rec]['date']=line[0].split('= "')[1]
                records_geo[num][rec]['times']=[line[1][:-1]]

            elif len(line)>0:
                if 'RTC Time' in line[0] or 'UTC Time' in line[0]:
                    records_geo[num][rec]['times'].append(line[1][:-1])
# Out:
# 453024075
# 453024075
# Start Acquisition FileName = "Seis000.DLD"
# 133
# 0 ['Start Acquisition FileName = "Seis000.DLD"']
# ['UTC Time = "2024/02/09', '20:47:33"']
# 453024075
# 453024075
# Start Acquisition FileName = "Seis001.DLD"
# 291
# 1 ['Start Acquisition FileName = "Seis001.DLD"']
# ['UTC Time = "2024/02/10', '12:42:00"']
# 453024075
# Start Acquisition FileName = "Seis002.DLD"
# 391
# 2 ['Start Acquisition FileName = "Seis002.DLD"']
# ['UTC Time = "2024/02/10', '13:05:50"']
# 453024075
# Start Acquisition FileName = "Seis003.DLD"
# 511
# 3 ['Start Acquisition FileName = "Seis003.DLD"']
# ['UTC Time = "2024/02/10', '13:33:34"']
# 453024075
# Start Acquisition FileName = "Seis004.DLD"
# 655
# 4 ['Start Acquisition FileName = "Seis004.DLD"']
# ['UTC Time = "2024/02/10', '14:22:34"']
# 453024075
# 453024075
# Start Acquisition FileName = "Seis005.DLD"
# 910
# 5 ['Start Acquisition FileName = "Seis005.DLD"']
# ['UTC Time = "2024/02/11', '18:43:33"']
# 453024075
# Start Acquisition FileName = "Seis006.DLD"
# 986
# 6 ['Start Acquisition FileName = "Seis006.DLD"']
# ['UTC Time = "2024/02/11', '18:54:21"']
# 453024075
# Start Acquisition FileName = "Seis007.DLD"
# 1062
# 7 ['Start Acquisition FileName = "Seis007.DLD"']
# ['UTC Time = "2024/02/11', '19:08:21"']
# 453024075
# Start Acquisition FileName = "Seis008.DLD"
# 1161
# 8 ['Start Acquisition FileName = "Seis008.DLD"']
# ['UTC Time = "2024/02/11', '19:23:06"']
# 453024075
# Start Acquisition FileName = "Seis009.DLD"
# 1285
# 9 ['Start Acquisition FileName = "Seis009.DLD"']
# ['UTC Time = "2024/02/11', '20:03:41"']
# 453024075
# 453024075
# Start Acquisition FileName = "Seis010.DLD"
# 1540
# 10 ['Start Acquisition FileName = "Seis010.DLD"']
# ['UTC Time = "2024/02/21', '17:24:03"']
# 453024075
# Start Acquisition FileName = "Seis011.DLD"
# 1712
# 11 ['Start Acquisition FileName = "Seis011.DLD"']
# ['UTC Time = "2024/02/21', '18:04:36"']
# 453024075
# Start Acquisition FileName = "Seis012.DLD"
# 1808
# 12 ['Start Acquisition FileName = "Seis012.DLD"']
# ['UTC Time = "2024/02/21', '18:21:02"']
# 453024075
# Start Acquisition FileName = "Seis013.DLD"
# 1932
# 13 ['Start Acquisition FileName = "Seis013.DLD"']
# ['UTC Time = "2024/02/21', '19:27:27"']
# 453024075
# 453024075
# Start Acquisition FileName = "Seis014.DLD"
# 2370
# 14 ['Start Acquisition FileName = "Seis014.DLD"']
# ['UTC Time = "2024/02/23', '17:28:07"']
# 453024075
# Start Acquisition FileName = "Seis015.DLD"
# 2692
# 15 ['Start Acquisition FileName = "Seis015.DLD"']
# ['UTC Time = "2024/02/23', '19:01:52"']
# 453024177
# 453024177
# Start Acquisition FileName = "Seis000.DLD"
# 134
# 0 ['Start Acquisition FileName = "Seis000.DLD"']
# ['UTC Time = "2024/02/09', '20:46:38"']
# 453024177
# 453024177
# Start Acquisition FileName = "Seis001.DLD"
# 296
# 1 ['Start Acquisition FileName = "Seis001.DLD"']
# ['UTC Time = "2024/02/10', '12:35:00"']
# 453024177
# Start Acquisition FileName = "Seis002.DLD"
# 420
# 2 ['Start Acquisition FileName = "Seis002.DLD"']
# ['UTC Time = "2024/02/10', '12:59:18"']
# 453024177
# Start Acquisition FileName = "Seis003.DLD"
# 544
# 3 ['Start Acquisition FileName = "Seis003.DLD"']
# ['UTC Time = "2024/02/10', '13:32:35"']
# 453024177
# Start Acquisition FileName = "Seis004.DLD"
# 668
# 4 ['Start Acquisition FileName = "Seis004.DLD"']
# ['UTC Time = "2024/02/10', '14:16:33"']
# 453024177
# 453024177
# Start Acquisition FileName = "Seis005.DLD"
# 953
# 5 ['Start Acquisition FileName = "Seis005.DLD"']
# ['UTC Time = "2024/02/11', '18:42:00"']
# 453024177
# Start Acquisition FileName = "Seis006.DLD"
# 1049
# 6 ['Start Acquisition FileName = "Seis006.DLD"']
# ['UTC Time = "2024/02/11', '18:53:39"']
# 453024177
# Start Acquisition FileName = "Seis007.DLD"
# 1145
# 7 ['Start Acquisition FileName = "Seis007.DLD"']
# ['UTC Time = "2024/02/11', '19:06:34"']
# 453024177
# Start Acquisition FileName = "Seis008.DLD"
# 1245
# 8 ['Start Acquisition FileName = "Seis008.DLD"']
# ['UTC Time = "2024/02/11', '19:20:24"']
# 453024177
# Start Acquisition FileName = "Seis009.DLD"
# 1389
# 9 ['Start Acquisition FileName = "Seis009.DLD"']
# ['UTC Time = "2024/02/11', '20:00:30"']
# 453024177
# 453024177
# Start Acquisition FileName = "Seis010.DLD"
# 1644
# 10 ['Start Acquisition FileName = "Seis010.DLD"']
# ['UTC Time = "2024/02/21', '17:26:33"']
# 453024177
# Start Acquisition FileName = "Seis011.DLD"
# 1796
# 11 ['Start Acquisition FileName = "Seis011.DLD"']
# ['UTC Time = "2024/02/21', '18:02:25"']
# 453024177
# Start Acquisition FileName = "Seis012.DLD"
# 1896
# 12 ['Start Acquisition FileName = "Seis012.DLD"']
# ['UTC Time = "2024/02/21', '18:18:08"']
# 453024177
# Start Acquisition FileName = "Seis013.DLD"
# 2041
# 13 ['Start Acquisition FileName = "Seis013.DLD"']
# ['UTC Time = "2024/02/21', '19:39:03"']
# 453024177
# 453024177
# Start Acquisition FileName = "Seis014.DLD"
# 2453
# 14 ['Start Acquisition FileName = "Seis014.DLD"']
# ['UTC Time = "2024/02/23', '17:26:00"']
# 453024177
# Start Acquisition FileName = "Seis015.DLD"
# 2775
# 15 ['Start Acquisition FileName = "Seis015.DLD"']
# ['UTC Time = "2024/02/23', '19:00:31"']
# 453024180
# 453024180
# Start Acquisition FileName = "Seis000.DLD"
# 134
# 0 ['Start Acquisition FileName = "Seis000.DLD"']
# ['UTC Time = "2024/02/09', '20:47:42"']
# 453024180
# 453024180
# Start Acquisition FileName = "Seis001.DLD"
# 293
# 1 ['Start Acquisition FileName = "Seis001.DLD"']
# ['UTC Time = "2024/02/10', '12:44:33"']
# 453024180
# Start Acquisition FileName = "Seis002.DLD"
# 393
# 2 ['Start Acquisition FileName = "Seis002.DLD"']
# ['UTC Time = "2024/02/10', '13:05:27"']
# 453024180
# Start Acquisition FileName = "Seis003.DLD"
# 513
# 3 ['Start Acquisition FileName = "Seis003.DLD"']
# ['UTC Time = "2024/02/10', '13:32:45"']
# 453024180
# Start Acquisition FileName = "Seis004.DLD"
# 657
# 4 ['Start Acquisition FileName = "Seis004.DLD"']
# ['UTC Time = "2024/02/10', '14:16:18"']
# 453024180
# 453024180
# Start Acquisition FileName = "Seis005.DLD"
# 942
# 5 ['Start Acquisition FileName = "Seis005.DLD"']
# ['UTC Time = "2024/02/11', '18:43:21"']
# 453024180
# Start Acquisition FileName = "Seis006.DLD"
# 1018
# 6 ['Start Acquisition FileName = "Seis006.DLD"']
# ['UTC Time = "2024/02/11', '18:54:50"']
# 453024180
# Start Acquisition FileName = "Seis007.DLD"
# 1094
# 7 ['Start Acquisition FileName = "Seis007.DLD"']
# ['UTC Time = "2024/02/11', '19:09:15"']
# 453024180
# Start Acquisition FileName = "Seis008.DLD"
# 1170
# 8 ['Start Acquisition FileName = "Seis008.DLD"']
# ['UTC Time = "2024/02/11', '20:08:10"']
# 453024180
# 453024180
# Start Acquisition FileName = "Seis009.DLD"
# 1381
# 9 ['Start Acquisition FileName = "Seis009.DLD"']
# ['UTC Time = "2024/02/21', '17:24:03"']
# 453024180
# Start Acquisition FileName = "Seis010.DLD"
# 1553
# 10 ['Start Acquisition FileName = "Seis010.DLD"']
# ['UTC Time = "2024/02/21', '18:04:59"']
# 453024180
# Start Acquisition FileName = "Seis011.DLD"
# 1629
# 11 ['Start Acquisition FileName = "Seis011.DLD"']
# ['UTC Time = "2024/02/21', '18:19:33"']
# 453024180
# Start Acquisition FileName = "Seis012.DLD"
# 1753
# 12 ['Start Acquisition FileName = "Seis012.DLD"']
# ['UTC Time = "2024/02/21', '19:20:30"']
# 453024180
# 453024180
# Start Acquisition FileName = "Seis013.DLD"
# 2215
# 13 ['Start Acquisition FileName = "Seis013.DLD"']
# ['UTC Time = "2024/02/23', '17:29:27"']
# 453024180
# Start Acquisition FileName = "Seis014.DLD"
# 2537
# 14 ['Start Acquisition FileName = "Seis014.DLD"']
# ['UTC Time = "2024/02/23', '19:07:46"']
# 453024265
# 453024265
# Start Acquisition FileName = "Seis000.DLD"
# 134
# 0 ['Start Acquisition FileName = "Seis000.DLD"']
# ['UTC Time = "2024/02/09', '20:47:31"']
# 453024265
# 453024265
# Start Acquisition FileName = "Seis001.DLD"
# 293
# 1 ['Start Acquisition FileName = "Seis001.DLD"']
# ['UTC Time = "2024/02/10', '12:39:45"']
# 453024265
# Start Acquisition FileName = "Seis002.DLD"
# 413
# 2 ['Start Acquisition FileName = "Seis002.DLD"']
# ['UTC Time = "2024/02/10', '13:01:41"']
# 453024265
# Start Acquisition FileName = "Seis003.DLD"
# 537
# 3 ['Start Acquisition FileName = "Seis003.DLD"']
# ['UTC Time = "2024/02/10', '13:33:21"']
# 453024265
# Start Acquisition FileName = "Seis004.DLD"
# 681
# 4 ['Start Acquisition FileName = "Seis004.DLD"']
# ['UTC Time = "2024/02/10', '14:19:51"']
# 453024265
# 453024265
# Start Acquisition FileName = "Seis005.DLD"
# 966
# 5 ['Start Acquisition FileName = "Seis005.DLD"']
# ['UTC Time = "2024/02/11', '18:43:45"']
# 453024265
# Start Acquisition FileName = "Seis006.DLD"
# 1042
# 6 ['Start Acquisition FileName = "Seis006.DLD"']
# ['UTC Time = "2024/02/11', '18:54:15"']
# 453024265
# Start Acquisition FileName = "Seis007.DLD"
# 1118
# 7 ['Start Acquisition FileName = "Seis007.DLD"']
# ['UTC Time = "2024/02/11', '19:06:54"']
# 453024265
# Start Acquisition FileName = "Seis008.DLD"
# 1221
# 8 ['Start Acquisition FileName = "Seis008.DLD"']
# ['UTC Time = "2024/02/11', '19:21:22"']
# 453024265
# Start Acquisition FileName = "Seis009.DLD"
# 1365
# 9 ['Start Acquisition FileName = "Seis009.DLD"']
# ['UTC Time = "2024/02/11', '20:02:27"']
# 453024265
# 453024265
# Start Acquisition FileName = "Seis010.DLD"
# 1620
# 10 ['Start Acquisition FileName = "Seis010.DLD"']
# ['UTC Time = "2024/02/21', '17:24:13"']
# 453024265
# Start Acquisition FileName = "Seis011.DLD"
# 1792
# 11 ['Start Acquisition FileName = "Seis011.DLD"']
# ['UTC Time = "2024/02/21', '18:04:03"']
# 453024265
# Start Acquisition FileName = "Seis012.DLD"
# 1888
# 12 ['Start Acquisition FileName = "Seis012.DLD"']
# ['UTC Time = "2024/02/21', '18:20:55"']
# 453024265
# Start Acquisition FileName = "Seis013.DLD"
# 2012
# 13 ['Start Acquisition FileName = "Seis013.DLD"']
# ['UTC Time = "2024/02/21', '19:32:29"']
# 453024265
# 453024265
# Start Acquisition FileName = "Seis014.DLD"
# 2450
# 14 ['Start Acquisition FileName = "Seis014.DLD"']
# ['UTC Time = "2024/02/23', '17:27:10"']
# 453024265
# Start Acquisition FileName = "Seis015.DLD"
# 2772
# 15 ['Start Acquisition FileName = "Seis015.DLD"']
# ['UTC Time = "2024/02/23', '19:03:09"']
# 453024274
# 453024274
# Start Acquisition FileName = "Seis000.DLD"
# 134
# 0 ['Start Acquisition FileName = "Seis000.DLD"']
# ['UTC Time = "2024/02/09', '20:47:45"']
# 453024274
# 453024274
# Start Acquisition FileName = "Seis001.DLD"
# 293
# 1 ['Start Acquisition FileName = "Seis001.DLD"']
# ['UTC Time = "2024/02/10', '12:45:03"']
# 453024274
# Start Acquisition FileName = "Seis002.DLD"
# 393
# 2 ['Start Acquisition FileName = "Seis002.DLD"']
# ['UTC Time = "2024/02/10', '13:05:18"']
# 453024274
# Start Acquisition FileName = "Seis003.DLD"
# 513
# 3 ['Start Acquisition FileName = "Seis003.DLD"']
# ['UTC Time = "2024/02/10', '13:32:41"']
# 453024274
# Start Acquisition FileName = "Seis004.DLD"
# 661
# 4 ['Start Acquisition FileName = "Seis004.DLD"']
# ['UTC Time = "2024/02/10', '14:22:59"']
# 453024274
# 453024274
# Start Acquisition FileName = "Seis005.DLD"
# 916
# 5 ['Start Acquisition FileName = "Seis005.DLD"']
# ['UTC Time = "2024/02/11', '18:43:22"']
# 453024274
# Start Acquisition FileName = "Seis006.DLD"
# 992
# 6 ['Start Acquisition FileName = "Seis006.DLD"']
# ['UTC Time = "2024/02/11', '18:54:58"']
# 453024274
# Start Acquisition FileName = "Seis007.DLD"
# 1071
# 7 ['Start Acquisition FileName = "Seis007.DLD"']
# ['UTC Time = "2024/02/11', '19:10:01"']
# 453024274
# Start Acquisition FileName = "Seis008.DLD"
# 1147
# 8 ['Start Acquisition FileName = "Seis008.DLD"']
# ['UTC Time = "2024/02/11', '20:01:43"']
# 453024274
# 453024274
# Start Acquisition FileName = "Seis009.DLD"
# 1379
# 9 ['Start Acquisition FileName = "Seis009.DLD"']
# ['UTC Time = "2024/02/21', '17:24:15"']
# 453024274
# Start Acquisition FileName = "Seis010.DLD"
# 1551
# 10 ['Start Acquisition FileName = "Seis010.DLD"']
# ['UTC Time = "2024/02/21', '18:05:24"']
# 453024274
# Start Acquisition FileName = "Seis011.DLD"
# 1627
# 11 ['Start Acquisition FileName = "Seis011.DLD"']
# ['UTC Time = "2024/02/21', '18:19:13"']
# 453024274
# Start Acquisition FileName = "Seis012.DLD"
# 1751
# 12 ['Start Acquisition FileName = "Seis012.DLD"']
# ['UTC Time = "2024/02/21', '19:18:01"']
# 453024274
# 453024274
# Start Acquisition FileName = "Seis013.DLD"
# 2213
# 13 ['Start Acquisition FileName = "Seis013.DLD"']
# ['UTC Time = "2024/02/23', '17:29:27"']
# 453024274
# Start Acquisition FileName = "Seis014.DLD"
# 2535
# 14 ['Start Acquisition FileName = "Seis014.DLD"']
# ['UTC Time = "2024/02/23', '19:07:09"']
# 453024514
# 453024514
# Start Acquisition FileName = "Seis000.DLD"
# 134
# 0 ['Start Acquisition FileName = "Seis000.DLD"']
# ['UTC Time = "2024/02/09', '20:47:13"']
# 453024514
# 453024514
# Start Acquisition FileName = "Seis001.DLD"
# 293
# 1 ['Start Acquisition FileName = "Seis001.DLD"']
# ['UTC Time = "2024/02/10', '12:37:36"']
# 453024514
# Start Acquisition FileName = "Seis002.DLD"
# 413
# 2 ['Start Acquisition FileName = "Seis002.DLD"']
# ['UTC Time = "2024/02/10', '13:05:56"']
# 453024514
# Start Acquisition FileName = "Seis003.DLD"
# 533
# 3 ['Start Acquisition FileName = "Seis003.DLD"']
# ['UTC Time = "2024/02/10', '13:33:15"']
# 453024514
# Start Acquisition FileName = "Seis004.DLD"
# 677
# 4 ['Start Acquisition FileName = "Seis004.DLD"']
# ['UTC Time = "2024/02/10', '14:15:50"']
# 453024514
# 453024514
# Start Acquisition FileName = "Seis005.DLD"
# 982
# 5 ['Start Acquisition FileName = "Seis005.DLD"']
# ['UTC Time = "2024/02/11', '18:44:12"']
# 453024514
# Start Acquisition FileName = "Seis006.DLD"
# 1058
# 6 ['Start Acquisition FileName = "Seis006.DLD"']
# ['UTC Time = "2024/02/11', '18:54:02"']
# 453024514
# Start Acquisition FileName = "Seis007.DLD"
# 1154
# 7 ['Start Acquisition FileName = "Seis007.DLD"']
# ['UTC Time = "2024/02/11', '19:06:06"']
# 453024514
# Start Acquisition FileName = "Seis008.DLD"
# 1254
# 8 ['Start Acquisition FileName = "Seis008.DLD"']
# ['UTC Time = "2024/02/11', '19:20:04"']
# 453024514
# Start Acquisition FileName = "Seis009.DLD"
# 1398
# 9 ['Start Acquisition FileName = "Seis009.DLD"']
# ['UTC Time = "2024/02/11', '19:59:02"']
# 453024514
# 453024514
# Start Acquisition FileName = "Seis010.DLD"
# 1653
# 10 ['Start Acquisition FileName = "Seis010.DLD"']
# ['UTC Time = "2024/02/21', '17:25:46"']
# 453024514
# Start Acquisition FileName = "Seis011.DLD"
# 1805
# 11 ['Start Acquisition FileName = "Seis011.DLD"']
# ['UTC Time = "2024/02/21', '18:03:58"']
# 453024514
# Start Acquisition FileName = "Seis012.DLD"
# 1901
# 12 ['Start Acquisition FileName = "Seis012.DLD"']
# ['UTC Time = "2024/02/21', '18:19:20"']
# 453024514
# Start Acquisition FileName = "Seis013.DLD"
# 2025
# 13 ['Start Acquisition FileName = "Seis013.DLD"']
# ['UTC Time = "2024/02/21', '19:27:07"']
# 453024514
# 453024514
# Start Acquisition FileName = "Seis014.DLD"
# 2483
# 14 ['Start Acquisition FileName = "Seis014.DLD"']
# ['UTC Time = "2024/02/23', '17:26:31"']
# 453024514
# Start Acquisition FileName = "Seis015.DLD"
# 2805
# 15 ['Start Acquisition FileName = "Seis015.DLD"']
# ['UTC Time = "2024/02/23', '19:01:18"']
# 453024765
# 453024765
# Start Acquisition FileName = "Seis000.DLD"
# 134
# 0 ['Start Acquisition FileName = "Seis000.DLD"']
# ['UTC Time = "2024/02/09', '20:46:32"']
# 453024765
# 453024765
# 453024765
# Start Acquisition FileName = "Seis001.DLD"
# 352
# 1 ['Start Acquisition FileName = "Seis001.DLD"']
# ['UTC Time = "2024/02/10', '12:45:39"']
# 453024765
# Start Acquisition FileName = "Seis002.DLD"
# 472
# 2 ['Start Acquisition FileName = "Seis002.DLD"']
# ['UTC Time = "2024/02/10', '13:05:35"']
# 453024765
# Start Acquisition FileName = "Seis003.DLD"
# 592
# 3 ['Start Acquisition FileName = "Seis003.DLD"']
# ['UTC Time = "2024/02/10', '13:32:31"']
# 453024765
# Start Acquisition FileName = "Seis004.DLD"
# 716
# 4 ['Start Acquisition FileName = "Seis004.DLD"']
# ['UTC Time = "2024/02/10', '14:15:12"']
# 453024765
# 453024765
# Start Acquisition FileName = "Seis005.DLD"
# 1005
# 5 ['Start Acquisition FileName = "Seis005.DLD"']
# ['UTC Time = "2024/02/11', '18:41:07"']
# 453024765
# Start Acquisition FileName = "Seis006.DLD"
# 1105
# 6 ['Start Acquisition FileName = "Seis006.DLD"']
# ['UTC Time = "2024/02/11', '18:53:35"']
# 453024765
# Start Acquisition FileName = "Seis007.DLD"
# 1201
# 7 ['Start Acquisition FileName = "Seis007.DLD"']
# ['UTC Time = "2024/02/11', '19:06:00"']
# 453024765
# Start Acquisition FileName = "Seis008.DLD"
# 1301
# 8 ['Start Acquisition FileName = "Seis008.DLD"']
# ['UTC Time = "2024/02/11', '19:19:56"']
# 453024765
# Start Acquisition FileName = "Seis009.DLD"
# 1445
# 9 ['Start Acquisition FileName = "Seis009.DLD"']
# ['UTC Time = "2024/02/11', '19:59:49"']
# 453024765
# Start Acquisition FileName = "Seis010.DLD"
# 1521
# 10 ['Start Acquisition FileName = "Seis010.DLD"']
# ['UTC Time = "2024/02/11', '20:07:05"']
# 453024765
# 453024765
# Start Acquisition FileName = "Seis011.DLD"
# 1752
# 11 ['Start Acquisition FileName = "Seis011.DLD"']
# ['UTC Time = "2024/02/21', '17:27:10"']
# 453024765
# Start Acquisition FileName = "Seis012.DLD"
# 1896
# 12 ['Start Acquisition FileName = "Seis012.DLD"']
# ['UTC Time = "2024/02/21', '18:02:14"']
# 453024765
# Start Acquisition FileName = "Seis013.DLD"
# 1996
# 13 ['Start Acquisition FileName = "Seis013.DLD"']
# ['UTC Time = "2024/02/21', '18:17:40"']
# 453024765
# Start Acquisition FileName = "Seis014.DLD"
# 2140
# 14 ['Start Acquisition FileName = "Seis014.DLD"']
# ['UTC Time = "2024/02/21', '19:39:58"']
# 453024765
# 453024765
# Start Acquisition FileName = "Seis015.DLD"
# 2548
# 15 ['Start Acquisition FileName = "Seis015.DLD"']
# ['UTC Time = "2024/02/23', '17:25:39"']
# 453024765
# Start Acquisition FileName = "Seis016.DLD"
# 2870
# 16 ['Start Acquisition FileName = "Seis016.DLD"']
# ['UTC Time = "2024/02/23', '19:01:00"']
# 453025132
# 453025132
# Start Acquisition FileName = "Seis000.DLD"
# 134
# 0 ['Start Acquisition FileName = "Seis000.DLD"']
# ['UTC Time = "2024/02/09', '20:46:36"']
# 453025132
# 453025132
# Start Acquisition FileName = "Seis001.DLD"
# 293
# 1 ['Start Acquisition FileName = "Seis001.DLD"']
# ['UTC Time = "2024/02/10', '12:35:09"']
# 453025132
# Start Acquisition FileName = "Seis002.DLD"
# 417
# 2 ['Start Acquisition FileName = "Seis002.DLD"']
# ['UTC Time = "2024/02/10', '13:00:34"']
# 453025132
# Start Acquisition FileName = "Seis003.DLD"
# 541
# 3 ['Start Acquisition FileName = "Seis003.DLD"']
# ['UTC Time = "2024/02/10', '13:32:51"']
# 453025132
# Start Acquisition FileName = "Seis004.DLD"
# 665
# 4 ['Start Acquisition FileName = "Seis004.DLD"']
# ['UTC Time = "2024/02/10', '14:12:14"']
# 453025132
# 453025132
# Start Acquisition FileName = "Seis005.DLD"
# 950
# 5 ['Start Acquisition FileName = "Seis005.DLD"']
# ['UTC Time = "2024/02/11', '18:42:09"']
# 453025132
# Start Acquisition FileName = "Seis006.DLD"
# 1050
# 6 ['Start Acquisition FileName = "Seis006.DLD"']
# ['UTC Time = "2024/02/11', '18:54:08"']
# 453025132
# Start Acquisition FileName = "Seis007.DLD"
# 1146
# 7 ['Start Acquisition FileName = "Seis007.DLD"']
# ['UTC Time = "2024/02/11', '19:06:56"']
# 453025132
# Start Acquisition FileName = "Seis008.DLD"
# 1246
# 8 ['Start Acquisition FileName = "Seis008.DLD"']
# ['UTC Time = "2024/02/11', '19:20:44"']
# 453025132
# Start Acquisition FileName = "Seis009.DLD"
# 1390
# 9 ['Start Acquisition FileName = "Seis009.DLD"']
# ['UTC Time = "2024/02/11', '20:01:09"']
# 453025132
# 453025132
# Start Acquisition FileName = "Seis010.DLD"
# 1645
# 10 ['Start Acquisition FileName = "Seis010.DLD"']
# ['UTC Time = "2024/02/21', '17:26:33"']
# 453025132
# Start Acquisition FileName = "Seis011.DLD"
# 1797
# 11 ['Start Acquisition FileName = "Seis011.DLD"']
# ['UTC Time = "2024/02/21', '18:03:11"']
# 453025132
# Start Acquisition FileName = "Seis012.DLD"
# 1897
# 12 ['Start Acquisition FileName = "Seis012.DLD"']
# ['UTC Time = "2024/02/21', '18:18:47"']
# 453025132
# Start Acquisition FileName = "Seis013.DLD"
# 2021
# 13 ['Start Acquisition FileName = "Seis013.DLD"']
# ['UTC Time = "2024/02/21', '19:36:29"']
# 453025132
# 453025132
# Start Acquisition FileName = "Seis014.DLD"
# 2429
# 14 ['Start Acquisition FileName = "Seis014.DLD"']
# ['UTC Time = "2024/02/23', '17:26:07"']
# 453025132
# Start Acquisition FileName = "Seis015.DLD"
# 2751
# 15 ['Start Acquisition FileName = "Seis015.DLD"']
# ['UTC Time = "2024/02/23', '18:59:44"']
# 453025137
# 453025137
# Start Acquisition FileName = "Seis000.DLD"
# 134
# 0 ['Start Acquisition FileName = "Seis000.DLD"']
# ['UTC Time = "2024/02/09', '20:48:12"']
# 453025137
# 453025137
# Start Acquisition FileName = "Seis001.DLD"
# 293
# 1 ['Start Acquisition FileName = "Seis001.DLD"']
# ['UTC Time = "2024/02/10', '12:46:21"']
# 453025137
# Start Acquisition FileName = "Seis002.DLD"
# 389
# 2 ['Start Acquisition FileName = "Seis002.DLD"']
# ['UTC Time = "2024/02/10', '13:05:13"']
# 453025137
# Start Acquisition FileName = "Seis003.DLD"
# 509
# 3 ['Start Acquisition FileName = "Seis003.DLD"']
# ['UTC Time = "2024/02/10', '13:32:48"']
# 453025137
# Start Acquisition FileName = "Seis004.DLD"
# 661
# 4 ['Start Acquisition FileName = "Seis004.DLD"']
# ['UTC Time = "2024/02/10', '14:20:05"']
# 453025137
# 453025137
# Start Acquisition FileName = "Seis005.DLD"
# 916
# 5 ['Start Acquisition FileName = "Seis005.DLD"']
# ['UTC Time = "2024/02/11', '18:43:03"']
# 453025137
# Start Acquisition FileName = "Seis006.DLD"
# 992
# 6 ['Start Acquisition FileName = "Seis006.DLD"']
# ['UTC Time = "2024/02/11', '18:55:03"']
# 453025137
# Start Acquisition FileName = "Seis007.DLD"
# 1068
# 7 ['Start Acquisition FileName = "Seis007.DLD"']
# ['UTC Time = "2024/02/11', '19:10:08"']
# 453025137
# Start Acquisition FileName = "Seis008.DLD"
# 1144
# 8 ['Start Acquisition FileName = "Seis008.DLD"']
# ['UTC Time = "2024/02/11', '20:01:16"']
# 453025137
# 453025137
# Start Acquisition FileName = "Seis009.DLD"
# 1399
# 9 ['Start Acquisition FileName = "Seis009.DLD"']
# ['UTC Time = "2024/02/21', '17:24:21"']
# 453025137
# Start Acquisition FileName = "Seis010.DLD"
# 1571
# 10 ['Start Acquisition FileName = "Seis010.DLD"']
# ['UTC Time = "2024/02/21', '18:05:18"']
# 453025137
# Start Acquisition FileName = "Seis011.DLD"
# 1650
# 11 ['Start Acquisition FileName = "Seis011.DLD"']
# ['UTC Time = "2024/02/21', '19:17:30"']
# 453025137
# 453025137
# Start Acquisition FileName = "Seis012.DLD"
# 2112
# 12 ['Start Acquisition FileName = "Seis012.DLD"']
# ['UTC Time = "2024/02/23', '17:29:03"']
# 453025137
# Start Acquisition FileName = "Seis013.DLD"
# 2434
# 13 ['Start Acquisition FileName = "Seis013.DLD"']
# ['UTC Time = "2024/02/23', '19:07:22"']
# 453025165
# 453025165
# Start Acquisition FileName = "Seis000.DLD"
# 134
# 0 ['Start Acquisition FileName = "Seis000.DLD"']
# ['UTC Time = "2024/02/09', '20:47:09"']
# 453025165
# 453025165
# Start Acquisition FileName = "Seis001.DLD"
# 293
# 1 ['Start Acquisition FileName = "Seis001.DLD"']
# ['UTC Time = "2024/02/10', '12:35:56"']
# 453025165
# Start Acquisition FileName = "Seis002.DLD"
# 417
# 2 ['Start Acquisition FileName = "Seis002.DLD"']
# ['UTC Time = "2024/02/10', '13:05:50"']
# 453025165
# Start Acquisition FileName = "Seis003.DLD"
# 537
# 3 ['Start Acquisition FileName = "Seis003.DLD"']
# ['UTC Time = "2024/02/10', '13:33:02"']
# 453025165
# Start Acquisition FileName = "Seis004.DLD"
# 661
# 4 ['Start Acquisition FileName = "Seis004.DLD"']
# ['UTC Time = "2024/02/10', '14:15:46"']
# 453025165
# 453025165
# Start Acquisition FileName = "Seis005.DLD"
# 946
# 5 ['Start Acquisition FileName = "Seis005.DLD"']
# ['UTC Time = "2024/02/11', '18:44:12"']
# 453025165
# Start Acquisition FileName = "Seis006.DLD"
# 1022
# 6 ['Start Acquisition FileName = "Seis006.DLD"']
# ['UTC Time = "2024/02/11', '18:53:50"']
# 453025165
# Start Acquisition FileName = "Seis007.DLD"
# 1118
# 7 ['Start Acquisition FileName = "Seis007.DLD"']
# ['UTC Time = "2024/02/11', '19:07:59"']
# 453025165
# Start Acquisition FileName = "Seis008.DLD"
# 1214
# 8 ['Start Acquisition FileName = "Seis008.DLD"']
# ['UTC Time = "2024/02/11', '19:21:08"']
# 453025165
# 453025165
# Start Acquisition FileName = "Seis009.DLD"
# 1417
# 9 ['Start Acquisition FileName = "Seis009.DLD"']
# ['UTC Time = "2024/02/21', '17:25:56"']
# 453025165
# Start Acquisition FileName = "Seis010.DLD"
# 1569
# 10 ['Start Acquisition FileName = "Seis010.DLD"']
# ['UTC Time = "2024/02/21', '18:03:33"']
# 453025165
# Start Acquisition FileName = "Seis011.DLD"
# 1669
# 11 ['Start Acquisition FileName = "Seis011.DLD"']
# ['UTC Time = "2024/02/21', '18:19:06"']
# 453025165
# Start Acquisition FileName = "Seis012.DLD"
# 1794
# 12 ['Start Acquisition FileName = "Seis012.DLD"']
# ['UTC Time = "2024/02/21', '19:38:06"']
# 453025165
# 453025165
# Start Acquisition FileName = "Seis013.DLD"
# 2206
# 13 ['Start Acquisition FileName = "Seis013.DLD"']
# ['UTC Time = "2024/02/23', '17:26:14"']
# 453025165
# Start Acquisition FileName = "Seis014.DLD"
# 2528
# 14 ['Start Acquisition FileName = "Seis014.DLD"']
# ['UTC Time = "2024/02/23', '18:59:40"']
# 453025167
# 453025167
# Start Acquisition FileName = "Seis000.DLD"
# 133
# 0 ['Start Acquisition FileName = "Seis000.DLD"']
# ['UTC Time = "2024/02/09', '20:47:31"']
# 453025167
# 453025167
# Start Acquisition FileName = "Seis001.DLD"
# 292
# 1 ['Start Acquisition FileName = "Seis001.DLD"']
# ['UTC Time = "2024/02/10', '12:42:36"']
# 453025167
# Start Acquisition FileName = "Seis002.DLD"
# 392
# 2 ['Start Acquisition FileName = "Seis002.DLD"']
# ['UTC Time = "2024/02/10', '13:05:45"']
# 453025167
# Start Acquisition FileName = "Seis003.DLD"
# 512
# 3 ['Start Acquisition FileName = "Seis003.DLD"']
# ['UTC Time = "2024/02/10', '13:32:27"']
# 453025167
# Start Acquisition FileName = "Seis004.DLD"
# 656
# 4 ['Start Acquisition FileName = "Seis004.DLD"']
# ['UTC Time = "2024/02/10', '14:21:55"']
# 453025167
# 453025167
# Start Acquisition FileName = "Seis005.DLD"
# 937
# 5 ['Start Acquisition FileName = "Seis005.DLD"']
# ['UTC Time = "2024/02/11', '18:43:36"']
# 453025167
# Start Acquisition FileName = "Seis006.DLD"
# 1013
# 6 ['Start Acquisition FileName = "Seis006.DLD"']
# ['UTC Time = "2024/02/11', '18:54:32"']
# 453025167
# Start Acquisition FileName = "Seis007.DLD"
# 1089
# 7 ['Start Acquisition FileName = "Seis007.DLD"']
# ['UTC Time = "2024/02/11', '19:08:47"']
# 453025167
# Start Acquisition FileName = "Seis008.DLD"
# 1165
# 8 ['Start Acquisition FileName = "Seis008.DLD"']
# ['UTC Time = "2024/02/11', '19:23:09"']
# 453025167
# Start Acquisition FileName = "Seis009.DLD"
# 1289
# 9 ['Start Acquisition FileName = "Seis009.DLD"']
# ['UTC Time = "2024/02/11', '20:04:42"']
# 453025167
# 453025167
# Start Acquisition FileName = "Seis010.DLD"
# 1520
# 10 ['Start Acquisition FileName = "Seis010.DLD"']
# ['UTC Time = "2024/02/21', '17:23:33"']
# 453025167
# Start Acquisition FileName = "Seis011.DLD"
# 1692
# 11 ['Start Acquisition FileName = "Seis011.DLD"']
# ['UTC Time = "2024/02/21', '18:04:46"']
# 453025167
# Start Acquisition FileName = "Seis012.DLD"
# 1788
# 12 ['Start Acquisition FileName = "Seis012.DLD"']
# ['UTC Time = "2024/02/21', '18:20:40"']
# 453025167
# Start Acquisition FileName = "Seis013.DLD"
# 1912
# 13 ['Start Acquisition FileName = "Seis013.DLD"']
# ['UTC Time = "2024/02/21', '19:30:14"']
# 453025167
# 453025167
# Start Acquisition FileName = "Seis014.DLD"
# 2346
# 14 ['Start Acquisition FileName = "Seis014.DLD"']
# ['UTC Time = "2024/02/23', '17:28:14"']
# 453025167
# Start Acquisition FileName = "Seis015.DLD"
# 2668
# 15 ['Start Acquisition FileName = "Seis015.DLD"']
# ['UTC Time = "2024/02/23', '19:05:57"']
# 453025235
# 453025235
# Start Acquisition FileName = "Seis000.DLD"
# 134
# 0 ['Start Acquisition FileName = "Seis000.DLD"']
# ['UTC Time = "2024/02/09', '20:47:22"']
# 453025235
# 453025235
# Start Acquisition FileName = "Seis001.DLD"
# 293
# 1 ['Start Acquisition FileName = "Seis001.DLD"']
# ['UTC Time = "2024/02/10', '12:38:14"']
# 453025235
# Start Acquisition FileName = "Seis002.DLD"
# 413
# 2 ['Start Acquisition FileName = "Seis002.DLD"']
# ['UTC Time = "2024/02/10', '13:06:00"']
# 453025235
# Start Acquisition FileName = "Seis003.DLD"
# 533
# 3 ['Start Acquisition FileName = "Seis003.DLD"']
# ['UTC Time = "2024/02/10', '13:33:19"']
# 453025235
# Start Acquisition FileName = "Seis004.DLD"
# 677
# 4 ['Start Acquisition FileName = "Seis004.DLD"']
# ['UTC Time = "2024/02/10', '14:18:51"']
# 453025235
# 453025235
# Start Acquisition FileName = "Seis005.DLD"
# 962
# 5 ['Start Acquisition FileName = "Seis005.DLD"']
# ['UTC Time = "2024/02/11', '18:43:57"']
# 453025235
# Start Acquisition FileName = "Seis006.DLD"
# 1038
# 6 ['Start Acquisition FileName = "Seis006.DLD"']
# ['UTC Time = "2024/02/11', '18:54:05"']
# 453025235
# Start Acquisition FileName = "Seis007.DLD"
# 1134
# 7 ['Start Acquisition FileName = "Seis007.DLD"']
# ['UTC Time = "2024/02/11', '19:06:22"']
# 453025235
# Start Acquisition FileName = "Seis008.DLD"
# 1234
# 8 ['Start Acquisition FileName = "Seis008.DLD"']
# ['UTC Time = "2024/02/11', '19:20:43"']
# 453025235
# Start Acquisition FileName = "Seis009.DLD"
# 1378
# 9 ['Start Acquisition FileName = "Seis009.DLD"']
# ['UTC Time = "2024/02/11', '19:59:31"']
# 453025235
# 453025235
# Start Acquisition FileName = "Seis010.DLD"
# 1633
# 10 ['Start Acquisition FileName = "Seis010.DLD"']
# ['UTC Time = "2024/02/21', '17:25:09"']
# 453025235
# Start Acquisition FileName = "Seis011.DLD"
# 1805
# 11 ['Start Acquisition FileName = "Seis011.DLD"']
# ['UTC Time = "2024/02/21', '18:03:56"']
# 453025235
# Start Acquisition FileName = "Seis012.DLD"
# 1901
# 12 ['Start Acquisition FileName = "Seis012.DLD"']
# ['UTC Time = "2024/02/21', '18:19:33"']
# 453025235
# Start Acquisition FileName = "Seis013.DLD"
# 2025
# 13 ['Start Acquisition FileName = "Seis013.DLD"']
# ['UTC Time = "2024/02/21', '19:33:05"']
# 453025235
# 453025235
# Start Acquisition FileName = "Seis014.DLD"
# 2459
# 14 ['Start Acquisition FileName = "Seis014.DLD"']
# ['UTC Time = "2024/02/23', '17:26:31"']
# 453025235
# Start Acquisition FileName = "Seis015.DLD"
# 2781
# 15 ['Start Acquisition FileName = "Seis015.DLD"']
# ['UTC Time = "2024/02/23', '19:02:50"']
# 453025251
# 453025251
# Start Acquisition FileName = "Seis000.DLD"
# 134
# 0 ['Start Acquisition FileName = "Seis000.DLD"']
# ['UTC Time = "2024/02/09', '20:47:30"']
# 453025251
# 453025251
# Start Acquisition FileName = "Seis001.DLD"
# 293
# 1 ['Start Acquisition FileName = "Seis001.DLD"']
# ['UTC Time = "2024/02/10', '12:40:33"']
# 453025251
# Start Acquisition FileName = "Seis002.DLD"
# 416
# 2 ['Start Acquisition FileName = "Seis002.DLD"']
# ['UTC Time = "2024/02/10', '13:06:03"']
# 453025251
# Start Acquisition FileName = "Seis003.DLD"
# 539
# 3 ['Start Acquisition FileName = "Seis003.DLD"']
# ['UTC Time = "2024/02/10', '13:33:33"']
# 453025251
# Start Acquisition FileName = "Seis004.DLD"
# 683
# 4 ['Start Acquisition FileName = "Seis004.DLD"']
# ['UTC Time = "2024/02/10', '14:15:59"']
# 453025251
# 453025251
# Start Acquisition FileName = "Seis005.DLD"
# 968
# 5 ['Start Acquisition FileName = "Seis005.DLD"']
# ['UTC Time = "2024/02/11', '18:43:33"']
# 453025251
# Start Acquisition FileName = "Seis006.DLD"
# 1044
# 6 ['Start Acquisition FileName = "Seis006.DLD"']
# ['UTC Time = "2024/02/11', '18:54:18"']
# 453025251
# Start Acquisition FileName = "Seis007.DLD"
# 1120
# 7 ['Start Acquisition FileName = "Seis007.DLD"']
# ['UTC Time = "2024/02/11', '19:08:10"']
# 453025251
# Start Acquisition FileName = "Seis008.DLD"
# 1216
# 8 ['Start Acquisition FileName = "Seis008.DLD"']
# ['UTC Time = "2024/02/11', '19:22:50"']
# 453025251
# Start Acquisition FileName = "Seis009.DLD"
# 1340
# 9 ['Start Acquisition FileName = "Seis009.DLD"']
# ['UTC Time = "2024/02/11', '20:04:08"']
# 453025251
# 453025251
# Start Acquisition FileName = "Seis010.DLD"
# 1571
# 10 ['Start Acquisition FileName = "Seis010.DLD"']
# ['UTC Time = "2024/02/21', '17:23:36"']
# 453025251
# Start Acquisition FileName = "Seis011.DLD"
# 1743
# 11 ['Start Acquisition FileName = "Seis011.DLD"']
# ['UTC Time = "2024/02/21', '18:04:29"']
# 453025251
# Start Acquisition FileName = "Seis012.DLD"
# 1839
# 12 ['Start Acquisition FileName = "Seis012.DLD"']
# ['UTC Time = "2024/02/21', '18:21:23"']
# 453025251
# Start Acquisition FileName = "Seis013.DLD"
# 1963
# 13 ['Start Acquisition FileName = "Seis013.DLD"']
# ['UTC Time = "2024/02/21', '19:23:37"']
# 453025251
# 453025251
# Start Acquisition FileName = "Seis014.DLD"
# 2421
# 14 ['Start Acquisition FileName = "Seis014.DLD"']
# ['UTC Time = "2024/02/23', '17:27:33"']
# 453025251
# Start Acquisition FileName = "Seis015.DLD"
# 2743
# 15 ['Start Acquisition FileName = "Seis015.DLD"']
# ['UTC Time = "2024/02/23', '19:03:13"']
# 453025291
# 453025291
# Start Acquisition FileName = "Seis000.DLD"
# 134
# 0 ['Start Acquisition FileName = "Seis000.DLD"']
# ['UTC Time = "2024/02/09', '20:47:27"']
# 453025291
# 453025291
# Start Acquisition FileName = "Seis001.DLD"
# 293
# 1 ['Start Acquisition FileName = "Seis001.DLD"']
# ['UTC Time = "2024/02/10', '12:46:43"']
# 453025291
# Start Acquisition FileName = "Seis002.DLD"
# 389
# 2 ['Start Acquisition FileName = "Seis002.DLD"']
# ['UTC Time = "2024/02/10', '13:05:13"']
# 453025291
# Start Acquisition FileName = "Seis003.DLD"
# 509
# 3 ['Start Acquisition FileName = "Seis003.DLD"']
# ['UTC Time = "2024/02/10', '13:33:06"']
# 453025291
# Start Acquisition FileName = "Seis004.DLD"
# 661
# 4 ['Start Acquisition FileName = "Seis004.DLD"']
# ['UTC Time = "2024/02/10', '14:21:09"']
# 453025291
# 453025291
# Start Acquisition FileName = "Seis005.DLD"
# 916
# 5 ['Start Acquisition FileName = "Seis005.DLD"']
# ['UTC Time = "2024/02/11', '18:44:36"']
# 453025291
# Start Acquisition FileName = "Seis006.DLD"
# 992
# 6 ['Start Acquisition FileName = "Seis006.DLD"']
# ['UTC Time = "2024/02/11', '18:55:08"']
# 453025291
# Start Acquisition FileName = "Seis007.DLD"
# 1068
# 7 ['Start Acquisition FileName = "Seis007.DLD"']
# ['UTC Time = "2024/02/11', '19:10:29"']
# 453025291
# Start Acquisition FileName = "Seis008.DLD"
# 1144
# 8 ['Start Acquisition FileName = "Seis008.DLD"']
# ['UTC Time = "2024/02/11', '20:00:24"']
# 453025291
# 453025291
# Start Acquisition FileName = "Seis009.DLD"
# 1399
# 9 ['Start Acquisition FileName = "Seis009.DLD"']
# ['UTC Time = "2024/02/21', '17:24:33"']
# 453025291
# Start Acquisition FileName = "Seis010.DLD"
# 1571
# 10 ['Start Acquisition FileName = "Seis010.DLD"']
# ['UTC Time = "2024/02/21', '18:05:29"']
# 453025291
# Start Acquisition FileName = "Seis011.DLD"
# 1647
# 11 ['Start Acquisition FileName = "Seis011.DLD"']
# ['UTC Time = "2024/02/21', '18:18:38"']
# 453025291
# Start Acquisition FileName = "Seis012.DLD"
# 1771
# 12 ['Start Acquisition FileName = "Seis012.DLD"']
# ['UTC Time = "2024/02/21', '19:17:00"']
# 453025291
# 453025291
# Start Acquisition FileName = "Seis013.DLD"
# 2253
# 13 ['Start Acquisition FileName = "Seis013.DLD"']
# ['UTC Time = "2024/02/23', '17:29:04"']
# 453025291
# Start Acquisition FileName = "Seis014.DLD"
# 2575
# 14 ['Start Acquisition FileName = "Seis014.DLD"']
# ['UTC Time = "2024/02/23', '19:04:46"']
# 453025442
# 453025442
# Start Acquisition FileName = "Seis000.DLD"
# 133
# 0 ['Start Acquisition FileName = "Seis000.DLD"']
# ['UTC Time = "2024/02/09', '20:47:31"']
# 453025442
# 453025442
# Start Acquisition FileName = "Seis001.DLD"
# 291
# 1 ['Start Acquisition FileName = "Seis001.DLD"']
# ['UTC Time = "2024/02/10', '12:43:39"']
# 453025442
# Start Acquisition FileName = "Seis002.DLD"
# 391
# 2 ['Start Acquisition FileName = "Seis002.DLD"']
# ['UTC Time = "2024/02/10', '13:05:43"']
# 453025442
# Start Acquisition FileName = "Seis003.DLD"
# 511
# 3 ['Start Acquisition FileName = "Seis003.DLD"']
# ['UTC Time = "2024/02/10', '13:32:43"']
# 453025442
# Start Acquisition FileName = "Seis004.DLD"
# 655
# 4 ['Start Acquisition FileName = "Seis004.DLD"']
# ['UTC Time = "2024/02/10', '14:21:30"']
# 453025442
# Start Acquisition FileName = "Seis005.DLD"
# 877
# 5 ['Start Acquisition FileName = "Seis005.DLD"']
# ['UTC Time = "2024/02/10', '15:13:17"']
# 453025442
# 453025442
# Start Acquisition FileName = "Seis006.DLD"
# 2121
# 6 ['Start Acquisition FileName = "Seis006.DLD"']
# ['UTC Time = "2024/02/11', '18:43:33"']
# 453025442
# Start Acquisition FileName = "Seis007.DLD"
# 2197
# 7 ['Start Acquisition FileName = "Seis007.DLD"']
# ['UTC Time = "2024/02/11', '18:54:36"']
# 453025442
# Start Acquisition FileName = "Seis008.DLD"
# 2273
# 8 ['Start Acquisition FileName = "Seis008.DLD"']
# ['UTC Time = "2024/02/11', '19:08:52"']
# 453025442
# Start Acquisition FileName = "Seis009.DLD"
# 2349
# 9 ['Start Acquisition FileName = "Seis009.DLD"']
# ['UTC Time = "2024/02/11', '19:22:25"']
# 453025442
# Start Acquisition FileName = "Seis010.DLD"
# 2473
# 10 ['Start Acquisition FileName = "Seis010.DLD"']
# ['UTC Time = "2024/02/11', '20:08:04"']
# 453025442
# 453025442
# Start Acquisition FileName = "Seis011.DLD"
# 2704
# 11 ['Start Acquisition FileName = "Seis011.DLD"']
# ['UTC Time = "2024/02/21', '17:23:06"']
# 453025442
# Start Acquisition FileName = "Seis012.DLD"
# 2876
# 12 ['Start Acquisition FileName = "Seis012.DLD"']
# ['UTC Time = "2024/02/21', '18:04:56"']
# 453025442
# Start Acquisition FileName = "Seis013.DLD"
# 2972
# 13 ['Start Acquisition FileName = "Seis013.DLD"']
# ['UTC Time = "2024/02/21', '18:20:07"']
# 453025442
# Start Acquisition FileName = "Seis014.DLD"
# 3096
# 14 ['Start Acquisition FileName = "Seis014.DLD"']
# ['UTC Time = "2024/02/21', '19:31:15"']
# 453025442
# 453025442
# Start Acquisition FileName = "Seis015.DLD"
# 3530
# 15 ['Start Acquisition FileName = "Seis015.DLD"']
# ['UTC Time = "2024/02/23', '17:28:42"']
# 453025442
# Start Acquisition FileName = "Seis016.DLD"
# 3852
# 16 ['Start Acquisition FileName = "Seis016.DLD"']
# ['UTC Time = "2024/02/23', '19:06:53"']
# 453025450
# 453025450
# Start Acquisition FileName = "Seis000.DLD"
# 134
# 0 ['Start Acquisition FileName = "Seis000.DLD"']
# ['UTC Time = "2024/02/09', '20:47:29"']
# 453025450
# 453025450
# Start Acquisition FileName = "Seis001.DLD"
# 293
# 1 ['Start Acquisition FileName = "Seis001.DLD"']
# ['UTC Time = "2024/02/10', '12:40:09"']
# 453025450
# Start Acquisition FileName = "Seis002.DLD"
# 413
# 2 ['Start Acquisition FileName = "Seis002.DLD"']
# ['UTC Time = "2024/02/10', '13:06:10"']
# 453025450
# Start Acquisition FileName = "Seis003.DLD"
# 533
# 3 ['Start Acquisition FileName = "Seis003.DLD"']
# ['UTC Time = "2024/02/10', '13:33:24"']
# 453025450
# Start Acquisition FileName = "Seis004.DLD"
# 677
# 4 ['Start Acquisition FileName = "Seis004.DLD"']
# ['UTC Time = "2024/02/10', '14:20:44"']
# 453025450
# 453025450
# Start Acquisition FileName = "Seis005.DLD"
# 962
# 5 ['Start Acquisition FileName = "Seis005.DLD"']
# ['UTC Time = "2024/02/11', '18:43:36"']
# 453025450
# Start Acquisition FileName = "Seis006.DLD"
# 1038
# 6 ['Start Acquisition FileName = "Seis006.DLD"']
# ['UTC Time = "2024/02/11', '18:54:20"']
# 453025450
# Start Acquisition FileName = "Seis007.DLD"
# 1114
# 7 ['Start Acquisition FileName = "Seis007.DLD"']
# ['UTC Time = "2024/02/11', '19:07:11"']
# 453025450
# Start Acquisition FileName = "Seis008.DLD"
# 1210
# 8 ['Start Acquisition FileName = "Seis008.DLD"']
# ['UTC Time = "2024/02/11', '19:21:44"']
# 453025450
# Start Acquisition FileName = "Seis009.DLD"
# 1357
# 9 ['Start Acquisition FileName = "Seis009.DLD"']
# ['UTC Time = "2024/02/11', '20:02:50"']
# 453025450
# 453025450
# Start Acquisition FileName = "Seis010.DLD"
# 1588
# 10 ['Start Acquisition FileName = "Seis010.DLD"']
# ['UTC Time = "2024/02/21', '17:24:12"']
# 453025450
# Start Acquisition FileName = "Seis011.DLD"
# 1760
# 11 ['Start Acquisition FileName = "Seis011.DLD"']
# ['UTC Time = "2024/02/21', '18:04:11"']
# 453025450
# Start Acquisition FileName = "Seis012.DLD"
# 1856
# 12 ['Start Acquisition FileName = "Seis012.DLD"']
# ['UTC Time = "2024/02/21', '18:21:47"']
# 453025450
# Start Acquisition FileName = "Seis013.DLD"
# 1976
# 13 ['Start Acquisition FileName = "Seis013.DLD"']
# ['UTC Time = "2024/02/21', '19:30:39"']
# 453025450
# 453025450
# Start Acquisition FileName = "Seis014.DLD"
# 2410
# 14 ['Start Acquisition FileName = "Seis014.DLD"']
# ['UTC Time = "2024/02/23', '17:27:09"']
# 453025450
# Start Acquisition FileName = "Seis015.DLD"
# 2732
# 15 ['Start Acquisition FileName = "Seis015.DLD"']
# ['UTC Time = "2024/02/23', '19:01:26"']

# %%
pprint(records_geo.keys())
# Out:
# dict_keys(['4075', '4177', '4180', '4265', '4274', '4514', '4765', '5132', '5137', '5165', '5167', '5235', '5251', '5291', '5442', '5450'])

# %%
filename = '/Volumes/Hublot24/Share_hublot/Data/0223/Summary/records_0223.pkl'
records = rw_data.load_pkl(filename)
print(records.keys())
# Out:
# dict_keys(['mesange', 'Bernache', 'phones', 'geophones', 'buoys'])

# %%
for key in records.keys():
    record = records[key]
    for k in record.keys():
        pprint(k)
# Out:
# '04-waves_001'
# '05-doc_003'
# '06-waves_002'
# '07-frac+waves_001'
# '08-waves_003'
# '10-rheo+waves_001'
# '11-ortho_002'
# '12-waves_004'
# '13-waves_005'
# '14-waves_006'
# '17-waves_007'
# '18-waves_008'
# '19-canot_001'
# '20-frac+waves_002'
# '21-waves_009'
# '23_waves_010'
# '24-doc_005'
# '25-doc_006'
# '27-doc_007'
# '28-waves_011'
# '29-waves_012'
# '30-rheo+waves_002'
# '32-canot-002'
# '34-waves_013'
# '35-waves_014'
# '37-waves_015'
# '39-waves_016'
# '40-waves_017'
# '41-waves_018'
# '42-waves_019'
# '16-waves_011'
# '17-waves_012'
# '18-doc_002'
# '20-waves_013'
# '21-waves_014'
# '22-waves_015'
# '23-doc_003'
# '25-waves_016'
# '26-diamand_001'
# '27-ice_001'
# '28-waves_017'
# '30-doc_004'
# '02-waves_002'
# '03-waves_003'
# '04-waves_004'
# '05-waves_005'
# '06-waves_006'
# '07-waves_007'
# '08-waves_008'
# '09-waves_009'
# '11-doc_001'
# '12-waves_010'
# '13-doc_002'
# '01-waves_001'
# 0
# 4
# 6
# 9
# 11
# 13
# 16
# 17
# 18
# 19
# '4075'
# '4177'
# '4180'
# '4265'
# '4274'
# '4514'
# '4765'
# '5132'
# '5137'
# '5165'
# '5167'
# '5235'
# '5251'
# '5291'
# '5442'
# '5450'
# 'B1'
# 'B2'
# 'B4'
# 'B5'

# %%
records['mesange']['04-waves_001'][0]['time']#.keys()
# Out:
# '17:24:23'

# %%
records.keys()
# Out:
# dict_keys(['mesange', 'Bernache', 'phones', 'geophones', 'buoys'])

# %%
fig = plt.figure(figsize=(20,15))
ax = fig.add_subplot(111)

import matplotlib.dates as mdates

colors = {}
for k in ['mesange','Bernache']:
    record = records['mesange']
    for name in record.keys():   
        try:
            title = name.split('-')[1]#.split('_')[0]
        except:
            title = name
        times = [record[name][key]['time'] for key in record[name].keys()]
        x = [times[0],times[-1]]
        x = np.asarray([convert(x[0]),convert(x[1])])

        r=np.random.random()*b
        ax.plot(x/3600, [1+r,1+r],color+symbol+'-')
        #display_text(x,y,title,ax=ax)
        ax.text(x[0]/3600,1+0.01+r,title)
        #print(convert(x[0]))

# %%
pprint(records_geo['4177'][14]['date'])
pprint(records_geo['4177'][14]['times'])
# Out:
# '2024/02/23'
# ['17:26:00',
#  '17:33:52',
#  '17:33:54',
#  '17:35:56',
#  '17:41:52',
#  '17:41:54',
#  '17:45:56',
#  '17:50:02',
#  '17:50:04',
#  '17:55:56',
#  '17:56:08',
#  '17:58:09',
#  '17:58:11',
#  '18:06:15',
#  '18:06:15',
#  '18:06:17',
#  '18:14:23',
#  '18:14:23',
#  '18:14:25',
#  '18:16:25',
#  '18:22:30',
#  '18:22:32',
#  '18:25:57',
#  '18:26:34',
#  '18:30:38',
#  '18:30:40',
#  '18:36:45',
#  '18:38:46',
#  '18:38:48',
#  '18:46:57',
#  '18:46:57',
#  '18:46:59']

# %%
fig = plt.figure(figsize=(20,15))
ax = fig.add_subplot(111)

import matplotlib.dates as mdates

b=0.2
for (record,name) in zip(records_b,srtfiles_bernache):
    try:
        title = name.split('/')[-2].split('-')[1]#.split('_')[0]
    except:
        title = name.split('/')[-2]

    times = [record[key]['time'] for key in record.keys()]
    x = [times[0],times[-1]]
    x = np.asarray([convert(x[0]),convert(x[1])])
    
    r=np.random.random()*b
    ax.plot(x/3600, [1+r,1+r],'ko-')
    #display_text(x,y,title,ax=ax)
    ax.text(x[0]/3600,1+0.01+r,title)
    #print(convert(x[0]))

for (record,name) in zip(records_m,srtfiles_mesange):
    try:
        title = name.split('/')[-2].split('-')[1]#.split('_')[0]
    except:
        title = name.split('/')[-2]

    times = [record[key]['time'] for key in record.keys()]
    x = [times[0],times[-1]]
    x = np.asarray([convert(x[0])-3600*6,convert(x[1])-3600*6])
    
    r=np.random.random()*b
    ax.plot(x/3600, [1+b+r,1+b+r],'bo-')
    ax.text(x[0]/3600,1+b+0.01+r,title)
    #print(convert(x[0]))
    
X = {}
for i,phone in enumerate(phonedict.keys()):
    t0 = phonedict[phone]['time_start'].split(' ')[1][:-4]#.keys())
    t1 = phonedict[phone]['time_end'].split(' ')[1][:-4]
    print(t0,t1)
    X[i] = np.asarray([convert(t0)-3600*6,convert(t1)-3600*6])
    
    if X[i][0]/3600<11:
        X[i]=X[i-1]
    r=i*0.02#np.random.random()*b
    ax.plot(X[i]/3600, [1.5+r,1.5+r],'rs-')
    ax.text(X[i][0]/3600-0.1,1.5+r,str(phone))

#    ax.plot()
    #.keys())

X={}
for i,num in enumerate(records_geo.keys()):
    for key in records_geo[num]:
        if records_geo[num][key]['date']=='2024/02/23':
            t0 = records_geo[num][key]['times'][0]
            t1 = records_geo[num][key]['times'][-1]
            
            X[num] = np.asarray([convert(t0)-3600*5,convert(t1)-3600*5])

            r=i*0.02#np.random.random()*b
            ax.plot(X[num]/3600, [0.5+r,0.5+r],'g^-')
            ax.text(X[num][0]/3600-0.1,0.5+r,num)

plt.ylim(0,2)
hours = [11,12,13,14,15,16]
ax.set_xticks(hours,[str(h)+':00' for h in hours])
#ax.xaxis.set_major_formatter(mdates.DateFormatter('%H:%M:%S'))
#ax.set_xlim(['11:30:00','15:00:00'])
#ax.xaxis.set_major_formatter(mdates.DateFormatter('%h-%m-%s'))
#fig.autofmt_xdate()

figs = graphes.legende('Local time','Instruments',date)
# Out:
# 18:47:40 19:38:08
# 18:47:43 19:36:04
# 18:47:37 19:40:04
# 18:47:41 19:40:58
# 18:47:27 19:41:14
# 05:57:50 06:53:09
# 18:47:15 19:43:19
# 18:47:12 19:43:16
# 06:05:16 06:59:53
# 18:47:36 19:43:07

# %%
buoyfile = glob.glob('*.mat')[0]

import h5py

buoy = h5py.File(buoyfile)

# %%
buoy['IMU'].keys()
print(buoy['IMU']['UTC_TIME'].keys())

hours = buoy['IMU']['UTC_TIME']['HOUR'][:][0]#.keys()
mins = buoy['IMU']['UTC_TIME']['MIN'][:][0]#.keys()
secs = buoy['IMU']['UTC_TIME']['SEC'][:][0]#.keys()

times = [str(int(hour))+':'+str(int(m))+':'+str(sec).replace('.','')[:2] for (hour,m,sec) in zip(hours,mins,secs)]
pprint(times)
# Out:
# <KeysViewHDF5 ['CLOCK_STATUS', 'CRC', 'CRC_CALC', 'DAY', 'GPS_TOW', 'HOUR', 'MIN', 'MONTH', 'NANOSEC', 'SEC', 'TIME_STAMP', 'TS_fix', 'YEAR', 't', 'time']>
# ['17:34:30',
#  '17:34:40',
#  '17:34:50',
#  '17:34:60',
#  '17:34:70',
#  '17:34:80',
#  '17:34:90',
#  '17:34:10',
#  '17:34:90',
#  '17:34:10',
#  '17:34:10',
#  '17:34:11',
#  '17:34:12',
#  '17:34:13',
#  '17:34:14',
#  '17:34:15',
#  '17:34:16',
#  '17:34:18',
#  '17:34:19',
#  '17:34:20',
#  '17:34:21',
#  '17:34:22',
#  '17:34:23',
#  '17:34:24',
#  '17:34:25',
#  '17:34:26',
#  '17:34:27',
#  '17:34:28',
#  '17:34:29',
#  '17:34:30',
#  '17:34:31',
#  '17:34:32',
#  '17:34:33',
#  '17:34:34',
#  '17:34:35',
#  '17:34:36',
#  '17:34:37',
#  '17:34:38',
#  '17:34:39',
#  '17:34:40',
#  '17:34:41',
#  '17:34:42',
#  '17:34:43',
#  '17:34:44',
#  '17:34:45',
#  '17:34:46',
#  '17:34:47',
#  '17:34:47',
#  '17:34:48',
#  '17:34:49',
#  '17:34:50',
#  '17:34:51',
#  '17:34:52',
#  '17:34:53',
#  '17:34:54',
#  '17:34:55',
#  '17:34:56',
#  '17:34:57',
#  '17:34:58',
#  '17:34:59',
#  '17:35:00',
#  '17:35:10',
#  '17:35:20',
#  '17:35:40',
#  '17:35:50',
#  '17:35:60',
#  '17:35:70',
#  '17:35:80',
#  '17:35:90',
#  '17:35:10',
#  '17:35:11',
#  '17:35:12',
#  '17:35:13',
#  '17:35:14',
#  '17:35:15',
#  '17:35:16',
#  '17:35:17',
#  '17:35:18',
#  '17:35:19',
#  '17:35:20',
#  '17:35:21',
#  '17:35:22',
#  '17:35:23',
#  '17:35:24',
#  '17:35:25',
#  '17:35:26',
#  '17:35:27',
#  '17:35:28',
#  '17:35:29',
#  '17:35:30',
#  '17:35:31',
#  '17:35:32',
#  '17:35:33',
#  '17:35:34',
#  '17:35:35',
#  '17:35:36',
#  '17:35:37',
#  '17:35:38',
#  '17:35:39',
#  '17:35:40',
#  '17:35:41',
#  '17:35:42',
#  '17:35:43',
#  '17:35:44',
#  '17:35:45',
#  '17:35:46',
#  '17:35:47',
#  '17:35:48',
#  '17:35:49',
#  '17:35:50',
#  '17:35:51',
#  '17:35:52',
#  '17:35:53',
#  '17:35:54',
#  '17:35:55',
#  '17:35:56',
#  '17:35:57',
#  '17:35:58',
#  '17:35:59',
#  '17:36:00',
#  '17:36:10',
#  '17:36:20',
#  '17:36:30',
#  '17:36:40',
#  '17:36:50',
#  '17:36:60',
#  '17:36:70',
#  '17:36:80',
#  '17:36:90',
#  '17:36:10',
#  '17:36:11',
#  '17:36:12',
#  '17:36:13',
#  '17:36:14',
#  '17:36:15',
#  '17:36:16',
#  '17:36:17',
#  '17:36:18',
#  '17:36:19',
#  '17:36:20',
#  '17:36:21',
#  '17:36:22',
#  '17:36:23',
#  '17:36:24',
#  '17:36:25',
#  '17:36:26',
#  '17:36:27',
#  '17:36:28',
#  '17:36:29',
#  '17:36:30',
#  '17:36:31',
#  '17:36:32',
#  '17:36:33',
#  '17:36:34',
#  '17:36:35',
#  '17:36:36',
#  '17:36:37',
#  '17:36:38',
#  '17:36:39',
#  '17:36:40',
#  '17:36:41',
#  '17:36:42',
#  '17:36:43',
#  '17:36:44',
#  '17:36:45',
#  '17:36:46',
#  '17:36:47',
#  '17:36:48',
#  '17:36:49',
#  '17:36:50',
#  '17:36:51',
#  '17:36:52',
#  '17:36:53',
#  '17:36:54',
#  '17:36:55',
#  '17:36:56',
#  '17:36:57',
#  '17:36:58',
#  '17:36:59',
#  '17:37:00',
#  '17:37:10',
#  '17:37:20',
#  '17:37:30',
#  '17:37:40',
#  '17:37:50',
#  '17:37:60',
#  '17:37:70',
#  '17:37:80',
#  '17:37:90',
#  '17:37:10',
#  '17:37:11',
#  '17:37:12',
#  '17:37:13',
#  '17:37:14',
#  '17:37:15',
#  '17:37:16',
#  '17:37:17',
#  '17:37:18',
#  '17:37:19',
#  '17:37:20',
#  '17:37:21',
#  '17:37:22',
#  '17:37:23',
#  '17:37:24',
#  '17:37:25',
#  '17:37:26',
#  '17:37:27',
#  '17:37:28',
#  '17:37:29',
#  '17:37:30',
#  '17:37:31',
#  '17:37:32',
#  '17:37:33',
#  '17:37:34',
#  '17:37:35',
#  '17:37:36',
#  '17:37:37',
#  '17:37:38',
#  '17:37:39',
#  '17:37:40',
#  '17:37:41',
#  '17:37:42',
#  '17:37:43',
#  '17:37:44',
#  '17:37:45',
#  '17:37:46',
#  '17:37:47',
#  '17:37:48',
#  '17:37:49',
#  '17:37:50',
#  '17:37:51',
#  '17:37:52',
#  '17:37:53',
#  '17:37:54',
#  '17:37:55',
#  '17:37:56',
#  '17:37:57',
#  '17:37:58',
#  '17:37:59',
#  '17:38:00',
#  '17:38:10',
#  '17:38:20',
#  '17:38:30',
#  '17:38:40',
#  '17:38:50',
#  '17:38:60',
#  '17:38:70',
#  '17:38:80',
#  '17:38:90',
#  '17:38:10',
#  '17:38:11',
#  '17:38:12',
#  '17:38:13',
#  '17:38:14',
#  '17:38:15',
#  '17:38:16',
#  '17:38:17',
#  '17:38:18',
#  '17:38:19',
#  '17:38:20',
#  '17:38:21',
#  '17:38:22',
#  '17:38:23',
#  '17:38:24',
#  '17:38:25',
#  '17:38:26',
#  '17:38:27',
#  '17:38:28',
#  '17:38:29',
#  '17:38:30',
#  '17:38:31',
#  '17:38:32',
#  '17:38:33',
#  '17:38:34',
#  '17:38:35',
#  '17:38:36',
#  '17:38:37',
#  '17:38:38',
#  '17:38:39',
#  '17:38:40',
#  '17:38:41',
#  '17:38:42',
#  '17:38:43',
#  '17:38:44',
#  '17:38:45',
#  '17:38:46',
#  '17:38:47',
#  '17:38:48',
#  '17:38:49',
#  '17:38:50',
#  '17:38:51',
#  '17:38:52',
#  '17:38:53',
#  '17:38:54',
#  '17:38:55',
#  '17:38:56',
#  '17:38:57',
#  '17:38:58',
#  '17:38:59',
#  '17:39:00',
#  '17:39:10',
#  '17:39:20',
#  '17:39:30',
#  '17:39:40',
#  '17:39:50',
#  '17:39:60',
#  '17:39:70',
#  '17:39:80',
#  '17:39:90',
#  '17:39:10',
#  '17:39:11',
#  '17:39:12',
#  '17:39:13',
#  '17:39:14',
#  '17:39:15',
#  '17:39:16',
#  '17:39:17',
#  '17:39:18',
#  '17:39:19',
#  '17:39:20',
#  '17:39:21',
#  '17:39:22',
#  '17:39:23',
#  '17:39:24',
#  '17:39:25',
#  '17:39:26',
#  '17:39:27',
#  '17:39:28',
#  '17:39:29',
#  '17:39:30',
#  '17:39:31',
#  '17:39:32',
#  '17:39:33',
#  '17:39:34',
#  '17:39:35',
#  '17:39:36',
#  '17:39:37',
#  '17:39:38',
#  '17:39:39',
#  '17:39:40',
#  '17:39:41',
#  '17:39:42',
#  '17:39:43',
#  '17:39:44',
#  '17:39:45',
#  '17:39:46',
#  '17:39:47',
#  '17:39:48',
#  '17:39:49',
#  '17:39:50',
#  '17:39:51',
#  '17:39:52',
#  '17:39:53',
#  '17:39:54',
#  '17:39:55',
#  '17:39:56',
#  '17:39:57',
#  '17:39:58',
#  '17:39:59',
#  '17:40:00',
#  '17:40:10',
#  '17:40:20',
#  '17:40:30',
#  '17:40:40',
#  '17:40:50',
#  '17:40:60',
#  '17:40:70',
#  '17:40:80',
#  '17:40:90',
#  '17:40:10',
#  '17:40:11',
#  '17:40:12',
#  '17:40:13',
#  '17:40:14',
#  '17:40:15',
#  '17:40:16',
#  '17:40:17',
#  '17:40:18',
#  '17:40:19',
#  '17:40:20',
#  '17:40:21',
#  '17:40:22',
#  '17:40:23',
#  '17:40:24',
#  '17:40:25',
#  '17:40:26',
#  '17:40:27',
#  '17:40:28',
#  '17:40:29',
#  '17:40:30',
#  '17:40:31',
#  '17:40:32',
#  '17:40:33',
#  '17:40:34',
#  '17:40:35',
#  '17:40:36',
#  '17:40:37',
#  '17:40:38',
#  '17:40:39',
#  '17:40:40',
#  '17:40:41',
#  '17:40:42',
#  '17:40:43',
#  '17:40:44',
#  '17:40:45',
#  '17:40:46',
#  '17:40:47',
#  '17:40:48',
#  '17:40:49',
#  '17:40:50',
#  '17:40:51',
#  '17:40:52',
#  '17:40:53',
#  '17:40:54',
#  '17:40:55',
#  '17:40:56',
#  '17:40:57',
#  '17:40:58',
#  '17:40:59',
#  '17:41:00',
#  '17:41:10',
#  '17:41:20',
#  '17:41:30',
#  '17:41:40',
#  '17:41:50',
#  '17:41:60',
#  '17:41:70',
#  '17:41:80',
#  '17:41:90',
#  '17:41:10',
#  '17:41:11',
#  '17:41:12',
#  '17:41:13',
#  '17:41:14',
#  '17:41:15',
#  '17:41:16',
#  '17:41:17',
#  '17:41:18',
#  '17:41:19',
#  '17:41:20',
#  '17:41:21',
#  '17:41:22',
#  '17:41:23',
#  '17:41:24',
#  '17:41:25',
#  '17:41:26',
#  '17:41:27',
#  '17:41:28',
#  '17:41:29',
#  '17:41:30',
#  '17:41:31',
#  '17:41:32',
#  '17:41:33',
#  '17:41:34',
#  '17:41:35',
#  '17:41:36',
#  '17:41:37',
#  '17:41:38',
#  '17:41:39',
#  '17:41:40',
#  '17:41:41',
#  '17:41:42',
#  '17:41:43',
#  '17:41:44',
#  '17:41:45',
#  '17:41:46',
#  '17:41:47',
#  '17:41:48',
#  '17:41:49',
#  '17:41:50',
#  '17:41:51',
#  '17:41:52',
#  '17:41:53',
#  '17:41:54',
#  '17:41:55',
#  '17:41:56',
#  '17:41:57',
#  '17:41:58',
#  '17:41:59',
#  '17:42:00',
#  '17:42:10',
#  '17:42:20',
#  '17:42:30',
#  '17:42:40',
#  '17:42:50',
#  '17:42:60',
#  '17:42:70',
#  '17:42:80',
#  '17:42:90',
#  '17:42:10',
#  '17:42:11',
#  '17:42:12',
#  '17:42:13',
#  '17:42:14',
#  '17:42:15',
#  '17:42:16',
#  '17:42:17',
#  '17:42:18',
#  '17:42:19',
#  '17:42:20',
#  '17:42:21',
#  '17:42:22',
#  '17:42:23',
#  '17:42:24',
#  '17:42:25',
#  '17:42:26',
#  '17:42:27',
#  '17:42:28',
#  '17:42:29',
#  '17:42:30',
#  '17:42:31',
#  '17:42:32',
#  '17:42:33',
#  '17:42:34',
#  '17:42:35',
#  '17:42:36',
#  '17:42:37',
#  '17:42:38',
#  '17:42:39',
#  '17:42:40',
#  '17:42:41',
#  '17:42:42',
#  '17:42:43',
#  '17:42:44',
#  '17:42:45',
#  '17:42:46',
#  '17:42:47',
#  '17:42:48',
#  '17:42:49',
#  '17:42:50',
#  '17:42:51',
#  '17:42:52',
#  '17:42:53',
#  '17:42:54',
#  '17:42:55',
#  '17:42:56',
#  '17:42:57',
#  '17:42:58',
#  '17:42:59',
#  '17:43:00',
#  '17:43:10',
#  '17:43:20',
#  '17:43:30',
#  '17:43:40',
#  '17:43:50',
#  '17:43:60',
#  '17:43:70',
#  '17:43:80',
#  '17:43:90',
#  '17:43:10',
#  '17:43:11',
#  '17:43:12',
#  '17:43:13',
#  '17:43:14',
#  '17:43:15',
#  '17:43:16',
#  '17:43:17',
#  '17:43:18',
#  '17:43:19',
#  '17:43:20',
#  '17:43:21',
#  '17:43:22',
#  '17:43:23',
#  '17:43:24',
#  '17:43:25',
#  '17:43:26',
#  '17:43:27',
#  '17:43:28',
#  '17:43:29',
#  '17:43:30',
#  '17:43:31',
#  '17:43:32',
#  '17:43:33',
#  '17:43:34',
#  '17:43:35',
#  '17:43:36',
#  '17:43:37',
#  '17:43:38',
#  '17:43:39',
#  '17:43:40',
#  '17:43:41',
#  '17:43:42',
#  '17:43:43',
#  '17:43:44',
#  '17:43:45',
#  '17:43:46',
#  '17:43:47',
#  '17:43:48',
#  '17:43:49',
#  '17:43:50',
#  '17:43:51',
#  '17:43:52',
#  '17:43:53',
#  '17:43:54',
#  '17:43:55',
#  '17:43:56',
#  '17:43:57',
#  '17:43:58',
#  '17:43:59',
#  '17:44:00',
#  '17:44:10',
#  '17:44:20',
#  '17:44:30',
#  '17:44:40',
#  '17:44:50',
#  '17:44:60',
#  '17:44:70',
#  '17:44:80',
#  '17:44:90',
#  '17:44:10',
#  '17:44:11',
#  '17:44:12',
#  '17:44:13',
#  '17:44:14',
#  '17:44:15',
#  '17:44:16',
#  '17:44:17',
#  '17:44:18',
#  '17:44:19',
#  '17:44:20',
#  '17:44:21',
#  '17:44:22',
#  '17:44:23',
#  '17:44:24',
#  '17:44:25',
#  '17:44:26',
#  '17:44:27',
#  '17:44:28',
#  '17:44:29',
#  '17:44:30',
#  '17:44:31',
#  '17:44:32',
#  '17:44:33',
#  '17:44:34',
#  '17:44:35',
#  '17:44:36',
#  '17:44:37',
#  '17:44:38',
#  '17:44:39',
#  '17:44:40',
#  '17:44:41',
#  '17:44:42',
#  '17:44:43',
#  '17:44:44',
#  '17:44:45',
#  '17:44:46',
#  '17:44:47',
#  '17:44:48',
#  '17:44:49',
#  '17:44:50',
#  '17:44:51',
#  '17:44:52',
#  '17:44:53',
#  '17:44:54',
#  '17:44:55',
#  '17:44:56',
#  '17:44:57',
#  '17:44:58',
#  '17:44:59',
#  '17:45:00',
#  '17:45:10',
#  '17:45:20',
#  '17:45:30',
#  '17:45:40',
#  '17:45:50',
#  '17:45:60',
#  '17:45:70',
#  '17:45:80',
#  '17:45:90',
#  '17:45:10',
#  '17:45:11',
#  '17:45:12',
#  '17:45:13',
#  '17:45:14',
#  '17:45:15',
#  '17:45:16',
#  '17:45:17',
#  '17:45:18',
#  '17:45:19',
#  '17:45:20',
#  '17:45:21',
#  '17:45:22',
#  '17:45:23',
#  '17:45:24',
#  '17:45:25',
#  '17:45:26',
#  '17:45:27',
#  '17:45:28',
#  '17:45:29',
#  '17:45:30',
#  '17:45:31',
#  '17:45:32',
#  '17:45:33',
#  '17:45:34',
#  '17:45:35',
#  '17:45:36',
#  '17:45:37',
#  '17:45:38',
#  '17:45:39',
#  '17:45:40',
#  '17:45:41',
#  '17:45:42',
#  '17:45:43',
#  '17:45:44',
#  '17:45:45',
#  '17:45:46',
#  '17:45:47',
#  '17:45:48',
#  '17:45:49',
#  '17:45:50',
#  '17:45:51',
#  '17:45:52',
#  '17:45:53',
#  '17:45:54',
#  '17:45:55',
#  '17:45:56',
#  '17:45:57',
#  '17:45:58',
#  '17:45:59',
#  '17:46:00',
#  '17:46:10',
#  '17:46:20',
#  '17:46:30',
#  '17:46:40',
#  '17:46:50',
#  '17:46:60',
#  '17:46:70',
#  '17:46:80',
#  '17:46:90',
#  '17:46:10',
#  '17:46:11',
#  '17:46:12',
#  '17:46:13',
#  '17:46:14',
#  '17:46:15',
#  '17:46:16',
#  '17:46:17',
#  '17:46:18',
#  '17:46:19',
#  '17:46:20',
#  '17:46:21',
#  '17:46:22',
#  '17:46:23',
#  '17:46:24',
#  '17:46:25',
#  '17:46:26',
#  '17:46:27',
#  '17:46:28',
#  '17:46:29',
#  '17:46:30',
#  '17:46:31',
#  '17:46:32',
#  '17:46:33',
#  '17:46:34',
#  '17:46:35',
#  '17:46:36',
#  '17:46:37',
#  '17:46:38',
#  '17:46:39',
#  '17:46:40',
#  '17:46:41',
#  '17:46:42',
#  '17:46:43',
#  '17:46:44',
#  '17:46:45',
#  '17:46:46',
#  '17:46:47',
#  '17:46:48',
#  '17:46:49',
#  '17:46:50',
#  '17:46:51',
#  '17:46:52',
#  '17:46:53',
#  '17:46:54',
#  '17:46:55',
#  '17:46:56',
#  '17:46:57',
#  '17:46:58',
#  '17:46:59',
#  '17:47:00',
#  '17:47:10',
#  '17:47:20',
#  '17:47:30',
#  '17:47:40',
#  '17:47:50',
#  '17:47:60',
#  '17:47:70',
#  '17:47:80',
#  '17:47:90',
#  '17:47:10',
#  '17:47:11',
#  '17:47:12',
#  '17:47:13',
#  '17:47:14',
#  '17:47:15',
#  '17:47:16',
#  '17:47:17',
#  '17:47:18',
#  '17:47:19',
#  '17:47:20',
#  '17:47:21',
#  '17:47:22',
#  '17:47:23',
#  '17:47:24',
#  '17:47:25',
#  '17:47:26',
#  '17:47:27',
#  '17:47:28',
#  '17:47:29',
#  '17:47:30',
#  '17:47:31',
#  '17:47:32',
#  '17:47:33',
#  '17:47:34',
#  '17:47:35',
#  '17:47:36',
#  '17:47:37',
#  '17:47:38',
#  '17:47:39',
#  '17:47:40',
#  '17:47:41',
#  '17:47:42',
#  '17:47:43',
#  '17:47:44',
#  '17:47:45',
#  '17:47:46',
#  '17:47:47',
#  '17:47:48',
#  '17:47:49',
#  '17:47:50',
#  '17:47:51',
#  '17:47:52',
#  '17:47:53',
#  '17:47:54',
#  '17:47:55',
#  '17:47:56',
#  '17:47:57',
#  '17:47:58',
#  '17:47:59',
#  '17:48:00',
#  '17:48:10',
#  '17:48:20',
#  '17:48:30',
#  '17:48:40',
#  '17:48:50',
#  '17:48:60',
#  '17:48:70',
#  '17:48:80',
#  '17:48:90',
#  '17:48:10',
#  '17:48:11',
#  '17:48:12',
#  '17:48:13',
#  '17:48:14',
#  '17:48:15',
#  '17:48:16',
#  '17:48:17',
#  '17:48:18',
#  '17:48:19',
#  '17:48:20',
#  '17:48:21',
#  '17:48:22',
#  '17:48:23',
#  '17:48:24',
#  '17:48:25',
#  '17:48:26',
#  '17:48:27',
#  '17:48:28',
#  '17:48:29',
#  '17:48:30',
#  '17:48:31',
#  '17:48:32',
#  '17:48:33',
#  '17:48:34',
#  '17:48:35',
#  '17:48:36',
#  '17:48:37',
#  '17:48:38',
#  '17:48:39',
#  '17:48:40',
#  '17:48:41',
#  '17:48:42',
#  '17:48:43',
#  '17:48:44',
#  '17:48:45',
#  '17:48:46',
#  '17:48:47',
#  '17:48:48',
#  '17:48:49',
#  '17:48:50',
#  '17:48:51',
#  '17:48:52',
#  '17:48:53',
#  '17:48:54',
#  '17:48:55',
#  '17:48:56',
#  '17:48:57',
#  '17:48:58',
#  '17:48:59',
#  '17:49:00',
#  '17:49:10',
#  '17:49:20',
#  '17:49:30',
#  '17:49:40',
#  '17:49:50',
#  '17:49:60',
#  '17:49:70',
#  '17:49:80',
#  '17:49:90',
#  '17:49:10',
#  '17:49:11',
#  '17:49:12',
#  '17:49:13',
#  '17:49:14',
#  '17:49:15',
#  '17:49:16',
#  '17:49:17',
#  '17:49:18',
#  '17:49:19',
#  '17:49:20',
#  '17:49:21',
#  '17:49:22',
#  '17:49:23',
#  '17:49:24',
#  '17:49:25',
#  '17:49:26',
#  '17:49:27',
#  '17:49:28',
#  '17:49:29',
#  '17:49:30',
#  '17:49:31',
#  '17:49:32',
#  '17:49:33',
#  '17:49:34',
#  '17:49:35',
#  '17:49:36',
#  '17:49:37',
#  '17:49:38',
#  '17:49:39',
#  '17:49:40',
#  '17:49:41',
#  '17:49:42',
#  '17:49:43',
#  '17:49:44',
#  '17:49:45',
#  '17:49:46',
#  '17:49:47',
#  '17:49:48',
#  '17:49:49',
#  '17:49:50',
#  '17:49:51',
#  '17:49:52',
#  '17:49:53',
#  '17:49:54',
#  '17:49:55',
#  '17:49:56',
#  '17:49:57',
#  '17:49:58',
#  '17:49:59',
#  '17:50:00',
#  '17:50:10',
#  '17:50:20',
#  '17:50:30',
#  '17:50:40',
#  '17:50:50',
#  '17:50:60',
#  '17:50:70',
#  '17:50:80',
#  '17:50:90',
#  '17:50:10',
#  '17:50:11',
#  '17:50:12',
#  '17:50:13',
#  '17:50:14',
#  '17:50:15',
#  '17:50:16',
#  '17:50:17',
#  '17:50:18',
#  '17:50:19',
#  '17:50:20',
#  '17:50:21',
#  '17:50:22',
#  '17:50:23',
#  '17:50:24',
#  '17:50:25',
#  '17:50:26',
#  '17:50:27',
#  '17:50:28',
#  '17:50:29',
#  '17:50:30',
#  '17:50:31',
#  '17:50:32',
#  '17:50:33',
#  '17:50:34',
#  '17:50:35',
#  '17:50:36',
#  '17:50:37',
#  '17:50:38',
#  '17:50:39',
#  '17:50:40',
#  '17:50:41',
#  '17:50:42',
#  '17:50:43',
#  '17:50:44',
#  '17:50:45',
#  '17:50:46',
#  '17:50:47',
#  '17:50:48',
#  '17:50:49',
#  '17:50:50',
#  '17:50:51',
#  '17:50:52',
#  '17:50:53',
#  '17:50:54',
#  '17:50:55',
#  '17:50:56',
#  '17:50:57',
#  '17:50:58',
#  '17:50:59',
#  '17:51:00',
#  '17:51:10',
#  '17:51:20',
#  '17:51:30',
#  '17:51:40',
#  '17:51:50',
#  '17:51:60',
#  '17:51:70',
#  '17:51:80',
#  '17:51:90',
#  '17:51:10',
#  '17:51:11',
#  '17:51:12',
#  '17:51:13',
#  '17:51:14',
#  '17:51:15',
#  '17:51:16',
#  '17:51:17',
#  '17:51:18',
#  '17:51:19',
#  '17:51:20',
#  '17:51:21',
#  '17:51:22',
#  '17:51:23',
#  '17:51:24',
#  '17:51:25',
#  '17:51:26',
#  '17:51:27',
#  '17:51:28',
#  '17:51:29',
#  '17:51:30',
#  '17:51:31',
#  '17:51:32',
#  '17:51:33',
#  '17:51:34',
#  '17:51:35',
#  '17:51:36',
#  '17:51:37',
#  '17:51:38',
#  '17:51:39',
#  '17:51:40',
#  '17:51:41',
#  '17:51:42',
#  '17:51:43',
#  '17:51:44',
#  '17:51:45',
#  '17:51:46',
#  '17:51:47',
#  '17:51:48',
#  '17:51:49',
#  '17:51:50',
#  '17:51:51',
#  '17:51:52',
#  '17:51:53',
#  '17:51:54',
#  '17:51:55',
#  '17:51:56',
#  '17:51:57',
#  '17:51:58',
#  '17:51:59',
#  '17:52:00',
#  '17:52:10',
#  '17:52:20',
#  '17:52:30',
#  '17:52:40',
#  '17:52:50',
#  '17:52:60',
#  '17:52:70',
#  '17:52:80',
#  '17:52:90',
#  '17:52:10',
#  '17:52:11',
#  '17:52:12',
#  '17:52:13',
#  '17:52:14',
#  '17:52:15',
#  '17:52:16',
#  '17:52:17',
#  '17:52:18',
#  '17:52:19',
#  '17:52:20',
#  '17:52:21',
#  '17:52:22',
#  '17:52:23',
#  '17:52:24',
#  '17:52:25',
#  '17:52:26',
#  '17:52:27',
#  '17:52:28',
#  '17:52:29',
#  '17:52:30',
#  '17:52:31',
#  '17:52:32',
#  '17:52:33',
#  '17:52:34',
#  '17:52:35',
#  '17:52:36',
#  '17:52:37',
#  '17:52:38',
#  '17:52:39',
#  '17:52:40',
#  '17:52:41',
#  '17:52:42',
#  '17:52:43',
#  '17:52:44',
#  '17:52:45',
#  '17:52:46',
#  '17:52:47',
#  '17:52:48',
#  '17:52:49',
#  '17:52:50',
#  '17:52:51',
#  '17:52:52',
#  '17:52:53',
#  '17:52:54',
#  '17:52:55',
#  '17:52:56',
#  '17:52:57',
#  '17:52:58',
#  '17:52:59',
#  '17:53:00',
#  '17:53:10',
#  '17:53:20',
#  '17:53:30',
#  '17:53:40',
#  '17:53:50',
#  '17:53:60',
#  '17:53:70',
#  '17:53:80',
#  '17:53:90',
#  '17:53:10',
#  '17:53:11',
#  '17:53:12',
#  '17:53:13',
#  '17:53:14',
#  '17:53:15',
#  '17:53:16',
#  '17:53:17',
#  '17:53:18',
#  '17:53:19',
#  '17:53:20',
#  '17:53:21',
#  '17:53:22',
#  '17:53:23',
#  '17:53:24',
#  '17:53:25',
#  '17:53:26',
#  '17:53:27',
#  '17:53:28',
#  '17:53:29',
#  '17:53:30',
#  '17:53:31',
#  '17:53:32',
#  '17:53:33',
#  '17:53:34',
#  '17:53:35',
#  '17:53:36',
#  '17:53:37',
#  '17:53:38',
#  '17:53:39',
#  '17:53:40',
#  '17:53:41',
#  '17:53:42',
#  '17:53:43',
#  '17:53:44',
#  '17:53:45',
#  '17:53:46',
#  '17:53:47',
#  '17:53:48',
#  '17:53:49',
#  '17:53:50',
#  '17:53:51',
#  '17:53:52',
#  '17:53:53',
#  '17:53:54',
#  '17:53:55',
#  '17:53:56',
#  '17:53:57',
#  '17:53:58',
#  '17:53:59',
#  '17:54:00',
#  '17:54:10',
#  '17:54:20',
#  '17:54:30',
#  '17:54:40',
#  '17:54:50',
#  '17:54:60',
#  '17:54:70',
#  '17:54:80',
#  '17:54:90',
#  '17:54:10',
#  '17:54:11',
#  '17:54:12',
#  '17:54:13',
#  '17:54:14',
#  '17:54:15',
#  '17:54:16',
#  '17:54:17',
#  '17:54:18',
#  '17:54:19',
#  '17:54:20',
#  '17:54:21',
#  '17:54:22',
#  '17:54:23',
#  '17:54:24',
#  '17:54:25',
#  '17:54:26',
#  '17:54:27',
#  '17:54:28',
#  '17:54:29',
#  '17:54:30',
#  '17:54:31',
#  '17:54:32',
#  '17:54:33',
#  '17:54:34',
#  '17:54:35',
#  '17:54:36',
#  '17:54:37',
#  '17:54:38',
#  '17:54:39',
#  '17:54:40',
#  '17:54:41',
#  '17:54:42',
#  '17:54:43',
#  '17:54:44',
#  '17:54:45',
#  '17:54:46',
#  '17:54:47',
#  '17:54:48',
#  '17:54:49',
#  '17:54:50',
#  '17:54:51',
#  '17:54:52',
#  '17:54:53',
#  '17:54:54',
#  '17:54:55',
#  '17:54:56',
#  '17:54:57',
#  '17:54:58',
#  '17:54:59',
#  '17:55:00',
#  '17:55:10',
#  '17:55:20',
#  '17:55:30',
#  '17:55:40',
#  '17:55:50',
#  '17:55:60',
#  '17:55:70',
#  '17:55:80',
#  '17:55:90',
#  '17:55:10',
#  '17:55:11',
#  '17:55:12',
#  '17:55:13',
#  '17:55:14',
#  '17:55:15',
#  '17:55:16',
#  '17:55:17',
#  '17:55:18',
#  '17:55:19',
#  '17:55:20',
#  '17:55:21',
#  '17:55:22',
#  '17:55:23',
#  '17:55:24',
#  '17:55:25',
#  '17:55:26',
#  '17:55:27',
#  '17:55:28',
#  '17:55:29',
#  '17:55:30',
#  '17:55:31',
#  '17:55:32',
#  '17:55:33',
#  '17:55:34',
#  '17:55:35',
#  '17:55:36',
#  '17:55:37',
#  '17:55:38',
#  '17:55:39',
#  '17:55:40',
#  '17:55:41',
#  '17:55:42',
#  '17:55:43',
#  '17:55:44',
#  '17:55:45',
#  '17:55:46',
#  '17:55:47',
#  '17:55:48',
#  '17:55:49',
#  '17:55:50',
#  '17:55:51',
#  '17:55:52',
#  '17:55:53',
#  '17:55:54',
#  '17:55:55',
#  '17:55:56',
#  '17:55:57',
#  '17:55:58',
#  '17:55:59',
#  '17:56:00',
#  '17:56:10',
#  '17:56:20',
#  '17:56:30',
#  '17:56:40',
#  '17:56:50',
#  '17:56:60',
#  '17:56:70',
#  '17:56:80',
#  '17:56:90',
#  '17:56:10',
#  '17:56:11',
#  '17:56:12',
#  '17:56:13',
#  '17:56:14',
#  '17:56:15',
#  '17:56:16',
#  '17:56:17',
#  '17:56:18',
#  '17:56:19',
#  '17:56:20',
#  '17:56:21',
#  '17:56:22',
#  '17:56:23',
#  '17:56:24',
#  '17:56:25',
#  '17:56:26',
#  '17:56:27',
#  '17:56:28',
#  '17:56:29',
#  '17:56:30',
#  '17:56:31',
#  '17:56:32',
#  '17:56:33',
#  '17:56:34',
#  '17:56:35',
#  '17:56:36',
#  '17:56:37',
#  '17:56:38',
#  '17:56:39',
#  '17:56:40',
#  '17:56:41',
#  '17:56:42',
#  '17:56:43',
#  '17:56:44',
#  '17:56:45',
#  '17:56:46',
#  '17:56:47',
#  '17:56:48',
#  '17:56:49',
#  '17:56:50',
#  '17:56:51',
#  '17:56:52',
#  '17:56:53',
#  '17:56:54',
#  '17:56:55',
#  '17:56:56',
#  '17:56:57',
#  '17:56:58',
#  '17:56:59',
#  '17:57:00',
#  '17:57:10',
#  '17:57:20',
#  '17:57:30',
#  '17:57:40',
#  '17:57:50',
#  '17:57:60',
#  '17:57:70',
#  '17:57:80',
#  '17:57:90',
#  '17:57:10',
#  '17:57:11',
#  '17:57:12',
#  '17:57:13',
#  '17:57:14',
#  '17:57:15',
#  '17:57:16',
#  '17:57:17',
#  '17:57:18',
#  '17:57:19',
#  '17:57:20',
#  '17:57:21',
#  '17:57:22',
#  '17:57:23',
#  '17:57:24',
#  '17:57:25',
#  '17:57:26',
#  '17:57:27',
#  '17:57:28',
#  '17:57:29',
#  '17:57:30',
#  '17:57:31',
#  '17:57:32',
#  '17:57:33',
#  '17:57:34',
#  '17:57:35',
#  '17:57:36',
#  '17:57:37',
#  '17:57:38',
#  '17:57:39',
#  '17:57:40',
#  '17:57:41',
#  '17:57:42',
#  '17:57:43',
#  '17:57:44',
#  '17:57:45',
#  '17:57:46',
#  '17:57:47',
#  '17:57:48',
#  '17:57:49',
#  '17:57:50',
#  '17:57:51',
#  '17:57:52',
#  '17:57:53',
#  '17:57:54',
#  '17:57:55',
#  '17:57:56',
#  '17:57:57',
#  '17:57:58',
#  '17:57:59',
#  '17:58:00',
#  '17:58:10',
#  '17:58:20',
#  '17:58:30',
#  '17:58:40',
#  '17:58:50',
#  '17:58:60',
#  '17:58:70',
#  '17:58:80',
#  '17:58:90',
#  '17:58:10',
#  '17:58:11',
#  '17:58:12',
#  '17:58:13',
#  '17:58:14',
#  '17:58:15',
#  '17:58:16',
#  '17:58:17',
#  '17:58:18',
#  '17:58:19',
#  '17:58:20',
#  '17:58:21',
#  '17:58:22',
#  '17:58:23',
#  '17:58:24',
#  '17:58:25',
#  '17:58:26',
#  '17:58:27',
#  '17:58:28',
#  '17:58:29',
#  '17:58:30',
#  '17:58:31',
#  '17:58:32',
#  '17:58:33',
#  '17:58:34',
#  '17:58:35',
#  '17:58:36',
#  '17:58:37',
#  '17:58:38',
#  '17:58:39',
#  '17:58:40',
#  '17:58:41',
#  '17:58:42',
#  '17:58:43',
#  '17:58:44',
#  '17:58:45',
#  '17:58:46',
#  '17:58:47',
#  '17:58:48',
#  '17:58:49',
#  '17:58:50',
#  '17:58:51',
#  '17:58:52',
#  '17:58:53',
#  '17:58:54',
#  '17:58:55',
#  '17:58:56',
#  '17:58:57',
#  '17:58:58',
#  '17:58:59',
#  '17:59:00',
#  '17:59:10',
#  '17:59:20',
#  '17:59:30',
#  '17:59:40',
#  '17:59:50',
#  '17:59:60',
#  '17:59:70',
#  '17:59:80',
#  '17:59:90',
#  '17:59:10',
#  '17:59:11',
#  '17:59:12',
#  '17:59:13',
#  '17:59:14',
#  '17:59:15',
#  '17:59:16',
#  '17:59:17',
#  '17:59:18',
#  '17:59:19',
#  '17:59:20',
#  '17:59:21',
#  '17:59:22',
#  '17:59:23',
#  '17:59:24',
#  '17:59:25',
#  '17:59:26',
#  '17:59:27',
#  '17:59:28',
#  '17:59:29',
#  '17:59:30',
#  '17:59:31',
#  '17:59:32',
#  '17:59:33',
#  '17:59:34',
#  '17:59:35',
#  '17:59:36',
#  '17:59:37',
#  '17:59:38',
#  '17:59:39',
#  '17:59:40',
#  '17:59:41',
#  '17:59:42',
#  '17:59:43',
#  '17:59:44',
#  '17:59:45',
#  '17:59:46',
#  '17:59:47',
#  '17:59:48',
#  '17:59:49',
#  '17:59:50',
#  '17:59:51',
#  '17:59:52',
#  '17:59:53',
#  '17:59:54',
#  '17:59:55']

# %%
files_buoys = glob.glob(base+date+'/boueeVague/*/mat/*.mat')#/*/*.srt')
pprint(files_buoys)
# Out:
# ['/Volumes/Hublot24/Share_hublot/Data/0223/boueeVague/B1/mat/buoy1_sbg_20240223_1700.mat',
#  '/Volumes/Hublot24/Share_hublot/Data/0223/boueeVague/B1/mat/buoy1_sbg_20240223_1800.mat',
#  '/Volumes/Hublot24/Share_hublot/Data/0223/boueeVague/B2/mat/buoy2_sbg_20240223_1700.mat',
#  '/Volumes/Hublot24/Share_hublot/Data/0223/boueeVague/B2/mat/buoy2_sbg_20240223_1800.mat',
#  '/Volumes/Hublot24/Share_hublot/Data/0223/boueeVague/B4/mat/buoy4_sbg_20240223_1700.mat',
#  '/Volumes/Hublot24/Share_hublot/Data/0223/boueeVague/B4/mat/buoy4_sbg_20240223_1800.mat',
#  '/Volumes/Hublot24/Share_hublot/Data/0223/boueeVague/B5/mat/buoy5_sbg_20240223_1700.mat',
#  '/Volumes/Hublot24/Share_hublot/Data/0223/boueeVague/B5/mat/buoy5_sbg_20240223_1800.mat']

# %%
import icewave.field.buoys as buoys_read

records_buoys = buoys_read.get_records(date)
# Out:
# /Volumes/Hublot24/Share_hublot/Data/0223/boueeVague/B1/mat/buoy1_sbg_20240223_1700.mat
# /Volumes/Hublot24/Share_hublot/Data/0223/boueeVague/B1/mat/buoy1_sbg_20240223_1800.mat
# /Volumes/Hublot24/Share_hublot/Data/0223/boueeVague/B2/mat/buoy2_sbg_20240223_1700.mat
# /Volumes/Hublot24/Share_hublot/Data/0223/boueeVague/B2/mat/buoy2_sbg_20240223_1800.mat
# /Volumes/Hublot24/Share_hublot/Data/0223/boueeVague/B4/mat/buoy4_sbg_20240223_1700.mat
# /Volumes/Hublot24/Share_hublot/Data/0223/boueeVague/B4/mat/buoy4_sbg_20240223_1800.mat
# /Volumes/Hublot24/Share_hublot/Data/0223/boueeVague/B5/mat/buoy5_sbg_20240223_1700.mat
# /Volumes/Hublot24/Share_hublot/Data/0223/boueeVague/B5/mat/buoy5_sbg_20240223_1800.mat

# %%
records_buoys['buoys']['B1'][0].keys()
# Out:
# dict_keys(['time', 'latitude', 'longitude'])

# %%
buoys={}
for filename in files_buoys:
    name = filename.split('/')[-3]
    print(name)
    if not name in buoys.keys():
        buoys[name]=[]
    data_buoy = h5py.File(filename)
    buoys[name].append(data_buoy)
# Out:
# B1
# B1
# B2
# B2
# B4
# B4
# B5
# B5

# %%
buoys['B1'][0]['IMU']['GPS1_POS'].keys()
# Out:
# <KeysViewHDF5 ['ALT', 'BASE_STATION_ID', 'CRC', 'CRC_CALC', 'DIFF_AGE', 'GPS_POS_STATUS', 'GPS_TOW', 'LAT', 'LONG', 'NUM_SV_USED', 'POS_ACC_ALT', 'POS_ACC_LAT', 'POS_ACC_LONG', 'TIME_STAMP', 'TS_fix', 'UNDULATION', 't', 'time']>

# %%
print(buoys['B1'][0]['IMU']['GPS1_POS']['LAT'][0])#.keys()
print(buoys['B1'][0]['IMU']['GPS1_POS']['LONG'][0])
# Out:
# [-68.8517424 -68.8517429 -68.8517428 ... -68.8517521 -68.8517522
#  -68.8517523]

# %%
record_buoys={}
for name in buoys.keys():
    record_buoys[name]={}
    for i,buoy in enumerate(buoys[name]):
        record_buoys[name][i]={}
        hours = buoy['IMU']['UTC_TIME']['HOUR'][:][0]#.keys()
        mins = buoy['IMU']['UTC_TIME']['MIN'][:][0]#.keys()
        secs = buoy['IMU']['UTC_TIME']['SEC'][:][0]#.keys()
        times = [str(int(hour))+':'+str(int(m))+':'+str(sec).replace('.','')[:2] for (hour,m,sec) in zip(hours,mins,secs)]
        print(times[0],times[-1])
        record_buoys[name][i]['times']=times
# Out:
# 17:34:30 17:59:55
# 17:59:56 18:42:27
# 17:35:54 17:59:58
# 17:59:59 18:42:39
# 17:37:58 18:0:20
# 18:0:30 18:40:10
# 17:40:20 17:59:56
# 17:59:57 18:36:54

# %%
pprint(record_buoys.keys())
# Out:
# dict_keys(['B1', 'B2', 'B4', 'B5'])

# %%
fig = plt.figure(figsize=(10,10))
ax = fig.add_subplot(111)

import matplotlib.dates as mdates

b=0.4
for (record,name) in zip(records_b,srtfiles_bernache):
    try:
        title = name.split('/')[-2].split('-')[1]#.split('_')[0]
    except:
        title = name.split('/')[-2]

    times = [record[key]['time'] for key in record.keys()]
    x = [times[0],times[-1]]
    x = np.asarray([convert(x[0]),convert(x[1])])
    
    r=np.random.random()*b
    y0 = 1.3
    ax.plot(x/3600, [y0+r,y0+r],'ko-')
    #display_text(x,y,title,ax=ax)
    ax.text(x[0]/3600,y0+0.01+r,title)
    #print(convert(x[0]))

for (record,name) in zip(records_m,srtfiles_mesange):
    try:
        title = name.split('/')[-2].split('-')[1]#.split('_')[0]
    except:
        title = name.split('/')[-2]

    times = [record[key]['time'] for key in record.keys()]
    x = [times[0],times[-1]]
    x = np.asarray([convert(x[0])-3600*6,convert(x[1])-3600*6])
    
    r=np.random.random()*b
    ax.plot(x/3600, [y0+b+r,y0+b+r],'bo-')
    ax.text(x[0]/3600,y0+b+0.01+r,title)
    #print(convert(x[0]))
    
X = {}
for i,phone in enumerate(phonedict.keys()):
    t0 = phonedict[phone]['time_start'].split(' ')[1][:-4]#.keys())
    t1 = phonedict[phone]['time_end'].split(' ')[1][:-4]
    print(t0,t1)
    X[i] = np.asarray([convert(t0)-3600*6,convert(t1)-3600*6])
    
    if X[i][0]/3600<11:
        X[i]=X[i-1]
    r=i*0.05#np.random.random()*b
    ax.plot(X[i]/3600, [2.1+r,2.1+r],'rs-')
    ax.text(X[i][0]/3600-0.2,2.1+r,'S'+str(phone))

#    ax.plot()
    #.keys())

X={}
first={}
for num in records_geo.keys():
    first[num]=True
for i,num in enumerate(records_geo.keys()):
    for key in records_geo[num]:
        if records_geo[num][key]['date']=='2024/02/23':

            t0 = records_geo[num][key]['times'][0]
            t1 = records_geo[num][key]['times'][-1]
            
            X[num] = np.asarray([convert(t0)-3600*5,convert(t1)-3600*5])

            r=i*0.05#np.random.random()*b
            ax.plot(X[num]/3600, [0.5+r,0.5+r],'g>-')
            if first[num]:
                ax.text(X[num][0]/3600-0.3,0.5+r,num)
                first[num]=False

            
for i,name in enumerate(record_buoys.keys()):
    print(name)
    for j,key in enumerate(record_buoys[name].keys()):
        t0 = record_buoys[name][key]['times'][0]
        t1 = record_buoys[name][key]['times'][-1]    
        
        X[num] = np.asarray([convert(t0)-3600*5,convert(t1)-3600*5])

        r=i*0.05#np.random.random()*b
        ax.plot(X[num]/3600, [0.2+r,0.2+r],'ro-')
        if j==0:
            ax.text(X[num][0]/3600-0.2,0.2+r,name)

plt.ylim(0,2.8)
hours = [11,12,13,14,15,16]
ax.set_xticks(hours,[str(h)+':00' for h in hours])


from matplotlib.lines import Line2D


# access legend objects automatically created from data
handles, labels = plt.gca().get_legend_handles_labels()
# create manual symbols for legend
#patch = mpatches.Patch(color='grey', label='manual patch')   
#line = Line2D([0], [0], label='manual line', color='k')
names = {'Smartphones':('r','s'),'Mesange':('b','o'),'Bernache':('k','o'),'Geophones':('g','>'),'Buoys':('r','o')}
legends = []
for key in names.keys():
    point = Line2D([0], [0], label=key, marker=names[key][1], markersize=10, 
         markeredgecolor=names[key][0], markerfacecolor=names[key][0], linestyle='')
    legends.append(point)

# add manual symbols to auto legend
handles.extend(legends)

plt.legend(handles=handles)
#plt.show()


#ax.xaxis.set_major_formatter(mdates.DateFormatter('%H:%M:%S'))
#ax.set_xlim(['11:30:00','15:00:00'])
#ax.xaxis.set_major_formatter(mdates.DateFormatter('%h-%m-%s'))
#fig.autofmt_xdate()

figs = graphes.legende('Local time','Instruments',date)
graphes.save_figs(figs,savedir=savefolder,overwrite=True)
graphes.save_figs(figs,savedir=savefolder_local,overwrite=True,prefix=date+'_')
# Out:
# 18:47:40 19:38:08
# 18:47:43 19:36:04
# 18:47:37 19:40:04
# 18:47:41 19:40:58
# 18:47:27 19:41:14
# 05:57:50 06:53:09
# 18:47:15 19:43:19
# 18:47:12 19:43:16
# 06:05:16 06:59:53
# 18:47:36 19:43:07
# B1
# B2
# B4
# B5

# %%
datas = {}

for i,(result,head) in enumerate(zip(results,headers)):
    header = result[0]
    core = result[1:]
    #print(core)

    try:
        print(np.asarray(core).shape)
    except:
        lengths = [len(c) for c in core]
        print(lengths)
        n = np.max(lengths)
        indices = np.where(lengths<n)[0]
        
        for indice in indices[::-1]:
            print("Missing data for phone : "+str(core[indice][0]))
            print(indice)
            del core[indice]
        
        lengths = [len(c) for c in core]
        print(lengths)

    data={}
    data['d']={}
    for j,key in enumerate(header):
        data['d'][key]=np.asarray(core)[:,j]
        data['date']=head['date']
        data['name']=head['name']

    datas[i]=data
# Out:
# (12, 62)
# (13, 62)
# (10, 62)
# [62, 56, 62, 62, 62, 62, 62, 62, 62, 62, 62]
# Missing data for phone : 1
# 1
# [62, 62, 62, 62, 62, 62, 62, 62, 62, 62]

# %%
pprint(data['d'].keys())
# Out:
# dict_keys(['Phone', 'ax_err', 'ax_w_mean', 'ax_high_mean', 'ax_trend_mean', 'ax_w_std', 'ax_high_std', 'ax_trend_std', 'ay_err', 'ay_w_mean', 'ay_high_mean', 'ay_trend_mean', 'ay_w_std', 'ay_high_std', 'ay_trend_std', 'az_err', 'az_w_mean', 'az_high_mean', 'az_trend_mean', 'az_w_std', 'az_high_std', 'az_trend_std', 'gx_err', 'gx_w_std', 'gx_high_std', 'gx_trend_std', 'gy_err', 'gy_w_std', 'gy_high_std', 'gy_trend_std', 'gz_err', 'gz_w_std', 'gz_high_std', 'gz_trend_std', 'mx_err', 'mx_w_mean', 'mx_high_mean', 'mx_trend_mean', 'mx_w_std', 'mx_high_std', 'mx_trend_std', 'my_err', 'my_w_mean', 'my_high_mean', 'my_trend_mean', 'my_w_std', 'my_high_std', 'my_trend_std', 'mz_err', 'mz_w_mean', 'mz_high_mean', 'mz_trend_mean', 'mz_w_std', 'mz_high_std', 'mz_trend_std', 'az_w_freq', 'elev_mean', 'elev_std', 'lat_mean', 'lat_std', 'lon_mean', 'lon_std'])

# %%
pprint(datas[2]['d']['az_w_freq'])
# Out:
# array([0.07057639, 0.06704901, 0.07124301, 0.07095251, 0.06887194,
#        0.07250722, 0.06366642, 0.06932231, 0.07318105, 0.06787604])

# %%
datas.keys()
# Out:
# dict_keys([0, 1, 2, 3])

# %%
datas[0].keys()
data = datas[0]

for k in datas.keys():
    data = datas[k]['d']
    for key in data.keys():
        if key == 'Phone':
            data[key] = data[key].astype(int)
        else:
            data[key] = data[key].astype(float)
    datas[k]['d']=data

# %%
import matplotlib.lines as mlines


fig,ax = plt.subplots(figsize=(8,6))


varx = 'x'
vary = 'z'
xth = np.logspace(-3,0,100)

colors = ['k','r','b','g']
marker = 'o'
patches= []
for k in datas.keys():
    data = datas[k]['d']
    date = datas[k]['date']
    if date=='0221':
        name = datas[k]['name'].split('_')[-1]
        if name=='withgeophones':
            continue
    date = date[:2]+'/'+date[-2:]
    color = colors[k]
    xs = data[f'az_w_freq']
    ys = data[f'a{vary}_w_std']
    for i,(x,y) in enumerate(zip(xs,ys)):
        phone = data['Phone'][i]
        ax.scatter(x,y,marker=marker,color=color,s=30)
        ax.text(x*0.97,y*1.1,phone)

    ax.set_xlim(0.05,2)
    ax.set_ylim(0.005,5)
    
    patch = mlines.Line2D([], [], color=color, marker=marker,markersize=6,linestyle='None', label=date)
#    patch = mpatches.Patch(color=color, label=k)
    patches.append(patch)

#    patch = mlines.Line2D([], [], color=color, marker=marker,markersize=6,linestyle='None', label=date)
#    patch = mpatches.Patch(color=color, label=k)
#    patches.append(patch)

ax.legend(handles=patches,loc='upper left')
    #ax.plot(xth,xth*4,'r--')
ax.set_xscale('log')
ax.set_yscale('log')
figs = graphes.legende(f'$f$ (Hz)',r'$a_{'+vary+r'}$ (m/s$^{-2}$)','')
#graphes.save_figs(figs,savedir=savefolder,prefix='Bic_February_')

# %%
import matplotlib.lines as mlines


fig,ax = plt.subplots(figsize=(8,6))


varx = 'x'
vary = 'y'
xth = np.logspace(-3,0,100)

colors = ['k','r','b','g']
marker = 'o'
patches= []
for k in datas.keys():
    data = datas[k]['d']
    date = datas[k]['date']
    if date=='0221':
        name = datas[k]['name'].split('_')[-1]
        if name=='withgeophones':
            continue
    date = date[:2]+'/'+date[-2:]
    color = colors[k]
    xs = data[f'g{varx}_w_std']
    ys = data[f'a{vary}_w_std']
    for i,(x,y) in enumerate(zip(xs,ys)):
        phone = data['Phone'][i]
        ax.scatter(x,y,marker=marker,color=color,s=30)
        ax.text(x*0.97,y*1.1,phone)

    ax.set_xlim(0.001,2)
    ax.set_ylim(0.002,5)
    
    patch = mlines.Line2D([], [], color=color, marker=marker,markersize=6,linestyle='None', label=date)
#    patch = mpatches.Patch(color=color, label=k)
    patches.append(patch)

ax.legend(handles=patches,loc='upper left')
    #ax.plot(xth,xth*4,'r--')
ax.set_xscale('log')
ax.set_yscale('log')
figs = graphes.legende(f'$g_{varx}$ (rad/s)',r'$a_{'+vary+r'}$ (m/s$^{-2}$)','')
#graphes.save_figs(figs,savedir=savefolder,prefix='Bic_February_')

# %%
import matplotlib.lines as mlines
import matplotlib.patches as plt_patches

import icewave.gps.gps as gps
fig,axs = plt.subplots(figsize=(10,4),ncols=2)

k = 2

colors = ['k','r','b','g']
marker = 'o'
patches= []
data = datas[k]['d']
date = datas[k]['date']
date_raw = date

date = date[:2]+'/'+date[-2:]
color = colors[k]
xs = data[f'lon_mean']
ys = data[f'lat_mean']

radius = 6371*10**3
[xs,ys] = gps.project(xs,ys)

xs = xs*radius*np.pi*2
ys = ys*radius*np.pi*2
xs = xs - np.mean(xs)
ys = ys - np.mean(ys)


#print(ys*radius-np.mean(ys*radius))
#stdxs = data[f'lon_std']
#stdys = data[f'lat_std']
#[stdxs,stdys] = gps.project(stdxs,stdys)

for i,(x,y,stdx,stdy) in enumerate(zip(xs,ys,stdxs,stdys)):
    phone = data['Phone'][i]
    axs[0].scatter(x,y,marker='s',color='r',s=50)
    #ellipse = plt_patches.Ellipse((x,y), stdx/10, stdy/10,color=color,fill=False)
    axs[0].text(x,y+3,phone)
    #ax.add_artist(ellipse)
    

axs[0].scatter(0,0,marker='x',color='k',s=50)
axs[0].set_xlim(-60,60)
axs[0].set_ylim(-45,45)

#patch = mlines.Line2D([], [], color=color, marker=marker,markersize=6,linestyle='None', label=date)
#    patch = mpatches.Patch(color=color, label=k)
#patches.append(patch)

#ax.legend(handles=patches,loc='upper left')
#ax.plot(xth,xth*4,'r--')
#ax.set_xscale('log')
#ax.set_yscale('log')
figs = graphes.legende(f'Distance (m)',f'Distance (m)',date,ax=axs[0])

#second axis

ys = data['az_w_std']
axs[1].plot(xs,ys,'ko')
axs[1].set_xlim(-60,60)
axs[1].set_ylim(0,2)

figs = graphes.legende(f'Distance (m)',r'$a_z$ (m/s$^{-2})$',date,ax=axs[1])
#graphes.save_figs(figs,savedir=savefolder,prefix='Bic_February_'+date_raw+'_map_1_damping')
#graphes.save_figs(figs,savedir=savefolder_local,prefix='Bic_February_'+date_raw+'_map_1_damping')

# %%
import matplotlib.lines as mlines
import matplotlib.patches as plt_patches

import icewave.gps.gps as gps
fig,axs = plt.subplots(figsize=(10,4),ncols=2)

k = 0

colors = ['k','r','b','g']
marker = 'o'
patches= []
data = datas[k]['d']
date = datas[k]['date']
date_raw = date

date = date[:2]+'/'+date[-2:]
color = colors[k]
xs = data[f'lon_mean']
ys = data[f'lat_mean']

radius = 6371*10**3
[xs,ys] = gps.project(xs,ys)

xs = xs*radius*np.pi*2
ys = ys*radius*np.pi*2
xs = xs - np.mean(xs)
ys = ys - np.mean(ys)


#print(ys*radius-np.mean(ys*radius))
#stdxs = data[f'lon_std']
#stdys = data[f'lat_std']
#[stdxs,stdys] = gps.project(stdxs,stdys)

for i,(x,y,stdx,stdy) in enumerate(zip(xs,ys,stdxs,stdys)):
    phone = data['Phone'][i]
    print(x,y)
    axs[0].scatter(x,y,marker='s',color='r',s=50)
    #ellipse = plt_patches.Ellipse((x,y), stdx/10, stdy/10,color=color,fill=False)
    axs[0].text(x-2+15*(i%2-1./2),y-2,phone)
    #ax.add_artist(ellipse)
    

axs[0].scatter(0,0,marker='x',color='k',s=50)
axs[0].set_ylim(-40,40)
axs[0].set_xlim(-40,40)

#patch = mlines.Line2D([], [], color=color, marker=marker,markersize=6,linestyle='None', label=date)
#    patch = mpatches.Patch(color=color, label=k)
#patches.append(patch)
figs = graphes.legende(f'Distance (m)',f'Distance (m)',date,ax=axs[0])


xs = data['az_w_std']
axs[1].plot(ys,xs,'ko')
axs[1].set_xlim(-40,40)
axs[1].set_ylim(0,0.05)


figs = graphes.legende(f'Distance (m)',r'$a_z$ (m/s$^{-2})$',date,ax=axs[1])

#ax.legend(handles=patches,loc='upper left')
#ax.plot(xth,xth*4,'r--')
#ax.set_xscale('log')
#ax.set_yscale('log')
#graphes.save_figs(figs,savedir=savefolder,prefix='Bic_February_'+date_raw+'_map')
#graphes.save_figs(figs,savedir=savefolder_local,prefix='Bic_February_'+date_raw+'_map')
# Out:
# -0.12486063502728939 32.08511711284518
# 1.4507332872599363 21.194708129391074
# 1.9303707610815763 13.208891410380602
# 0.8693295381963253 5.180058594793081
# -0.3667992502450943 1.8613753821700811
# -1.2728367000818253 -3.8115324545651674
# -0.21974832750856876 -4.34381022118032
# -1.3086165077984333 -4.702623529359698
# -0.43888182006776333 -12.774537844583392
# -0.2851772475987673 -13.721014700829983

# %%
import matplotlib.lines as mlines
import matplotlib.patches as plt_patches

import icewave.gps.gps as gps
fig,ax = plt.subplots(figsize=(5,4))

k = 3

colors = ['k','r','b','g']
marker = 'o'
patches= []
data = datas[k]['d']
date = datas[k]['date']
date_raw = date

date = date[:2]+'/'+date[-2:]
color = colors[k]
xs = data[f'lon_mean']
ys = data[f'lat_mean']

radius = 6371*10**3
[xs,ys] = gps.project(xs,ys)

xs = xs*radius*np.pi*2
ys = ys*radius*np.pi*2
xs = xs - np.mean(xs)
ys = ys - np.mean(ys)


#print(ys*radius-np.mean(ys*radius))
#stdxs = data[f'lon_std']
#stdys = data[f'lat_std']
#[stdxs,stdys] = gps.project(stdxs,stdys)

for i,(x,y,stdx,stdy) in enumerate(zip(xs,ys,stdxs,stdys)):
    phone = data['Phone'][i]
    print(x,y)
    ax.scatter(x,y,marker='s',color='r',s=50)
    #ellipse = plt_patches.Ellipse((x,y), stdx/10, stdy/10,color=color,fill=False)
    ax.text(x-5,y-12,phone)
    #ax.add_artist(ellipse)
    

ax.scatter(0,0,marker='x',color='k',s=50)
ax.set_xlim(-200,600)
ax.set_ylim(-100,100)

#patch = mlines.Line2D([], [], color=color, marker=marker,markersize=6,linestyle='None', label=date)
#    patch = mpatches.Patch(color=color, label=k)
#patches.append(patch)

#ax.legend(handles=patches,loc='upper left')
#ax.plot(xth,xth*4,'r--')
#ax.set_xscale('log')
#ax.set_yscale('log')
figs = graphes.legende(f'Distance (m)',f'Distance (m)',date)
graphes.save_figs(figs,savedir=savefolder,prefix='Bic_February_'+date_raw+'_map')
# Out:
# -147.64154233969748 -17.366646338254213
# -139.11361201666296 50.203746208921075
# -105.02592387422919 6.919953037053347
# -50.89605373702943 -4.907342197373509
# -65.33172775618732 39.049010725691915
# -63.85729024372995 -72.21809195913374
# -16.824054639786482 -42.26780475489795
# 18.761812841519713 -14.537944007664919
# 28.75070388801396 -39.021756725385785
# 541.1776879001409 94.14687601290643
