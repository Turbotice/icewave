# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
import numpy as np
import pylab as plt
import glob
import os
from pprint import pprint
import scipy.integrate as inte
import scipy.special as special
import scipy.interpolate as interp
import scipy.signal as sig

# %%
import stephane.display.graphes as graphes
import stephane.tools.Smath as smath

import icewave.tools.datafolders as df
#import sympy #symoblic python
#import mpmath as math
#import cv2
import glob
import csv
import os

import icewave.phone.rw_pyphone as rw

# %%
day = '0306'
date = '2024_'+day
year,day = date.split('_')


base = '/Volumes/Hublot24/Share_hublot/Data/'
basefolders = glob.glob(base+day+'/Telephones/Bic24*/')

for i,basefolder in enumerate(basefolders):
    folders = glob.glob(basefolder+'test*/')

    for folder in folders:
        phone = rw.get_phone_num(folder)
        print(phone,os.path.basename(folder))
        newfolder = basefolder + f"000{i+1}_{phone}_AGML/"
        #print(newfolder)
        os.rename(folder,newfolder)
    pprint(folders)
#base = '/Users/stephane/Documents/git/icewave/icewave/field/Bicwin2024/'
#folder = base+'Data/'+year+'/'+day+'/T_00*'
#folder = basefolder +'000*/'
#norme_folder = base + 'Nomenclature/'
#savefolder = base+'Data/'+year+'/'+day+'/Results'
# Out:
# 22
# 16
# 10
# 6
# 13
# 11
# 5
# 29
# 0
# 24
# 32
# 12
# 15
# 18
# 26
# 30
# 4
# 17
# 28
# 19
# 33
# 23
# 9
# 14
# 1
# 8
# 31
# 21
# 20
# 25
# 34
# 27
# ['/Volumes/Hublot24/Share_hublot/Data/0306/Telephones/Bic24_S03_2024_0306_line2/test_192_168_0_122/',
#  '/Volumes/Hublot24/Share_hublot/Data/0306/Telephones/Bic24_S03_2024_0306_line2/test_192_168_0_116/',
#  '/Volumes/Hublot24/Share_hublot/Data/0306/Telephones/Bic24_S03_2024_0306_line2/test_192_168_0_110/',
#  '/Volumes/Hublot24/Share_hublot/Data/0306/Telephones/Bic24_S03_2024_0306_line2/test_192_168_0_106/',
#  '/Volumes/Hublot24/Share_hublot/Data/0306/Telephones/Bic24_S03_2024_0306_line2/test_192_168_0_113/',
#  '/Volumes/Hublot24/Share_hublot/Data/0306/Telephones/Bic24_S03_2024_0306_line2/test_192_168_0_111/',
#  '/Volumes/Hublot24/Share_hublot/Data/0306/Telephones/Bic24_S03_2024_0306_line2/test_192_168_0_105/',
#  '/Volumes/Hublot24/Share_hublot/Data/0306/Telephones/Bic24_S03_2024_0306_line2/test_192_168_0_129/',
# ...

# %%
pprint(basefolders)
# Out:
# ['/Volumes/Hublot24/Share_hublot/Data/0306/Telephones/Bic24_S03_2024_0306_line2/',
#  '/Volumes/Hublot24/Share_hublot/Data/0306/Telephones/Bic24_S03_2024_0306_tomo/',
#  '/Volumes/Hublot24/Share_hublot/Data/0306/Telephones/Bic24_S03_2024_0306_line2bis_tomerge/']
