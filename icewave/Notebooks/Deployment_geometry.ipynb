# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
import icewave.geometry.define as define
import icewave.geometry.display as display

import os
import glob

from pprint import pprint

# %%
table = define.exemple2()
pprint(table)
# Out:
# [['#', 'X', 'Y', 'Z'],
#  ['G_01', 0, 0, 0],
#  ['G_02', 20, 0, 0],
#  ['G_03', 40, 0, 0],
#  ['G_04', 60, 0, 0],
#  ['G_05', 0, 20, 0],
#  ['G_06', 20, 20, 0],
#  ['G_07', 40, 20, 0],
#  ['G_08', 60, 20, 0],
#  ['G_09', 0, 40, 0],
#  ['G_10', 20, 40, 0],
#  ['G_11', 40, 40, 0],
#  ['G_12', 60, 40, 0],
#  ['G_13', 0, 60, 0],
#  ['G_14', 20, 60, 0],
#  ['G_15', 40, 60, 0],
#  ['G_16', 60, 60, 0],
#  ['S_01', -20, 0, 0],
#  ['S_02', 80, 0, 0],
#  ['S_03', -20, 60, 0],
#  ['S_04', 80, 60, 0],
#  ['S_05', 0, -20, 0],
#  ['S_06', 0, 80, 0],
#  ['S_07', 60, -20, 0],
#  ['S_08', 60, 80, 0]]

# %%
table[0][1]
# Out:
# 'X'

# %%
table = define.exemple1()
display.show(table,sx=10,sy=3)

# %%
table = define.exemple2()
display.show(table,sx=6,sy=6)
