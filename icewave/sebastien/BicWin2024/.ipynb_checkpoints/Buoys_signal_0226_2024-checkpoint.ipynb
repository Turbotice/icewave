# %% [markdown]
# ### Import modules and packages

# %%
# %load_ext autoreload
# %autoreload 2
    
import sys
sys.path.append('C:/Users/sebas/git')

import numpy as np
import os
import glob
import pandas as pd 
import h5py
import pickle
import cv2 as cv

import matplotlib as mpl
import matplotlib.pyplot as plt
import matplotlib.colors as mcolors 
import matplotlib.cm as cm
from mpl_toolkits.axes_grid1 import make_axes_locatable

import scipy.signal as signal
from scipy.interpolate import LinearNDInterpolator, griddata, RegularGridInterpolator
from datetime import datetime,timedelta
import pytz

import icewave.tools.matlab2python as mat2py
import icewave.sebastien.set_graphs as set_graphs
import icewave.drone.drone_projection as dp
import icewave.tools.matlab_colormaps as matcmaps
import icewave.tools.rw_data as rw
import icewave.gps.gps_seb as gps_seb
import icewave.gps.gps as gps
import icewave.geometry.tables as tables

# PARULA COLORMAP 
parula_map = matcmaps.parula()

plt.rc('text', usetex=True)
plt.rc('font', family='serif', serif='Computer Modern')
# Out:
# Windows
# DESKTOP-N65FJTM
# Please install garmin package

# %% [markdown]
# ### Import buoys data

# %%
date = '0226'
base = f'K:/Share_hublot/Data/'
path2buoys = f'{base}{date}/BoueeVague/'

filelist = glob.glob(f'{path2buoys}**/mat/*.mat',recursive = True)

# %%
data_buoy = {}

buoys_list = ['B1','B2','B4','B5']
for key_buoy in buoys_list:
    path = f'{path2buoys}{key_buoy}/mat/*.mat'
    filelist = glob.glob(path)

    data_buoy[key_buoy] = {}
    for i in range(len(filelist)):
        file2load = filelist[i]
        with h5py.File(file2load, 'r') as fmat:
            print('Top-level keys : ', list(fmat.keys()))
    
            # create a key
            key_acq = f'acq_{i}'
            data_buoy[key_buoy][key_acq] = mat2py.mat_to_dict(fmat['IMU'],fmat['IMU'])
# Out:
# Top-level keys :  ['#refs#', 'IMU']
# Top-level keys :  ['#refs#', 'IMU']
# Top-level keys :  ['#refs#', 'IMU']
# Top-level keys :  ['#refs#', 'IMU']
# Top-level keys :  ['#refs#', 'IMU']
# Top-level keys :  ['#refs#', 'IMU']
# Top-level keys :  ['#refs#', 'IMU']
# Top-level keys :  ['#refs#', 'IMU']
# Top-level keys :  ['#refs#', 'IMU']
# Top-level keys :  ['#refs#', 'IMU']
# Top-level keys :  ['#refs#', 'IMU']
# Top-level keys :  ['#refs#', 'IMU']
# Top-level keys :  ['#refs#', 'IMU']
# Top-level keys :  ['#refs#', 'IMU']
# Top-level keys :  ['#refs#', 'IMU']
# Top-level keys :  ['#refs#', 'IMU']

# %%
data_buoy['B4']['acq_0']['GPS1_POS'].keys()
# Out:
# dict_keys(['ALT', 'BASE_STATION_ID', 'CRC', 'CRC_CALC', 'DIFF_AGE', 'GPS_POS_STATUS', 'GPS_TOW', 'LAT', 'LONG', 'NUM_SV_USED', 'POS_ACC_ALT', 'POS_ACC_LAT', 'POS_ACC_LONG', 'TIME_STAMP', 'TS_fix', 'UNDULATION', 't', 'time'])

# %%
data_buoy['B4']['acq_0']['GPS1_POS']['TIME_STAMP']
# Out:
# array([2.74000e+07, 2.76000e+07, 2.78000e+07, ..., 7.07495e+08,
#        7.07695e+08, 7.07895e+08], shape=(3401,))

# %%
data_buoy['B4']['acq_0']['IMU_DATA'].keys()
# Out:
# dict_keys(['ACCEL_X', 'ACCEL_Y', 'ACCEL_Z', 'CRC', 'CRC_CALC', 'DATA_VEL_X', 'DATA_VEL_Y', 'DATA_VEL_Z', 'DELTA_ANGLE_X', 'DELTA_ANGLE_Y', 'DELTA_ANGLE_Z', 'GYRO_X', 'GYRO_Y', 'GYRO_Z', 'IMU_STATUS', 'TEMP', 'TIME_STAMP', 'TS_fix', 't', 'time'])

# %%
# Out:
# [nan nan nan ... nan nan nan]

# %%
fig, ax = plt.subplots()
# ax.plot(data_buoy['B4']['acq_0']['IMU_DATA']['t'])
dt = np.diff(data_buoy['B4']['acq_0']['IMU_DATA']['t'])
ax.plot(dt)
ax.set_ylim([0.015,0.025])
# Out:
# (0.015, 0.025)

# %%
UTC_buoy = {}
u_buoy = {}

# build a filter for buoys
fs = 50 # sampling frequency
fc = 0.05 # cutoff frequency
order_filter = 4
b,a = signal.butter(order_filter,fc,'high',fs = fs)

# define acceleration keys
key_accel = ['ACCEL_X','ACCEL_Y','ACCEL_Z']
key_ufield = ['ux','uy','uz']
for key_buoy in data_buoy.keys():
    UTC_buoy[key_buoy] = {}
    u_buoy[key_buoy] = {}
    for key_acq in data_buoy[key_buoy].keys():
    
        UTC_buoy[key_buoy][key_acq] = []
        # Build UTC time for buoys
        Y = int(data_buoy[key_buoy][key_acq]['UTC_TIME']['YEAR'][0])
        M = int(data_buoy[key_buoy][key_acq]['UTC_TIME']['MONTH'][0])
        D = int(data_buoy[key_buoy][key_acq]['UTC_TIME']['DAY'][0])
        H = int(data_buoy[key_buoy][key_acq]['UTC_TIME']['HOUR'][0])
        MIN = int(data_buoy[key_buoy][key_acq]['UTC_TIME']['MIN'][0])
        SEC = int(data_buoy[key_buoy][key_acq]['UTC_TIME']['SEC'][0])
    
        # initial UTC time for buoys
        UTC0 = datetime(Y,M,D,H,MIN,SEC)
        t0_epoch = UTC0.timestamp()
        t_epoch = t0_epoch + data_buoy[key_buoy][key_acq]['IMU_DATA']['t']
    
        for t in t_epoch:
            if not np.isnan(t):
                UTC_buoy[key_buoy][key_acq].append(datetime.fromtimestamp(t).replace(tzinfo = pytz.utc))
    
        mask = ~np.isnan(t_epoch)
    
        # u_buoy[key] = {}
        current_u = np.array([data_buoy[key_buoy][key_acq]['IMU_DATA'][key_a][mask] for key_a in key_accel])
        # Apply filter to signal 
        current_u = signal.filtfilt(b,a,current_u,axis = -1)
        # Compute vertical velocity
        u_buoy[key_buoy][key_acq] = np.cumsum(current_u - np.mean(current_u,axis = -1,keepdims = True),axis = -1)/fs

# %%
UTC_buoy['B1'].keys()
# Out:
# dict_keys(['acq_0', 'acq_1', 'acq_2', 'acq_3'])

# %%
idx_u = 2 # 0 = u_x, 1 = u_y, 2 = u_z

key_buoys = list(u_buoy.keys())
color_table = ['tab:blue','tab:orange','tab:green','tab:red']
acquisition = np.arange(0,4)

# outlier = 'B1_1900'
outlier = 'B1acq_1'

for key_acq in u_buoy['B1'].keys():
    fig, axs = plt.subplots(figsize = (12,9),ncols = 1, nrows = 3,sharex = True)

    for i,key_buoy in enumerate(u_buoy.keys()):
        current_color = color_table[i]

        test = key_buoy + key_acq
        print(test)
        if test != outlier:
            for idx_u in range(3):
                axs[idx_u].plot(UTC_buoy[key_buoy][key_acq],u_buoy[key_buoy][key_acq][idx_u,:],'-',color = current_color)

    axs[0].set_ylabel(r'$u_x$')
    axs[1].set_ylabel(r'$u_y$')
    axs[2].set_ylabel(r'$u_z$')
    axs[0].set_title(f'Acquisition = {key_acq}')

    
    # for i in range(0 + acqu,len(key_buoys),4):
    #     print(i)
    #     key = key_buoys[i]
    #     current_color = color_table[i//4]
    #     print(i//4)
    #     if key != outlier :
    #         for idx_u in range(3):
    #             axs[idx_u].plot(UTC_buoy[key],u_buoy[key][idx_u,:],'-',color = current_color)
    
    # axs[0].set_ylabel(r'$u_x$')
    # axs[1].set_ylabel(r'$u_y$')
    # axs[2].set_ylabel(r'$u_z$')
    # axs[0].set_title(f'Acquisition = {acqu}')
# Out:
# B1acq_0
# B2acq_0
# B4acq_0
# B5acq_0
# B1acq_1
# B2acq_1
# B4acq_1
# B5acq_1
# B1acq_2
# B2acq_2
# B4acq_2
# B5acq_2
# B1acq_3
# B2acq_3
# B4acq_3
# B5acq_3

# %% [markdown]
# ### Load Drone data

# %%
drone_ID = 'mesange'
exp_ID = '12-FRAC_001'
path2drone = f'{base}{date}/Drones/{drone_ID}/matData/{exp_ID}/'
file2load = glob.glob(f'{path2drone}*scaled.h5')[0]

S = rw.load_dict_from_h5(file2load)

# %%
print(S['SCALE'])
print(S['X'])
print(S['Y'])
# Out:
# {'facq_pix': np.float64(41.795665634674926), 'facq_t': np.float64(30.0), 'ft': np.float64(0.03333333333333333), 'fx': np.float64(0.3828148148148148), 'scale_V': np.float64(0.10253968253968253), 'units': {'facq_pix': 'pix/m', 'facq_t': 'frame/s', 'ft': 's/frame', 'fx': 'm/box', 'scale_V': 'm.frame/pixel/s'}}
# [[ 0.38281481  0.38281481  0.38281481 ...  0.38281481  0.38281481
#    0.38281481]
#  [ 0.76562963  0.76562963  0.76562963 ...  0.76562963  0.76562963
#    0.76562963]
#  [ 1.14844444  1.14844444  1.14844444 ...  1.14844444  1.14844444
#    1.14844444]
#  ...
#  [90.72711111 90.72711111 90.72711111 ... 90.72711111 90.72711111
#   90.72711111]
#  [91.10992593 91.10992593 91.10992593 ... 91.10992593 91.10992593
#   91.10992593]
#  [91.49274074 91.49274074 91.49274074 ... 91.49274074 91.49274074
#   91.49274074]]
# [[ 0.38281481  0.76562963  1.14844444 ... 50.53155556 50.91437037
#   51.29718519]
#  [ 0.38281481  0.76562963  1.14844444 ... 50.53155556 50.91437037
#   51.29718519]
#  [ 0.38281481  0.76562963  1.14844444 ... 50.53155556 50.91437037
#   51.29718519]
#  ...
#  [ 0.38281481  0.76562963  1.14844444 ... 50.53155556 50.91437037
#   51.29718519]
#  [ 0.38281481  0.76562963  1.14844444 ... 50.53155556 50.91437037
#   51.29718519]
#  [ 0.38281481  0.76562963  1.14844444 ... 50.53155556 50.91437037
#   51.29718519]]

# %% [markdown]
# ### Create UTC time array for drone

# %%
datetime_format = '%Y-%m-%d %H:%M:%S.%f'
UTC_0 = datetime.strptime(S['t0_UTC'] + '000',datetime_format)
UTC_0 = UTC_0.replace(tzinfo = pytz.utc)

UTC_drone = [UTC_0 + timedelta(seconds = t) for t in S['t']]
# t0_epoch_drone = UTC_0.timestamp()
# t_epoch_drone = t0_epoch_drone + S['t']
# UTC_drone = []
# for t in t_epoch_drone:
#     if not np.isnan(t):
#         UTC_drone.append(datetime.fromtimestamp(t).replace(tzinfo = pytz.utc))

# %% [markdown]
# ### Spatio temporal plot

# %%
extents_spatio = [UTC_drone[0],UTC_drone[-1],S['x'][0],S['x'][-1]]
fig,ax = plt.subplots()
imsh = ax.imshow(S['uz'],origin = 'lower',aspect = 'auto',cmap = 'seismic',
          interpolation = 'gaussian',extent = extents_spatio)
divider = make_axes_locatable(ax)
cax = divider.append_axes("right", size="2%", pad=0.1)
cbar = plt.colorbar(imsh,cax = cax)
cbar.set_label(r'$u_z \; \mathrm{(m.s^{-1})}$')

ax.set_xlabel(r'$t \; \mathrm{(s)}$',labelpad = 5)
ax.set_ylabel(r'$x \; \mathrm{(m)}$',labelpad = 5)
# Out:
# Text(0, 0.5, '$x \\; \\mathrm{(m)}$')

# %% [markdown]
# ### Compute buoys GPS positions

# %%
buoys_GPS = {}
key_nav = 'GPS1_POS'
for key_buoy in data_buoy.keys():
    buoys_GPS[key_buoy] = {}
    for key_acq in data_buoy[key_buoy].keys():
    
        lat = data_buoy[key_buoy][key_acq][key_nav]['LAT']
        long = data_buoy[key_buoy][key_acq][key_nav]['LONG']
        
        buoys_GPS[key_buoy][key_acq] = {}
        buoys_GPS[key_buoy][key_acq]['latitude'] = np.mean(lat)
        buoys_GPS[key_buoy][key_acq]['longitude'] = np.mean(long)

# %%
key_buoy = 'B1_1800'
data_buoy[key_buoy].keys()
# Out:
# dict_keys(['EKF_EULER', 'EKF_NAV', 'EKF_QUAT', 'GPS1_HDT', 'GPS1_POS', 'GPS1_VEL', 'IMU_DATA', 'MAG', 'STATUS', 'UTC_TIME', 'file_name', 'mdir', 'mname'])

# %%
data_buoy[key_buoy]['GPS1_POS'].keys()
# Out:
# dict_keys(['ALT', 'BASE_STATION_ID', 'CRC', 'CRC_CALC', 'DIFF_AGE', 'GPS_POS_STATUS', 'GPS_TOW', 'LAT', 'LONG', 'NUM_SV_USED', 'POS_ACC_ALT', 'POS_ACC_LAT', 'POS_ACC_LONG', 'TIME_STAMP', 'TS_fix', 'UNDULATION', 't', 'time'])

# %% [markdown]
# ### Plot buoys GPS position and drone GPS positions

# %%
# load Stephane GPS data
path2gps = f'{base}{date}/GPS/'
gpx_filelist = glob.glob(path2gps + '*.gpx')

gpx_file = gpx_filelist[0]
# get gpx
gpx = gps.get_wpts(gpx_file)

# use Map_table to create a dictionnary
data_gps = tables.dict_from_gpx(gpx,path2gps)
# Out:
# waypoint Sag240288, Mon Feb 26 17:13:21 2024 -> (48.348653,-68.799496)
# waypoint Sag240289, Mon Feb 26 17:33:45 2024 -> (48.347318,-68.80523)
# waypoint Sag240290, Mon Feb 26 17:47:27 2024 -> (48.347681,-68.809319)
# waypoint Sag240291, Mon Feb 26 17:48:29 2024 -> (48.34765,-68.809562)
# waypoint Sag240292, Mon Feb 26 17:50:02 2024 -> (48.347664,-68.809648)
# waypoint Sag240293, Mon Feb 26 17:51:56 2024 -> (48.347902,-68.810624)
plot_03'], [302, 'G_0116'], [303, 'plot_04'], [304, 'plot_04'], [305, 'plot_05'], [306, 'S_0101'], [307, 'H_11', '14'], [308, 'S_0102'], [309, 'S_0103'], [310, 'B_0101'], [311, 'T_0100'], [312, 'B_0102'], [312, 'T_0101'], [313, 'B_0103'], [313, 'T_0104'], [315, 'H_12', '14.5'], [316, 'T_9900'], [317, 'B_0104', 'A_verifier'], [318, 'plot_07'], [318, 'G_0316'], [319, 'T_0105'], [320, 'T_0108'], [321, 'H_13', '19'], [322, 'T_0107'], [323, 'plot_06'], [323, 'G_0301'], [324, 'H_14', '21'], [325, 'H_15'], [326, 'T_0109'], [327, 'T_0110'], [328, 'T_0111', 'A_verifier'], [329, 'T_0112', 'A_verifier'], [330, 'T_0119'], [337, 'B_0202'], [333, 'G_0401'], [333, 'plot_11'], [334, 'G_0413'], [334, 'plot_12'], [335, 'G_0416'], [335, 'plot_13'], [336, 'G_0404'], [336, 'plot_14'], [338, 'B_0201'], [338, 'T_0200'], [337, 'T_0201'], [339, 'T_0204'], [340, 'B_0203'], [341, 'T_0205'], [342, 'B_0204'], [343, 'T_0207'], [344, 'B_0205'], [345, 'B_0207'], [346, 'T_0208'], [347, 'T_0209'], [348, 'T_0210'], [349, 'T_0211'], [350, 'T_0212', '']]
# Value 19 associated to waypoint 291 for tag H_02
# Value 19 associated to waypoint 292 for tag H_03
# Value 17.5 associated to waypoint 293 for tag H_04
# Value 19 associated to waypoint 294 for tag H_05
# Value 21 associated to waypoint 295 for tag H_06
# Value 24 associated to waypoint 296 for tag H_07
# Value 25 associated to waypoint 297 for tag H_08
# Value 13 associated to waypoint 298 for tag H_09
# Value 14 associated to waypoint 307 for tag H_11
# Value 14.5 associated to waypoint 315 for tag H_12
# Value A_verifier associated to waypoint 317 for tag B_0104
# Value 19 associated to waypoint 321 for tag H_13
# Value 21 associated to waypoint 324 for tag H_14
# Value A_verifier associated to waypoint 328 for tag T_0111
# Value A_verifier associated to waypoint 329 for tag T_0112
# Value  associated to waypoint 350 for tag T_0212
# dict_keys([288, 289, 290, 291, 292, 293, 294, 295, 296, 297, 298, 299, 300, 301, 302, 303, 304, 305, 306, 307, 308, 309, 310, 311, 312, 313, 315, 316, 317, 318, 319, 320, 321, 322, 323, 324, 325, 326, 327, 328, 329, 330, 337, 333, 334, 335, 336, 338, 339, 340, 341, 342, 343, 344, 345, 346, 347, 348, 349, 350])
# 288 350
# 288 288
# 288
# found!
# 289 288
# 290 288
# 291 288
# 292 288
# 293 288
# 294 288
# 295 288
# 296 288
# 297 288
# 298 288
# 299 288
# 300 288
# 301 288
# 302 288
# 303 288
# 304 288
# 305 288
# 306 288
# 307 288
# 308 288
# 309 288
# 310 288
# 311 288
# 312 288
# 313 288
# 314 288
# 315 288
# 316 288
# 317 288
# 318 288
# 319 288
# 320 288
# 321 288
# 322 288
# 323 288
# 324 288
# 325 288
# 326 288
# 327 288
# 328 288
# 329 288
# 330 288
# 331 288
# 332 288
# 333 288
# 334 288
# 335 288
# 336 288
# 337 288
# 338 288
# 339 288
# 340 288
# 341 288
# 342 288
# 343 288
# 344 288
# 345 288
# 346 288
# 347 288
# 348 288
# 349 288
# 350 288
# 288 289
# 289 289
# 289
# found!
# 290 289
# 291 289
# 292 289
# 293 289
# 294 289
# 344 350
# 345 350
# 346 350
# 347 350
# 348 350
# 349 350
# 350 350
# 350
# found!

# %%
data_gps.keys()
# Out:
# dict_keys(['depart', 'H_01', 'H_02', 'H_03', 'H_04', 'H_05', 'H_06', 'H_07', 'H_08', 'H_09', 'H_10', 'G_0101', 'G_0216', 'G_0116', 'plot_04', 'plot_05', 'S_0101', 'H_11', 'S_0102', 'S_0103', 'B_0101', 'T_0100', 'T_0101', 'T_0104', 'H_12', 'T_9900', 'B_0104', 'G_0316', 'T_0105', 'T_0108', 'H_13', 'T_0107', 'G_0301', 'H_14', 'H_15', 'T_0109', 'T_0110', 'T_0111', 'T_0112', 'T_0119', 'T_0201', 'plot_11', 'plot_12', 'plot_13', 'plot_14', 'T_0200', 'T_0204', 'B_0203', 'T_0205', 'B_0204', 'T_0207', 'B_0205', 'B_0207', 'T_0208', 'T_0209', 'T_0210', 'T_0211', 'T_0212'])

# %%
# keep only gps position of buoys
data_gps_buoy = {}
for key in data_gps.keys():
    instrument = key[0]
    if instrument == 'B' or instrument == 'T':
        data_gps_buoy[key] = data_gps[key]

# %%
data_gps_buoy
# Out:
# {'B_0101': {'longitude': -68.814998,
#   'latitude': 48.348339,
#   'elevation': -2.347648,
#   'time': datetime.datetime(2024, 2, 26, 18, 24, 29, tzinfo=SimpleTZ('Z'))},
#  'T_0100': {'longitude': -68.814769,
#   'latitude': 48.348358,
#   'elevation': -0.927035,
#   'time': datetime.datetime(2024, 2, 26, 18, 26, 37, tzinfo=SimpleTZ('Z'))},
#  'T_0101': {'longitude': -68.814398,
#   'latitude': 48.34839,
#   'elevation': -0.674547,
#   'time': datetime.datetime(2024, 2, 26, 18, 29, 9, tzinfo=SimpleTZ('Z'))},
#  'T_0104': {'longitude': -68.814687,
#   'latitude': 48.347959,
#   'elevation': -0.433199,
#   'time': datetime.datetime(2024, 2, 26, 18, 33, 23, tzinfo=SimpleTZ('Z'))},
#  'T_9900': {'longitude': -68.814363,
#   'latitude': 48.348183,
#   'elevation': -1.61996,
#   'time': datetime.datetime(2024, 2, 26, 18, 44, 12, tzinfo=SimpleTZ('Z'))},
#  'B_0104': {'longitude': -68.813802,
#   'latitude': 48.348438,
#   'elevation': -0.005396,
#   'time': datetime.datetime(2024, 2, 26, 18, 47, 44, tzinfo=SimpleTZ('Z')),
#   'value': 'A_verifier'},
#  'T_0105': {'longitude': -68.813856,
#   'latitude': 48.348269,
#   'elevation': 0.053035,
#   'time': datetime.datetime(2024, 2, 26, 18, 49, 55, tzinfo=SimpleTZ('Z'))},
#  'T_0108': {'longitude': -68.814024,
#   'latitude': 48.348004,
#   'elevation': -1.162986,
#   'time': datetime.datetime(2024, 2, 26, 18, 51, 18, tzinfo=SimpleTZ('Z'))},
#  'T_0107': {'longitude': -68.814006,
#   'latitude': 48.34862,
#   'elevation': -1.953522,
#   'time': datetime.datetime(2024, 2, 26, 18, 55, tzinfo=SimpleTZ('Z'))},
#  'T_0109': {'longitude': -68.813581,
#   'latitude': 48.34858,
#   'elevation': -8.138574,
#   'time': datetime.datetime(2024, 2, 26, 18, 58, 5, tzinfo=SimpleTZ('Z'))},
#  'T_0110': {'longitude': -68.813523,
#   'latitude': 48.34831,
#   'elevation': -7.902989,
#   'time': datetime.datetime(2024, 2, 26, 18, 58, 46, tzinfo=SimpleTZ('Z'))},
#  'T_0111': {'longitude': -68.813199,
#   'latitude': 48.348323,
#   'elevation': -8.467814,
#   'time': datetime.datetime(2024, 2, 26, 18, 59, 34, tzinfo=SimpleTZ('Z')),
#   'value': 'A_verifier'},
#  'T_0112': {'longitude': -68.813122,
#   'latitude': 48.348508,
#   'elevation': -6.957312,
#   'time': datetime.datetime(2024, 2, 26, 19, 0, 46, tzinfo=SimpleTZ('Z')),
#   'value': 'A_verifier'},
#  'T_0119': {'longitude': -68.808562,
#   'latitude': 48.347684,
#   'elevation': -10.130186,
#   'time': datetime.datetime(2024, 2, 26, 19, 11, 58, tzinfo=SimpleTZ('Z'))},
#  'T_0201': {'longitude': -68.811029,
#   'latitude': 48.347901,
#   'elevation': -6.433991,
#   'time': datetime.datetime(2024, 2, 26, 20, 21, 11, tzinfo=SimpleTZ('Z'))},
#  'T_0200': {'longitude': -68.810613,
#   'latitude': 48.347908,
#   'elevation': -6.759455,
#   'time': datetime.datetime(2024, 2, 26, 20, 22, 34, tzinfo=SimpleTZ('Z'))},
#  'T_0204': {'longitude': -68.810903,
#   'latitude': 48.348217,
#   'elevation': -6.488031,
#   'time': datetime.datetime(2024, 2, 26, 20, 25, 30, tzinfo=SimpleTZ('Z'))},
#  'B_0203': {'longitude': -68.810987,
#   'latitude': 48.348281,
#   'elevation': -5.403884,
#   'time': datetime.datetime(2024, 2, 26, 20, 26, 19, tzinfo=SimpleTZ('Z'))},
#  'T_0205': {'longitude': -68.810895,
#   'latitude': 48.34758,
#   'elevation': -6.564401,
#   'time': datetime.datetime(2024, 2, 26, 20, 28, 32, tzinfo=SimpleTZ('Z'))},
#  'B_0204': {'longitude': -68.810975,
#   'latitude': 48.347502,
#   'elevation': -7.260654,
#   'time': datetime.datetime(2024, 2, 26, 20, 29, 16, tzinfo=SimpleTZ('Z'))},
#  'T_0207': {'longitude': -68.811054,
#   'latitude': 48.347414,
#   'elevation': -7.277978,
#   'time': datetime.datetime(2024, 2, 26, 20, 29, 44, tzinfo=SimpleTZ('Z'))},
#  'B_0205': {'longitude': -68.811181,
#   'latitude': 48.347891,
#   'elevation': -6.821996,
#   'time': datetime.datetime(2024, 2, 26, 20, 34, 20, tzinfo=SimpleTZ('Z'))},
#  'B_0207': {'longitude': -68.811442,
#   'latitude': 48.347881,
#   'elevation': -8.096949,
#   'time': datetime.datetime(2024, 2, 26, 20, 35, 21, tzinfo=SimpleTZ('Z'))},
#  'T_0208': {'longitude': -68.811345,
#   'latitude': 48.347883,
#   'elevation': -7.522513,
#   'time': datetime.datetime(2024, 2, 26, 20, 35, 55, tzinfo=SimpleTZ('Z'))},
#  'T_0209': {'longitude': -68.811248,
#   'latitude': 48.348028,
#   'elevation': -6.442705,
#   'time': datetime.datetime(2024, 2, 26, 20, 36, 40, tzinfo=SimpleTZ('Z'))},
#  'T_0210': {'longitude': -68.811482,
#   'latitude': 48.348019,
#   'elevation': -5.686577,
#   'time': datetime.datetime(2024, 2, 26, 20, 37, 43, tzinfo=SimpleTZ('Z'))},
#  'T_0211': {'longitude': -68.811416,
#   'latitude': 48.34771,
#   'elevation': -6.263741,
#   'time': datetime.datetime(2024, 2, 26, 20, 38, 40, tzinfo=SimpleTZ('Z'))},
#  'T_0212': {'longitude': -68.811095,
#   'latitude': 48.347718,
#   'elevation': -7.644236,
#   'time': datetime.datetime(2024, 2, 26, 20, 39, 36, tzinfo=SimpleTZ('Z')),
#   'value': ''}}

# %%
# Load image 
path2img = f'{base}{date}/Drones/{drone_ID}/{exp_ID}/images/*0683*.tiff'
filelist_img = glob.glob(path2img)
file2load = filelist_img[0]

img = cv.imread(file2load)
img = cv.cvtColor(img,cv.COLOR_BGR2RGB)

# %%
# plot image 
GPS_D = (S['GPS']['latitude'],S['GPS']['longitude'],S['GPS']['azimuth'])
Lat,Long,Lat0,Long0 = dp.georeference_from_param(img,S['DRONE']['h_drone'],S['DRONE']['alpha_0'],S['DRONE']['focale'],GPS_D)

extents = [Long.min(),Long.max(),Lat.min(),Lat.max()]
fig, ax = plt.subplots()
imsh = ax.pcolormesh(Long,Lat,img[:,:,2],shading = 'auto', cmap = 'gray')
ax.set_aspect(1/np.cos(S['GPS']['latitude']*np.pi/180)) # scaling y/x

# %%
# create a dictionnary for buoy colors
norm = mcolors.Normalize(vmin = 0, vmax = 3)

cmap_dict = {'B1':'Blues','B2':'Greens','B4':'Oranges','B5':'Reds'}

GPS_D = (S['GPS']['latitude'],S['GPS']['longitude'],S['GPS']['azimuth'])
Lat,Long,Lat0,Long0 = dp.georeference_from_param(img,S['DRONE']['h_drone'],S['DRONE']['alpha_0'],S['DRONE']['focale'],GPS_D)

set_graphs.set_matplotlib_param('single')
fig, ax = plt.subplots(figsize = (12,9))

extents = [Long.min(),Long.max(),Lat.min(),Lat.max()]
imsh = ax.pcolormesh(Long,Lat,img[:,:,2],shading = 'auto',cmap = 'gray')

ax.plot(S['GPS']['longitude'],S['GPS']['latitude'],'ks')

for key_buoy in buoys_GPS.keys():
    full_cmap = mpl.colormaps[cmap_dict[key_buoy]].resampled(256)
    cmap = mcolors.ListedColormap(full_cmap(np.linspace(0.2,0.8,256)))
    for i,key_acq in enumerate(buoys_GPS[key_buoy].keys()):
        current_color = cmap(norm(i))
        ax.plot(buoys_GPS[key_buoy][key_acq]['longitude'],buoys_GPS[key_buoy][key_acq]['latitude'],'p',
                color = current_color,mec = 'k',ms = 10)

for key in data_gps_buoy.keys():
    ax.plot(data_gps_buoy[key]['longitude'],data_gps_buoy[key]['latitude'],'^',color = 'tab:purple',mec = 'k',ms = 10)
    # test = np.logical_and(data_gps_buoy[key]['longitude'] > extents[0], data_gps_buoy[key]['longitude'] < extents[1],
    #                       data_gps_buoy[key]['latitude'] > extents[2], data_gps_buoy[key]['latitude'] > extents[3])
    # ax.text(data_gps_buoy[key]['longitude'],data_gps_buoy[key]['latitude'],key)

ax.set_aspect(1/np.cos(S['GPS']['latitude']*np.pi/180)) # scaling y/x
# ax.set_xlim([Long.min(),Long.max()])
# ax.set_ylim([Lat.min(),Lat.max()])

ax.set_xlabel(r'Longitude (°)')
ax.set_ylabel(r'Latitude (°)')
# Out:
# Text(0, 0.5, 'Latitude (°)')

# %% [markdown]
# ### Load buoys tracking data

# %%
path2tracking = f'{base}{date}/Drones/{drone_ID}/matData/{exp_ID}/Buoys_tracking*.mat'
file2load = glob.glob(path2tracking)[0]
print(file2load)

with h5py.File(file2load,'r') as fmat:
    print('Top-level keys : ', list(fmat.keys()))
    track = mat2py.mat_to_dict(fmat['S_buoys'],fmat['S_buoys'])
# track = rw.load_dict_from_h5(file2load)
# Out:
# K:/Share_hublot/Data/0226/Drones/mesange/matData/12-FRAC_001\Buoys_tracking_pix_0226_mesange_12-FRAC_001.mat
# Top-level keys :  ['#refs#', 'S_buoys']

# %%
len(track['x1'])/30
# Out:
# 256.6666666666667

# %% [markdown]
# ### Superpose detected buoys on image

# %%
fig, ax = plt.subplots()
ax.imshow(img)

# track_keys = list(track.keys())
color_dict = {1:'tab:orange',2:'tab:green',3:'tab:blue'}
idx = 0
for i in range(1,4):
    key_x = f'x{i}'
    key_y = f'y{i}'

    ax.plot(track[key_x][idx],track[key_y][idx],'o',color = color_dict[i],mec = 'k',ms = 8)

# %% [markdown]
# ### Build correspondance table and tracking matrix

# %%
corresp_table = {0:'B4',1:'B2',2:'B1'}
N = len(track['idx'])
Z = {'pix':np.zeros((3,2,N))}

for i in range(1,4):
    key_x = f'x{i}'
    key_y = f'y{i}'
    Z['pix'][i-1,0,:] = track[key_x][:]
    Z['pix'][i-1,1,:] = track[key_y][:]

# %% [markdown]
# ### Compute (X,Y) and GPS coordinates of buoys

# %%
Z['real'] = np.zeros(Z['pix'].shape)
Z['real'][:,0,:],Z['real'][:,1,:] = dp.projection_real_space(Z['pix'][:,0,:],Z['pix'][:,1,:],S['PIXEL']['x0'],S['PIXEL']['y0'],
                                    S['DRONE']['h_drone'],S['DRONE']['alpha_0'],S['DRONE']['focale'])

# Z['GPS'] = dp.XY2GPS(Z['real'][:,0,:],Z['real'][:,1,:],S['GPS']['latitude'],S['GPS']['longitude'],S['GPS']['azimuth'])

# %% [markdown]
# ### Interpolate velocity field along buoys trajectories

# %%
interp_u = {}

for buoy_idx in range(3):
    key_buoy = corresp_table[buoy_idx]
    
    # collect object trajectory in image coordinates 
    indices = np.arange(0,Z['pix'].shape[2])
    x_obj = Z['pix'][buoy_idx,0,:]
    y_obj = Z['pix'][buoy_idx,1,:]

    interp_u[key_buoy] = np.zeros((2,len(indices)))

    # interpolate u_x
    I_ux = RegularGridInterpolator((S['PIXEL']['x_pix'],S['PIXEL']['y_pix'],indices),S['ux'][:,:,:Z['pix'].shape[2]],
                                  bounds_error = False,fill_value = None)
    interp_u[key_buoy][0,:] = I_ux(np.column_stack([x_obj,y_obj,indices]))
    # interpolate u_z
    I_uz = RegularGridInterpolator((S['PIXEL']['x_pix'],indices),S['uz'][:,:Z['pix'].shape[2]],
                                   bounds_error = False,fill_value = None)
    interp_u[key_buoy][1,:] = I_uz(np.column_stack([x_obj,indices]))
    print(f'{key_buoy} processed !')
# Out:
# B4 processed !
# B2 processed !
# B1 processed !

# %% [markdown]
# ### Filter interpolated velocities

# %%
# filter drone signal
fs = 30 # sampling frequency
fc = 2 # cutoff frequency
order_filter = 4
b,a = signal.butter(order_filter,fc,'low',fs = fs)

# Apply filter to signal 
filtered_u = {}
for key_buoy in interp_u.keys():
    filtered_u[key_buoy] = signal.filtfilt(b,a,interp_u[key_buoy],axis = -1)

# %% [markdown]
# ### Save buoys velocity fields in a structure

# %%
u_buoy['B1']['acq_0']
# Out:
# array([[-7.16106585e-04, -1.47024745e-03, -2.37992383e-03, ...,
#          3.78284554e-04,  1.55490632e-04, -2.26560090e-15],
#        [ 5.57959834e-05,  1.51434468e-04,  2.32824046e-04, ...,
#         -1.11403881e-04, -7.74764733e-05,  1.16408619e-16],
#        [-1.39711596e-04, -2.38753286e-04, -3.54747457e-04, ...,
#         -2.30414053e-04, -1.42352712e-04, -1.26825633e-15]],
#       shape=(3, 101951))

# %%
data = {}
data['drone'] = interp_u
data['buoy'] = u_buoy
data['UTC'] = {'drone':UTC_drone,'buoy':UTC_buoy}
data['structure'] = {'drone':'Interpolated velocity on traj, u[0,:] = ux, u[1,:] = uz',
                     'buoy':'buoy velocity for each acquisition, (u[0,:],u[1,:],u[2,:]) = (ux,uy,uz)',
                    'UTC':'UTC datetime for each velocity type'}

base = 'F:/Rimouski_2024/Data/'
# F:\Rimouski_2024\Data\0226\Drones\mesange\matData\12-FRAC_001
file2save = f'{base}{date}/Drones/{drone_ID}/matData/{exp_ID}/data_buoys_velocity_{date}_{drone_ID}_{exp_ID}.pkl'
with open(file2save,'wb') as pf:
    pickle.dump(data,pf)
# rw.save_dict_to_h5(data,file2save)

# %% [markdown]
# ### Plot interpolated velocities and true buoy velocities

# %%
key_acq = 'acq_0'
color_dict = {'B4':'tab:orange','B2':'tab:green','B1':'tab:blue'}
fig, axs = plt.subplots(nrows = 3,ncols = 1)
for i,key_buoy in enumerate(filtered_u.keys()):
    axs[i].plot(UTC_drone[:N],filtered_u[key_buoy][1,:],color = color_dict[key_buoy])
    axs[i].plot(UTC_buoy[key_buoy][key_acq],u_buoy[key_buoy][key_acq][2,:],'k-')

# %%
u_buoy['B1']['acq_0'].shape
# Out:
# (3, 101951)

# %%
fig, ax = plt.subplots()
color_dict = {'B4':'tab:orange','B2':'tab:green','B1':'tab:blue'}
for key_buoy in filtered_u.keys():
    ax.plot(UTC_drone[:N],filtered_u[key_buoy][1,:],color = color_dict[key_buoy],label = key_buoy)

ax.legend()
