# %%
# ouverture d'une des images tiff pour vérification
tiff_image_path = r"F:\bicwin26\data\0212\Drones\Tourterelle\2-orthoTV_001\DJI_20260212150922_0001_T.JPG"
import sys
sys.path.append('../drone_IR')
from open_IRimage_dji import open_IR_image

open_IR_image(tiff_image_path,plot=True)
# Out:
# 2072576
# File size: 2072576
# File size: c_long(2072576)
# rjpeg_data: <ctypes.c_char_Array_2072576 object at 0x0000021D8EA4C9D0>
# ret = 0
# successfully get the r-jpeg handle.
# DIRP_HANDLE: c_void_p(2325949650528)  address: 0x21d8d671660
# Résolution : 640x512
# Ret measure: 0

# %%
import pandas as pd
df_calib = pd.read_csv(r"F:\bicwin26\Summary\calibration_IR\calibration_Tourterelle_0212.csv",sep=";")
df_calib
# Out:
#       heure T_IR_celsius T_err_IR_celsius T_thermometre_cuisine surface  \
# 0  09:09:21         -9,9              0,1                  -6,5   glace
# 1  09:09:21        -11,5              0,2                  -7,1   neige
# 2  09:09:21         -5,6              0,2                    -2     eau
#
#                                        image_path_IR  \
# 0  F:\bicwin26\data\0212\Drones\Tourterelle\2-ort...
# 1  F:\bicwin26\data\0212\Drones\Tourterelle\2-ort...
# 2  F:\bicwin26\data\0212\Drones\Tourterelle\2-ort...
#
#                                   image_path_visible   x_px   y_px  \
# 0  F:\bicwin26\data\0212\Drones\Tourterelle\2-ort...    NaN    NaN
# 1  F:\bicwin26\data\0212\Drones\Tourterelle\2-ort...    NaN    NaN
# 2  F:\bicwin26\data\0212\Drones\Tourterelle\2-ort...  342.0  242.0
#
#    commentaire
# 0          NaN
# 1          NaN
# 2          NaN
